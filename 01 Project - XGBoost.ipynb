# %%
def preprocesamiento(df):

    import pandas as pd
    import numpy as np
    
    import warnings
    warnings.filterwarnings('ignore')
    
    
#    df = pd.read_csv("Esophageal_Dataset.csv")
    cols_to_drop = ['Unnamed: 0',
                    'patient_barcode',
                    'tissue_source_site',
                    'patient_id',
                    'bcr_patient_uuid',
                    'informed_consent_verified',
                    'icd_o_3_site',
                    'country_of_birth',
                    'country_of_procurement', 
                    'state_province_of_procurement',
                    'city_of_procurement',
                    'history_of_neoadjuvant_treatment', 
                    'age_began_smoking_in_years',
                    'stopped_smoking_year',
                    'number_pack_years_smoked',
                    'frequency_of_alcohol_consumption',
                    'amount_of_alcohol_consumption_per_day',
                    'antireflux_treatment_types',
                    'h_pylori_infection',
                    'goblet_cells_present',
                    'number_of_relatives_diagnosed',
                    'day_of_form_completion',
                    'month_of_form_completion',
                    'year_of_form_completion',
                    'project',
                    'stage_event_system_version',
                    'stage_event_psa',
                    'stage_event_gleason_grading',
                    'stage_event_ann_arbor',
                    'stage_event_serum_markers',
                    'stage_event_igcccg_stage',
                    'stage_event_masaoka_stage',
                    'primary_pathology_tumor_tissue_site',
                    'primary_pathology_esophageal_tumor_involvement_sites',
                    'primary_pathology_columnar_metaplasia_present',
                    'primary_pathology_columnar_mucosa_goblet_cell_present',
                    'primary_pathology_columnar_mucosa_dysplasia',
                    'primary_pathology_days_to_initial_pathologic_diagnosis',
                    'primary_pathology_year_of_initial_pathologic_diagnosis',
                    'primary_pathology_init_pathology_dx_method_other',
                    'primary_pathology_number_of_lymphnodes_positive_by_he',
                    'primary_pathology_number_of_lymphnodes_positive_by_ihc',
                    'primary_pathology_planned_surgery_status',
                    'primary_pathology_treatment_prior_to_surgery',
                    'primary_pathology_karnofsky_performance_score',
                    'primary_pathology_eastern_cancer_oncology_group',
                    'days_to_last_followup',
                    'days_to_death']
    
    df.drop(columns=cols_to_drop, inplace=True)
    
#se harán dummies para los indicadores histológicos icd_o_3 & icd_10
    
#rellenamos nans de prospective collection con método bfill, y usamos prospective collection para crear columna tissue collection:
#con valor 1 para prospective (prospective=YES) y 0 para retrospective (prospective=NO)
#y eliminaremos las columnas prospective y retrospective
    df.tissue_prospective_collection_indicator = df.tissue_prospective_collection_indicator.fillna(method='bfill')
    df['tissue_collection'] = df['tissue_prospective_collection_indicator']
    
    df.loc[(df['tissue_prospective_collection_indicator'] == 'YES'), 'tissue_collection'] = 1
    df.loc[(df['tissue_prospective_collection_indicator'] == 'NO'), 'tissue_collection'] = 0
  
    
#se crea una columna edad que contendrá la edad en años (módulo de la division por 365 de la columna days_to_birth)
#y se crea una columna de años sobrevividos con la diferencia entre edad y edad de diagnóstico
#(para casos en los que la diferencia es -1 por ajuste del modulo, se fuerza valor 0)
#se escala usando minmax scaling
#por último se eliminará la columna original days_to_birth
    df['age'] = df.days_to_birth // -365
    df['years_survived']=df.age - df.primary_pathology_age_at_initial_pathologic_diagnosis
    df.loc[df.years_survived < 0, 'years_survived'] = 0
    df.age = (df.age - df.age.min()) / (df.age.max() - df.age.min())
    
#se crean dummies para sexo
#se eliminará la columna original después de haber calculado las medias de altura y peso por sexo
#para rellenar los NaN de esas columnas 
#se escalan min_max la altura y el peso    
    df.loc[(df.height.isna()) & (df.gender == 'FEMALE'), 'height'] = df.loc[(df.gender == 'FEMALE'), 'height'].mean()
    df.loc[(df.height.isna()) & (df.gender == 'MALE'), 'height'] = df.loc[(df.gender == 'MALE'), 'height'].mean()
    df.height = (df.height - df.height.min()) / (df.height.max() - df.height.min())
    
    df.loc[(df.weight.isna()) & (df.gender == 'FEMALE'), 'weight'] = df.loc[(df.gender == 'FEMALE'), 'weight'].mean()
    df.loc[(df.weight.isna()) & (df.gender == 'MALE'), 'weight'] = df.loc[(df.gender == 'MALE'), 'weight'].mean()
    df.weight = (df.weight - df.weight.min()) / (df.weight.max() - df.weight.min())

    
#Los NaN de la columna race_list se rellenará de la siguiente forma:
#en los casos en los que sea NAN y la columna 'ethnicity' sea HISPANIC, se rellenará como HISPANIC… 
#los demás NAN se rellenárán usando el método backfill.
#se crean dummies para la columna y se eliminará la columna 'ethnicity'
    df.loc[(df.race_list.isna()) & (df.ethnicity == 'HISPANIC OR LATINO'), 'race_list'] = 'HISPANIC'
    df.race_list = df.race_list.fillna(method='bfill')
    
#valores YES/NO de other_dx pasan a ser 1/0
    df.loc[df.other_dx == 'Yes', 'other_dx'] = 1
    df.loc[df.other_dx == 'No', 'other_dx'] = 0
    
#valores TUMOR FREE/WITH TUMOR de person_neoplasm_cancer_status pasan a ser 0/1
#y NaN se cambian con método ffill
    df.loc[df.person_neoplasm_cancer_status == 'TUMOR FREE', 'person_neoplasm_cancer_status'] = 0
    df.loc[df.person_neoplasm_cancer_status == 'WITH TUMOR', 'person_neoplasm_cancer_status'] = 1
    df.person_neoplasm_cancer_status = df.person_neoplasm_cancer_status.fillna(method='ffill')
    
#valores Dead/Alive de vital_status pasan a ser 0/1
    df.loc[df.vital_status == 'Dead', 'vital_status'] = 0
    df.loc[df.vital_status == 'Alive', 'vital_status'] = 1
    
#historial de fumador: sustituimos NaN con método ffill y hacemos dummies para los valores 1,2,3,4. 
    df.tobacco_smoking_history = df.tobacco_smoking_history.fillna(method='ffill')
   
    
#historial de alcohol: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.loc[df.alcohol_history_documented == 'NO', 'alcohol_history_documented'] = 0
    df.loc[df.alcohol_history_documented == 'YES', 'alcohol_history_documented'] = 1
    df.alcohol_history_documented = df.alcohol_history_documented.fillna(method='bfill')
    
#historial de reflujo: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.reflux_history = df.reflux_history.fillna(method='ffill')
    df.loc[(df.reflux_history == 'NO') | (df.reflux_history.isna()), 'reflux_history'] = 0
    df.loc[df.reflux_history == 'YES', 'reflux_history'] = 1
    
    
#diagnóstico inicial: pasar Symptomatic/Screening/Surveillance a 1/2/3 
#rellenar NaN con frontfill y get_dummies
    df.initial_diagnosis_by = df.initial_diagnosis_by.fillna(method='ffill')

    
#barretts_esophagus: Yes/No a 1/0 y rellenar NaN con frontfill
    df.loc[df.barretts_esophagus  == 'No', 'barretts_esophagus'] = 0
    df.loc[df.barretts_esophagus  == 'Yes-USA', 'barretts_esophagus'] = 1
    df.loc[df.barretts_esophagus  == 'Yes-UK', 'barretts_esophagus'] = 1 
    df.barretts_esophagus = df.barretts_esophagus.fillna(method='ffill')
    
#historial de cáncer de esófago: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.history_of_esophageal_cancer = df.history_of_esophageal_cancer.fillna(method='ffill')
    df.loc[(df.history_of_esophageal_cancer == 'NO') | (df.history_of_esophageal_cancer.isna()), 'history_of_esophageal_cancer'] = 0
    df.loc[df.history_of_esophageal_cancer == 'YES', 'history_of_esophageal_cancer'] = 1
    
    
#nuevos eventos tumorales: pasar Yes/No a 1/0
    df.loc[df.has_new_tumor_events_information == 'NO', 'has_new_tumor_events_information'] = 0
    df.loc[df.has_new_tumor_events_information == 'YES', 'has_new_tumor_events_information'] = 1
    
#le hacen seguimientos: pasar Yes/No a 1/0
    df.loc[df.has_follow_ups_information == 'NO', 'has_follow_ups_information'] = 0
    df.loc[df.has_follow_ups_information == 'YES', 'has_follow_ups_information'] = 1
    
#pautan medicación tumorales: pasar Yes/No a 1/0
    df.loc[df.has_drugs_information == 'NO', 'has_drugs_information'] = 0
    df.loc[df.has_drugs_information == 'YES', 'has_drugs_information'] = 1
    
#pautan radiación: pasar Yes/No a 1/0
    df.loc[df.has_radiations_information == 'NO', 'has_radiations_information'] = 0
    df.loc[df.has_radiations_information == 'YES', 'has_radiations_information'] = 1
    
#Combinamos las columnas stage_event_clinical_stage y stage_event_pathologic_stage en una única columna stage
#tomando como referencia el valor de stage_event_pathologic_stage, y cuando este es NaN
#tomando el valor de stage_event_clinical_stage.
    df['stage'] = np.where(~df['stage_event_pathologic_stage'].isna(), 
                           df['stage_event_pathologic_stage'], 
                           df['stage_event_clinical_stage'])
    
#Para aquellos casos en los que no está informado ni el estadio clínico ni patológico
#utilizaremos el valor T y N de la columna stage_event_tnm_categories para establecer el Stage
#Para ello, creamos las siguientes máscaras booleanas según la clasificación de stages
#para cáncer de esófago a partir de valores TNM encontrado online:

    #Stage I: T1, N0, M0
    #Stage II: T2, N0, M0 or T3, N0, M0 ...incluyo aquí los T2NX por ser Stage II mayoría
    #Stage III: T1-3, N1, M0 or T4, N0-1, M0
    #Stage IV: T1-4, N2-3, M0 or T1-4, N0-3, M1
    
    bool_mask_1 = ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                   (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False)))
    
    bool_mask_2 = (((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('X').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))))
    
    bool_mask_3 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))))
    
    bool_mask_4 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))))
    
    #Aplicamos la máscara
    mask_na = df['stage'].isna()
    df.loc[mask_na, 'stage'] = np.select([bool_mask_1[df['stage'].isna()], 
                                          bool_mask_2[df['stage'].isna()], 
                                          bool_mask_3[df['stage'].isna()],
                                          bool_mask_4[df['stage'].isna()]], 
                                         ['Stage I', 'Stage II', 'Stage III', 'Stage IV'], 
                                            default=np.nan)
    
#Simplificamos los valores de Stage a Stage I, Stage II, Stage III y Stage IV eliminando sufijos, previo a pasar a dummies
    df['stage'] = df['stage'].str.removesuffix('A').str.removesuffix('B').str.removesuffix('C')
      
#eliminaremos las columnas de clinical_stage, pathologic_stage y tnm_categories
    
    
#rellenamos los pocos valores NaN de primary_pathology_esophageal_tumor_cental_location 
#con Distal por ser el valor más frecuente y hacemos get_dummies para los tres valores: Distal, Mid, Proximal
    df.primary_pathology_esophageal_tumor_cental_location = df.primary_pathology_esophageal_tumor_cental_location.fillna('Distal')

    
#primary_pathology_histological_type: renombramos y hacemos get_dummies antes de eliminar columna original
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Adenocarcinoma, NOS'), 
            'primary_pathology_histological_type'] = 'Adeno-NOS'
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Squamous Cell Carcinoma'), 
            'primary_pathology_histological_type'] = 'ESCC'
   
    
#primary_pathology_neoplasm_histologic_grade: get_dummies

    
#primary_pathology_age_at_initial_pathologic_diagnosis: escalar min_max
    df.primary_pathology_age_at_initial_pathologic_diagnosis = (df.primary_pathology_age_at_initial_pathologic_diagnosis - df.primary_pathology_age_at_initial_pathologic_diagnosis.min()) / (df.primary_pathology_age_at_initial_pathologic_diagnosis.max() - df.primary_pathology_age_at_initial_pathologic_diagnosis.min())
    
#primary_pathology_initial_pathologic_diagnosis_method:
#valores: biopsy/surgery/other
#la columna primary_pathology_init_pathology_dx_method_other (elimiada) informa de los posibles 'other':
#que en la gran mayoría de casos son surgical resection… por tanto, dejaremos solo dos alores biopsy/resection
#y en el último incluiremos los other y NaN de la columna, para después crear dummies
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] == 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Biopsy'
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] != 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Resection'
    df.primary_pathology_initial_pathologic_diagnosis_method = df.primary_pathology_initial_pathologic_diagnosis_method.fillna('Resection')

    
#primary_pathology_lymph_node_metastasis_radiographic_evidence: 
#rellenar NaN en función de si en 'stage' es StageIV (YES) o no (NO), y hacer dummies
#borrar esta fila y stage
    
    bool_mask_stage = df.stage.str.match('Stage IV').fillna(False)
    bool_mask_no_stage = ((df.stage.str.match('Stage III').fillna(False)) |
                          (df.stage.str.match('Stage II').fillna(False)) |
                          (df.stage.str.match('Stage I').fillna(False)))
    mask_stage = df.primary_pathology_lymph_node_metastasis_radiographic_evidence.isna()
    df.loc[mask_stage, 'primary_pathology_lymph_node_metastasis_radiographic_evidence'] = np.select([bool_mask_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()], 
                                                                                                     bool_mask_no_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()]], 
                                                                                                    ['YES', 'NO'],
                                                                                                    default=np.nan)
        
#primary_pathology_primary_lymph_node_presentation_assessment. Rellenar NaN con method bfill
    df.primary_pathology_primary_lymph_node_presentation_assessment = df.primary_pathology_primary_lymph_node_presentation_assessment.fillna(method='bfill')

    
    
#primary_pathology_lymph_node_examined_count:
#se rellenarán los NaN como 0 si primary_lymph_node_presentation es 'NO' o con la media de recuento si es 'YES' (14.0)
#después se dividirán en 4 grupos según la clasificación descrita por The Cleveland Journal of Medicine
#de la clasificación TNM para el cáncer de esófago: 
#0 (N0), 1-2 (N1), 3-6 (N2), 7 o más (N3)
    bool_mask_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('YES').fillna(False)
    bool_mask_no_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('NO').fillna(False)
    
    mask_lymph_count = df.primary_pathology_lymph_node_examined_count.isna()
    mean_count = round(df.primary_pathology_lymph_node_examined_count.mean(),0)
    df.loc[mask_lymph_count, 'primary_pathology_lymph_node_examined_count'] = np.select([bool_mask_lymph[df['primary_pathology_lymph_node_examined_count'].isna()], 
                                                                                                     bool_mask_no_lymph[df['primary_pathology_lymph_node_examined_count'].isna()]], 
                                                                                                    [mean_count, 0.0],
                                                                                                    default=np.nan)
    df.loc[(df['primary_pathology_lymph_node_examined_count'] == 0.0), 'lymph_node_count'] = 'N0'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 1.0) & (df['primary_pathology_lymph_node_examined_count'] <= 2.0), 'lymph_node_count'] = 'N1'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 3.0) & (df['primary_pathology_lymph_node_examined_count'] <= 6.0), 'lymph_node_count'] = 'N2'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 7.0), 'lymph_node_count'] = 'N3'
    
#primary_pathology_residual_tumor: rellenamos NaN con forward fill, y demás valores pasan a dos grupos: No (R0) & Yes (R1/R2/RX), then get_dummies
    
    df.primary_pathology_residual_tumor = df.primary_pathology_residual_tumor.fillna(method='ffill')
    df.loc[(df['primary_pathology_residual_tumor'] == 'R0'),'primary_pathology_residual_tumor'] = 'NO'
    df.loc[(df['primary_pathology_residual_tumor'] != 'R0'),'primary_pathology_residual_tumor'] = 'YES'

    
    #primary_pathology_radiation_therapy
    df.primary_pathology_radiation_therapy = df.primary_pathology_radiation_therapy.fillna(method='ffill')

    
    #primary_pathology_postoperative_rx_tx 
    df.primary_pathology_postoperative_rx_tx = df.primary_pathology_postoperative_rx_tx.fillna(method='bfill')
    
    cols_to_dummies = ['icd_o_3_histology', 'icd_10', 'gender', 'race_list', 'tobacco_smoking_history', 'initial_diagnosis_by', 'stage', 
                         'primary_pathology_esophageal_tumor_cental_location', 'primary_pathology_histological_type', 'primary_pathology_neoplasm_histologic_grade',
                         'primary_pathology_initial_pathologic_diagnosis_method', 'primary_pathology_lymph_node_metastasis_radiographic_evidence',
                         'primary_pathology_primary_lymph_node_presentation_assessment', 'lymph_node_count', 'primary_pathology_residual_tumor',
                         'primary_pathology_radiation_therapy', 'primary_pathology_postoperative_rx_tx']
    
#    cols_to_concat = ['tissue_collection','age','years_survived', 'height', 'weight', 'other_dx', 'person_neoplasm_cancer_status', 'vital_status', 'alcohol_history_documented',
#                     'reflux_history', 'barretts_esophagus', 'history_of_esophageal_cancer','has_new_tumor_events_information', 'has_follow_ups_information', 'has_drugs_information',
#                     'has_radiations_information', 'primary_pathology_age_at_initial_pathologic_diagnosis']
    
    
    df_final = pd.get_dummies(data=df, columns=cols_to_dummies, drop_first=True)
    df_final.drop(columns=['tissue_prospective_collection_indicator', 'tissue_retrospective_collection_indicator', 'days_to_birth', 
                           'ethnicity', 'stage_event_clinical_stage', 'stage_event_pathologic_stage', 'stage_event_tnm_categories', 
                           'primary_pathology_lymph_node_examined_count'], inplace=True)
    df_final=df_final.astype("float")
    df_final.to_csv('Esophageal_Dataset_clean.csv')
    return(df_final)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
data.columns
# Out:
# Index(['height', 'weight', 'other_dx', 'person_neoplasm_cancer_status',
#        'vital_status', 'alcohol_history_documented', 'reflux_history',
#        'barretts_esophagus', 'history_of_esophageal_cancer',
#        'has_new_tumor_events_information', 'has_follow_ups_information',
#        'has_drugs_information', 'has_radiations_information',
#        'primary_pathology_age_at_initial_pathologic_diagnosis',
#        'tissue_collection', 'age', 'years_survived',
#        'icd_o_3_histology_8071/3', 'icd_o_3_histology_8083/3',
#        'icd_o_3_histology_8140/3', 'icd_o_3_histology_8211/3',
#        'icd_o_3_histology_8480/3', 'icd_10_C15.4', 'icd_10_C15.5',
#        'icd_10_C15.9', 'icd_10_C16.0', 'gender_MALE',
#        'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
#        'race_list_WHITE', 'tobacco_smoking_history_2.0',
#        'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
#        'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
#        'stage_Stage II', 'stage_Stage III', 'stage_Stage IV',
#        'primary_pathology_esophageal_tumor_cental_location_Mid',
#        'primary_pathology_esophageal_tumor_cental_location_Proximal',
#        'primary_pathology_histological_type_ESCC',
#        'primary_pathology_neoplasm_histologic_grade_G2',
#        'primary_pathology_neoplasm_histologic_grade_G3',
#        'primary_pathology_neoplasm_histologic_grade_GX',
#        'primary_pathology_lymph_node_metastasis_radiographic_evidence_YES',
#        'primary_pathology_primary_lymph_node_presentation_assessment_YES',
#        'lymph_node_count_N1', 'lymph_node_count_N2', 'lymph_node_count_N3',
#        'primary_pathology_radiation_therapy_YES',
#        'primary_pathology_postoperative_rx_tx_YES'],
#       dtype='object')

# %%
def random_forest(data, target):
    import sklearn
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
    rand_forest = RandomForestClassifier(max_depth=3, min_samples_leaf=5, n_estimators=50)
    rand_forest.fit(X_train,y_train)
    #resultados para el TRAIN
    y_pred_train=rand_forest.predict(X_train)
    probs=rand_forest.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = rand_forest.predict(X_test) 
    probs = rand_forest.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import sklearn
from sklearn.tree import DecisionTreeClassifier # predict proba
from sklearn.tree import DecisionTreeRegressor

# %%
def xgboost(data, target):
    import sklearn
    import xgboost as xgb
    from xgboost import XGBClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import GridSearchCV
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

    xgbmodel = xgb.XGBClassifier()

    params = { #'objective': 'binary:logistic',
             'base_score': [0.5], # prediccion inicial
             'booster': ['gbtree'], # (gbtree, gblinear, dart)
             'colsample_bylevel': [1], # ratio de columnas en cada nivel
             'colsample_bytree': [0.6], # ratio de columnas por tree
             #'device': None,
             'early_stopping_rounds': [10],
             #'enable_categorical': False,
             #'eval_metric': None,
             #'feature_types': None,
             #'gamma': None, # minimo "loss" reduccion para crear un nuevo split. Larger-> conservative
             #'grow_policy': None,
             #'importance_type': None,
             #'interaction_constraints': None,
             'learning_rate': [0.01, 0.05], # aportacion de cada arbol al modelo
             #'max_bin': None,
             #'max_cat_threshold': None,
             #'max_cat_to_onehot': None,
             #'max_delta_step': None,
             'max_depth': [3,4,5,6,7], # maxima profundidad en cada arbol
             #'max_leaves': None,
             'min_child_weight': [10], # minimo numero samples por hoja
             #'missing': [0],
             #'monotone_constraints': None,
             #'multi_strategy': None,
             'n_estimators': [50,100,200] # numero de arboles
             #'n_jobs': [-1], # trabajos en paralelo
             #'num_parallel_tree': None,
             #'random_state': [0], # seed para generar los folds
             #'reg_alpha': None, # L1 regularización
             #'reg_lambda': None, # L2 regularización
             #'sampling_method': None,
             #'scale_pos_weight': [1],
             #'subsample': [0.9] # ratio de muestras por cada arbol 
             #'tree_method': None,
             #'validate_parameters': None,
             #'verbosity': 1
                            }
    
    scoring = ['accuracy', 'roc_auc']
    
    grid_solver = GridSearchCV(estimator = xgbmodel, # model to train
                   param_grid = params,
                   scoring = scoring,
                   cv = 10,
                   n_jobs=-1,
                   refit='accuracy',
                   verbose = 5)
 
    #grid_solver.fit(X_train,y_train)
    model_grid_boost = grid_solver.fit(X_train,y_train, eval_set=[(X_train, y_train), (X_test, y_test)]) 
    #resultados para el TRAIN

    
    
    y_pred_train=grid_solver.predict(X_train)
    probs=grid_solver.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = grid_solver.predict(X_test) 
    probs = grid_solver.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

    #df_test=pd.read_csv("test.csv")
    #y_pred = grid_solver.predict(preprocessing(df_test)) 

    #data_return = {"id":df_test["id"], "Depression":y_pred}
    #df_return = pd.DataFrame(data=data_return)
    #df_return.to_csv('second_attempt_test_v2_increase_folds.csv', index=False)
    #df_return.head()

    return

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)

cols_to_model = ['height', 'weight', 'other_dx', 'alcohol_history_documented', 'reflux_history',
       'barretts_esophagus', 'history_of_esophageal_cancer', 'vital_status', 'age', 
       'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
       'race_list_WHITE', 'tobacco_smoking_history_2.0',
       'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
       'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
       'primary_pathology_esophageal_tumor_cental_location_Mid',
       'primary_pathology_esophageal_tumor_cental_location_Proximal', 'primary_pathology_histological_type_ESCC']

data_model = pd.DataFrame(data=data, columns=cols_to_model)
xgboost(data_model, 'primary_pathology_histological_type_ESCC')
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# [0]	validation_0-logloss:0.65973	validation_1-logloss:0.66005
# [1]	validation_0-logloss:0.63222	validation_1-logloss:0.63343
# [2]	validation_0-logloss:0.60709	validation_1-logloss:0.60947
# [3]	validation_0-logloss:0.58425	validation_1-logloss:0.58676
# [4]	validation_0-logloss:0.56060	validation_1-logloss:0.56311
# [5]	validation_0-logloss:0.53755	validation_1-logloss:0.53978
# [6]	validation_0-logloss:0.52069	validation_1-logloss:0.52375
# [7]	validation_0-logloss:0.50234	validation_1-logloss:0.50462
# [8]	validation_0-logloss:0.48436	validation_1-logloss:0.48713
# [9]	validation_0-logloss:0.46613	validation_1-logloss:0.46854
# [10]	validation_0-logloss:0.44853	validation_1-logloss:0.45027
# [11]	validation_0-logloss:0.43410	validation_1-logloss:0.43612
# [12]	validation_0-logloss:0.41854	validation_1-logloss:0.42110
# [13]	validation_0-logloss:0.40317	validation_1-logloss:0.40548
# [14]	validation_0-logloss:0.38785	validation_1-logloss:0.39015
# [15]	validation_0-logloss:0.37551	validation_1-logloss:0.37771
# [16]	validation_0-logloss:0.36314	validation_1-logloss:0.36575
# [17]	validation_0-logloss:0.35128	validation_1-logloss:0.35410
# [18]	validation_0-logloss:0.34107	validation_1-logloss:0.34378
# [19]	validation_0-logloss:0.33029	validation_1-logloss:0.33354
# [20]	validation_0-logloss:0.32080	validation_1-logloss:0.32371
# [21]	validation_0-logloss:0.31045	validation_1-logloss:0.31294
# [22]	validation_0-logloss:0.30103	validation_1-logloss:0.30357
# [23]	validation_0-logloss:0.29171	validation_1-logloss:0.29463
# [24]	validation_0-logloss:0.28576	validation_1-logloss:0.28893
# [25]	validation_0-logloss:0.27840	validation_1-logloss:0.28130
# [26]	validation_0-logloss:0.27269	validation_1-logloss:0.27555
# [27]	validation_0-logloss:0.26804	validation_1-logloss:0.27089
# [28]	validation_0-logloss:0.26113	validation_1-logloss:0.26399
# [29]	validation_0-logloss:0.25427	validation_1-logloss:0.25739
# [30]	validation_0-logloss:0.24896	validation_1-logloss:0.25250
# [31]	validation_0-logloss:0.24263	validation_1-logloss:0.24627
# [32]	validation_0-logloss:0.23648	validation_1-logloss:0.24021
# [33]	validation_0-logloss:0.23181	validation_1-logloss:0.23560
# [34]	validation_0-logloss:0.22634	validation_1-logloss:0.23009
# [35]	validation_0-logloss:0.22214	validation_1-logloss:0.22610
# [36]	validation_0-logloss:0.21737	validation_1-logloss:0.22154
# [37]	validation_0-logloss:0.21415	validation_1-logloss:0.21812
# [38]	validation_0-logloss:0.21025	validation_1-logloss:0.21438
# [39]	validation_0-logloss:0.20561	validation_1-logloss:0.20942
# [40]	validation_0-logloss:0.20179	validation_1-logloss:0.20525
# [41]	validation_0-logloss:0.19881	validation_1-logloss:0.20264
# [42]	validation_0-logloss:0.19421	validation_1-logloss:0.19814
# [43]	validation_0-logloss:0.19004	validation_1-logloss:0.19379
# [44]	validation_0-logloss:0.18619	validation_1-logloss:0.18950
# [45]	validation_0-logloss:0.18329	validation_1-logloss:0.18671
# [46]	validation_0-logloss:0.18095	validation_1-logloss:0.18449
# [47]	validation_0-logloss:0.17900	validation_1-logloss:0.18253
# [48]	validation_0-logloss:0.17625	validation_1-logloss:0.17994
# [49]	validation_0-logloss:0.17414	validation_1-logloss:0.17803
# [50]	validation_0-logloss:0.17077	validation_1-logloss:0.17446
# [51]	validation_0-logloss:0.16870	validation_1-logloss:0.17263
# [52]	validation_0-logloss:0.16586	validation_1-logloss:0.16978
# [53]	validation_0-logloss:0.16377	validation_1-logloss:0.16782
# [54]	validation_0-logloss:0.16135	validation_1-logloss:0.16535
# [55]	validation_0-logloss:0.15933	validation_1-logloss:0.16340
# [56]	validation_0-logloss:0.15737	validation_1-logloss:0.16144
# [57]	validation_0-logloss:0.15489	validation_1-logloss:0.15892
# [58]	validation_0-logloss:0.15288	validation_1-logloss:0.15691
# [59]	validation_0-logloss:0.15027	validation_1-logloss:0.15383
# [60]	validation_0-logloss:0.14787	validation_1-logloss:0.15099
# [61]	validation_0-logloss:0.14669	validation_1-logloss:0.14980
# [62]	validation_0-logloss:0.14453	validation_1-logloss:0.14751
# [63]	validation_0-logloss:0.14220	validation_1-logloss:0.14537
# [64]	validation_0-logloss:0.14000	validation_1-logloss:0.14297
# [65]	validation_0-logloss:0.13787	validation_1-logloss:0.14046
# [66]	validation_0-logloss:0.13598	validation_1-logloss:0.13839
# [67]	validation_0-logloss:0.13429	validation_1-logloss:0.13647
# [68]	validation_0-logloss:0.13277	validation_1-logloss:0.13481
# [69]	validation_0-logloss:0.13149	validation_1-logloss:0.13344
# [70]	validation_0-logloss:0.12937	validation_1-logloss:0.13118
# [71]	validation_0-logloss:0.12755	validation_1-logloss:0.12942
# [72]	validation_0-logloss:0.12576	validation_1-logloss:0.12765
# [73]	validation_0-logloss:0.12407	validation_1-logloss:0.12583
# [74]	validation_0-logloss:0.12225	validation_1-logloss:0.12405
# [75]	validation_0-logloss:0.12090	validation_1-logloss:0.12270
# [76]	validation_0-logloss:0.11962	validation_1-logloss:0.12147
# [77]	validation_0-logloss:0.11800	validation_1-logloss:0.11991
# [78]	validation_0-logloss:0.11683	validation_1-logloss:0.11858
# [79]	validation_0-logloss:0.11575	validation_1-logloss:0.11753
# [80]	validation_0-logloss:0.11462	validation_1-logloss:0.11654
# [81]	validation_0-logloss:0.11308	validation_1-logloss:0.11486
# [82]	validation_0-logloss:0.11185	validation_1-logloss:0.11373
# [83]	validation_0-logloss:0.11026	validation_1-logloss:0.11215
# [84]	validation_0-logloss:0.10955	validation_1-logloss:0.11155
# [85]	validation_0-logloss:0.10871	validation_1-logloss:0.11082
# [86]	validation_0-logloss:0.10770	validation_1-logloss:0.10971
# [87]	validation_0-logloss:0.10723	validation_1-logloss:0.10936
# [88]	validation_0-logloss:0.10594	validation_1-logloss:0.10815
# [89]	validation_0-logloss:0.10465	validation_1-logloss:0.10679
# [90]	validation_0-logloss:0.10340	validation_1-logloss:0.10548
# [91]	validation_0-logloss:0.10193	validation_1-logloss:0.10392
# [92]	validation_0-logloss:0.10116	validation_1-logloss:0.10324
# [93]	validation_0-logloss:0.09984	validation_1-logloss:0.10195
# [94]	validation_0-logloss:0.09894	validation_1-logloss:0.10094
# [95]	validation_0-logloss:0.09828	validation_1-logloss:0.10058
# [96]	validation_0-logloss:0.09776	validation_1-logloss:0.10022
# [97]	validation_0-logloss:0.09680	validation_1-logloss:0.09925
# [98]	validation_0-logloss:0.09591	validation_1-logloss:0.09813
# [99]	validation_0-logloss:0.09495	validation_1-logloss:0.09728
# [100]	validation_0-logloss:0.09467	validation_1-logloss:0.09698
# [101]	validation_0-logloss:0.09390	validation_1-logloss:0.09631
# [102]	validation_0-logloss:0.09270	validation_1-logloss:0.09525
# [103]	validation_0-logloss:0.09173	validation_1-logloss:0.09438
# [104]	validation_0-logloss:0.09103	validation_1-logloss:0.09388
# [105]	validation_0-logloss:0.09066	validation_1-logloss:0.09353
# [106]	validation_0-logloss:0.09009	validation_1-logloss:0.09316
# [107]	validation_0-logloss:0.08883	validation_1-logloss:0.09163
# [108]	validation_0-logloss:0.08854	validation_1-logloss:0.09135
# [109]	validation_0-logloss:0.08820	validation_1-logloss:0.09107
# [110]	validation_0-logloss:0.08759	validation_1-logloss:0.09057
# [111]	validation_0-logloss:0.08720	validation_1-logloss:0.09033
# [112]	validation_0-logloss:0.08680	validation_1-logloss:0.09021
# [113]	validation_0-logloss:0.08612	validation_1-logloss:0.08962
# [114]	validation_0-logloss:0.08531	validation_1-logloss:0.08874
# [115]	validation_0-logloss:0.08472	validation_1-logloss:0.08797
# [116]	validation_0-logloss:0.08416	validation_1-logloss:0.08755
# [117]	validation_0-logloss:0.08350	validation_1-logloss:0.08686
# [118]	validation_0-logloss:0.08286	validation_1-logloss:0.08631
# [119]	validation_0-logloss:0.08226	validation_1-logloss:0.08573
# [120]	validation_0-logloss:0.08158	validation_1-logloss:0.08507
# [121]	validation_0-logloss:0.08104	validation_1-logloss:0.08462
# [122]	validation_0-logloss:0.08022	validation_1-logloss:0.08378
# [123]	validation_0-logloss:0.07951	validation_1-logloss:0.08327
# [124]	validation_0-logloss:0.07879	validation_1-logloss:0.08263
# [125]	validation_0-logloss:0.07799	validation_1-logloss:0.08183
# [126]	validation_0-logloss:0.07762	validation_1-logloss:0.08144
# [127]	validation_0-logloss:0.07739	validation_1-logloss:0.08131
# [128]	validation_0-logloss:0.07657	validation_1-logloss:0.08056
# [129]	validation_0-logloss:0.07628	validation_1-logloss:0.08025
# [130]	validation_0-logloss:0.07600	validation_1-logloss:0.08010
# [131]	validation_0-logloss:0.07545	validation_1-logloss:0.07968
# [132]	validation_0-logloss:0.07512	validation_1-logloss:0.07942
# [133]	validation_0-logloss:0.07463	validation_1-logloss:0.07879
# [134]	validation_0-logloss:0.07414	validation_1-logloss:0.07829
# [135]	validation_0-logloss:0.07362	validation_1-logloss:0.07772
# [136]	validation_0-logloss:0.07323	validation_1-logloss:0.07746
# [137]	validation_0-logloss:0.07275	validation_1-logloss:0.07705
# [138]	validation_0-logloss:0.07253	validation_1-logloss:0.07692
# [139]	validation_0-logloss:0.07218	validation_1-logloss:0.07652
# [140]	validation_0-logloss:0.07188	validation_1-logloss:0.07621
# [141]	validation_0-logloss:0.07156	validation_1-logloss:0.07606
# [142]	validation_0-logloss:0.07130	validation_1-logloss:0.07584
# [143]	validation_0-logloss:0.07070	validation_1-logloss:0.07542
# [144]	validation_0-logloss:0.07018	validation_1-logloss:0.07476
# [145]	validation_0-logloss:0.06982	validation_1-logloss:0.07436
# [146]	validation_0-logloss:0.06929	validation_1-logloss:0.07392
# [147]	validation_0-logloss:0.06892	validation_1-logloss:0.07357
# [148]	validation_0-logloss:0.06861	validation_1-logloss:0.07324
# [149]	validation_0-logloss:0.06823	validation_1-logloss:0.07273
# [150]	validation_0-logloss:0.06802	validation_1-logloss:0.07254
# [151]	validation_0-logloss:0.06758	validation_1-logloss:0.07213
# [152]	validation_0-logloss:0.06745	validation_1-logloss:0.07208
# [153]	validation_0-logloss:0.06695	validation_1-logloss:0.07159
# [154]	validation_0-logloss:0.06656	validation_1-logloss:0.07131
# [155]	validation_0-logloss:0.06612	validation_1-logloss:0.07106
# [156]	validation_0-logloss:0.06573	validation_1-logloss:0.07082
# [157]	validation_0-logloss:0.06538	validation_1-logloss:0.07045
# [158]	validation_0-logloss:0.06496	validation_1-logloss:0.07001
# [159]	validation_0-logloss:0.06460	validation_1-logloss:0.06964
# [160]	validation_0-logloss:0.06403	validation_1-logloss:0.06917
# [161]	validation_0-logloss:0.06379	validation_1-logloss:0.06909
# [162]	validation_0-logloss:0.06346	validation_1-logloss:0.06891
# [163]	validation_0-logloss:0.06306	validation_1-logloss:0.06851
# [164]	validation_0-logloss:0.06272	validation_1-logloss:0.06821
# [165]	validation_0-logloss:0.06247	validation_1-logloss:0.06803
# [166]	validation_0-logloss:0.06228	validation_1-logloss:0.06802
# [167]	validation_0-logloss:0.06207	validation_1-logloss:0.06783
# [168]	validation_0-logloss:0.06193	validation_1-logloss:0.06765
# [169]	validation_0-logloss:0.06152	validation_1-logloss:0.06730
# [170]	validation_0-logloss:0.06131	validation_1-logloss:0.06716
# [171]	validation_0-logloss:0.06071	validation_1-logloss:0.06649
# [172]	validation_0-logloss:0.06039	validation_1-logloss:0.06635
# [173]	validation_0-logloss:0.06024	validation_1-logloss:0.06620
# [174]	validation_0-logloss:0.05994	validation_1-logloss:0.06591
# [175]	validation_0-logloss:0.05973	validation_1-logloss:0.06581
# [176]	validation_0-logloss:0.05956	validation_1-logloss:0.06573
# [177]	validation_0-logloss:0.05921	validation_1-logloss:0.06535
# [178]	validation_0-logloss:0.05897	validation_1-logloss:0.06507
# [179]	validation_0-logloss:0.05881	validation_1-logloss:0.06498
# [180]	validation_0-logloss:0.05863	validation_1-logloss:0.06490
# [181]	validation_0-logloss:0.05825	validation_1-logloss:0.06451
# [182]	validation_0-logloss:0.05802	validation_1-logloss:0.06433
# [183]	validation_0-logloss:0.05773	validation_1-logloss:0.06400
# [184]	validation_0-logloss:0.05753	validation_1-logloss:0.06384
# [185]	validation_0-logloss:0.05749	validation_1-logloss:0.06381
# [186]	validation_0-logloss:0.05728	validation_1-logloss:0.06367
# [187]	validation_0-logloss:0.05710	validation_1-logloss:0.06357
# [188]	validation_0-logloss:0.05690	validation_1-logloss:0.06334
# [189]	validation_0-logloss:0.05669	validation_1-logloss:0.06319
# [190]	validation_0-logloss:0.05656	validation_1-logloss:0.06311
# [191]	validation_0-logloss:0.05629	validation_1-logloss:0.06274
# [192]	validation_0-logloss:0.05609	validation_1-logloss:0.06262
# [193]	validation_0-logloss:0.05601	validation_1-logloss:0.06254
# [194]	validation_0-logloss:0.05580	validation_1-logloss:0.06225
# [195]	validation_0-logloss:0.05568	validation_1-logloss:0.06214
# [196]	validation_0-logloss:0.05547	validation_1-logloss:0.06197
# [197]	validation_0-logloss:0.05528	validation_1-logloss:0.06182
# [198]	validation_0-logloss:0.05508	validation_1-logloss:0.06155
# [199]	validation_0-logloss:0.05487	validation_1-logloss:0.06132
# Train AUC: 1.0
# Train Accuracy: 0.9952948557089084
# Test AUC:  0.9996281590722884
# Test Accuracy:  0.9874529485570891

# %%
#MODEL NOW WITH LYMPH COUNT NODE OBTAINED FROM RADIOGRAPHY

df = pd.read_csv("Esophageal_Dataset.csv")
data2 = preprocesamiento(df)

cols_to_model2 = ['height', 'weight', 'other_dx', 'alcohol_history_documented', 'reflux_history',
       'barretts_esophagus', 'history_of_esophageal_cancer', 'vital_status', 'age', 
       'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
       'race_list_WHITE', 'tobacco_smoking_history_2.0',
       'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
       'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
       'primary_pathology_esophageal_tumor_cental_location_Mid',
       'primary_pathology_esophageal_tumor_cental_location_Proximal', 'primary_pathology_histological_type_ESCC',
       'lymph_node_count_N1', 'lymph_node_count_N2', 'lymph_node_count_N3']

data_model2 = pd.DataFrame(data=data2, columns=cols_to_model2)
xgboost(data_model2, 'primary_pathology_histological_type_ESCC')
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# [0]	validation_0-logloss:0.66552	validation_1-logloss:0.66689
# [1]	validation_0-logloss:0.63692	validation_1-logloss:0.63774
# [2]	validation_0-logloss:0.60672	validation_1-logloss:0.60761
# [3]	validation_0-logloss:0.58141	validation_1-logloss:0.58413
# [4]	validation_0-logloss:0.55870	validation_1-logloss:0.56198
# [5]	validation_0-logloss:0.53988	validation_1-logloss:0.54369
# [6]	validation_0-logloss:0.51878	validation_1-logloss:0.52151
# [7]	validation_0-logloss:0.49845	validation_1-logloss:0.50259
# [8]	validation_0-logloss:0.47860	validation_1-logloss:0.48139
# [9]	validation_0-logloss:0.46138	validation_1-logloss:0.46493
# [10]	validation_0-logloss:0.44147	validation_1-logloss:0.44558
# [11]	validation_0-logloss:0.42530	validation_1-logloss:0.42941
# [12]	validation_0-logloss:0.40858	validation_1-logloss:0.41314
# [13]	validation_0-logloss:0.39561	validation_1-logloss:0.39955
# [14]	validation_0-logloss:0.38538	validation_1-logloss:0.38939
# [15]	validation_0-logloss:0.37375	validation_1-logloss:0.37836
# [16]	validation_0-logloss:0.36178	validation_1-logloss:0.36571
# [17]	validation_0-logloss:0.35068	validation_1-logloss:0.35384
# [18]	validation_0-logloss:0.34292	validation_1-logloss:0.34613
# [19]	validation_0-logloss:0.33049	validation_1-logloss:0.33399
# [20]	validation_0-logloss:0.31895	validation_1-logloss:0.32276
# [21]	validation_0-logloss:0.30859	validation_1-logloss:0.31229
# [22]	validation_0-logloss:0.29845	validation_1-logloss:0.30209
# [23]	validation_0-logloss:0.29234	validation_1-logloss:0.29595
# [24]	validation_0-logloss:0.28606	validation_1-logloss:0.29005
# [25]	validation_0-logloss:0.27810	validation_1-logloss:0.28220
# [26]	validation_0-logloss:0.27091	validation_1-logloss:0.27517
# [27]	validation_0-logloss:0.26593	validation_1-logloss:0.27042
# [28]	validation_0-logloss:0.25817	validation_1-logloss:0.26270
# [29]	validation_0-logloss:0.25222	validation_1-logloss:0.25636
# [30]	validation_0-logloss:0.24575	validation_1-logloss:0.24943
# [31]	validation_0-logloss:0.23887	validation_1-logloss:0.24277
# [32]	validation_0-logloss:0.23249	validation_1-logloss:0.23605
# [33]	validation_0-logloss:0.22601	validation_1-logloss:0.23023
# [34]	validation_0-logloss:0.21988	validation_1-logloss:0.22367
# [35]	validation_0-logloss:0.21476	validation_1-logloss:0.21852
# [36]	validation_0-logloss:0.20978	validation_1-logloss:0.21364
# [37]	validation_0-logloss:0.20550	validation_1-logloss:0.20962
# [38]	validation_0-logloss:0.20205	validation_1-logloss:0.20645
# [39]	validation_0-logloss:0.19828	validation_1-logloss:0.20297
# [40]	validation_0-logloss:0.19383	validation_1-logloss:0.19818
# [41]	validation_0-logloss:0.19060	validation_1-logloss:0.19462
# [42]	validation_0-logloss:0.18744	validation_1-logloss:0.19198
# [43]	validation_0-logloss:0.18399	validation_1-logloss:0.18877
# [44]	validation_0-logloss:0.17949	validation_1-logloss:0.18381
# [45]	validation_0-logloss:0.17553	validation_1-logloss:0.17965
# [46]	validation_0-logloss:0.17309	validation_1-logloss:0.17767
# [47]	validation_0-logloss:0.17075	validation_1-logloss:0.17526
# [48]	validation_0-logloss:0.16810	validation_1-logloss:0.17240
# [49]	validation_0-logloss:0.16554	validation_1-logloss:0.16983
# [50]	validation_0-logloss:0.16274	validation_1-logloss:0.16705
# [51]	validation_0-logloss:0.15935	validation_1-logloss:0.16332
# [52]	validation_0-logloss:0.15669	validation_1-logloss:0.16063
# [53]	validation_0-logloss:0.15399	validation_1-logloss:0.15793
# [54]	validation_0-logloss:0.15168	validation_1-logloss:0.15573
# [55]	validation_0-logloss:0.14993	validation_1-logloss:0.15418
# [56]	validation_0-logloss:0.14837	validation_1-logloss:0.15291
# [57]	validation_0-logloss:0.14560	validation_1-logloss:0.15045
# [58]	validation_0-logloss:0.14381	validation_1-logloss:0.14863
# [59]	validation_0-logloss:0.14213	validation_1-logloss:0.14688
# [60]	validation_0-logloss:0.14005	validation_1-logloss:0.14466
# [61]	validation_0-logloss:0.13862	validation_1-logloss:0.14312
# [62]	validation_0-logloss:0.13719	validation_1-logloss:0.14161
# [63]	validation_0-logloss:0.13484	validation_1-logloss:0.13928
# [64]	validation_0-logloss:0.13264	validation_1-logloss:0.13709
# [65]	validation_0-logloss:0.13103	validation_1-logloss:0.13570
# [66]	validation_0-logloss:0.12957	validation_1-logloss:0.13446
# [67]	validation_0-logloss:0.12824	validation_1-logloss:0.13315
# [68]	validation_0-logloss:0.12654	validation_1-logloss:0.13137
# [69]	validation_0-logloss:0.12513	validation_1-logloss:0.13008
# [70]	validation_0-logloss:0.12422	validation_1-logloss:0.12921
# [71]	validation_0-logloss:0.12190	validation_1-logloss:0.12659
# [72]	validation_0-logloss:0.12062	validation_1-logloss:0.12506
# [73]	validation_0-logloss:0.11897	validation_1-logloss:0.12345
# [74]	validation_0-logloss:0.11675	validation_1-logloss:0.12117
# [75]	validation_0-logloss:0.11490	validation_1-logloss:0.11938
# [76]	validation_0-logloss:0.11319	validation_1-logloss:0.11784
# [77]	validation_0-logloss:0.11128	validation_1-logloss:0.11591
# [78]	validation_0-logloss:0.10928	validation_1-logloss:0.11385
# [79]	validation_0-logloss:0.10755	validation_1-logloss:0.11192
# [80]	validation_0-logloss:0.10660	validation_1-logloss:0.11119
# [81]	validation_0-logloss:0.10543	validation_1-logloss:0.11030
# [82]	validation_0-logloss:0.10430	validation_1-logloss:0.10915
# [83]	validation_0-logloss:0.10308	validation_1-logloss:0.10804
# [84]	validation_0-logloss:0.10209	validation_1-logloss:0.10714
# [85]	validation_0-logloss:0.10096	validation_1-logloss:0.10628
# [86]	validation_0-logloss:0.09939	validation_1-logloss:0.10453
# [87]	validation_0-logloss:0.09825	validation_1-logloss:0.10335
# [88]	validation_0-logloss:0.09769	validation_1-logloss:0.10261
# [89]	validation_0-logloss:0.09657	validation_1-logloss:0.10141
# [90]	validation_0-logloss:0.09555	validation_1-logloss:0.10034
# [91]	validation_0-logloss:0.09481	validation_1-logloss:0.09962
# [92]	validation_0-logloss:0.09368	validation_1-logloss:0.09862
# [93]	validation_0-logloss:0.09274	validation_1-logloss:0.09769
# [94]	validation_0-logloss:0.09187	validation_1-logloss:0.09684
# [95]	validation_0-logloss:0.09130	validation_1-logloss:0.09626
# [96]	validation_0-logloss:0.09053	validation_1-logloss:0.09552
# [97]	validation_0-logloss:0.08987	validation_1-logloss:0.09486
# [98]	validation_0-logloss:0.08889	validation_1-logloss:0.09388
# [99]	validation_0-logloss:0.08817	validation_1-logloss:0.09302
# [100]	validation_0-logloss:0.08700	validation_1-logloss:0.09212
# [101]	validation_0-logloss:0.08618	validation_1-logloss:0.09113
# [102]	validation_0-logloss:0.08550	validation_1-logloss:0.09047
# [103]	validation_0-logloss:0.08426	validation_1-logloss:0.08923
# [104]	validation_0-logloss:0.08374	validation_1-logloss:0.08860
# [105]	validation_0-logloss:0.08323	validation_1-logloss:0.08818
# [106]	validation_0-logloss:0.08274	validation_1-logloss:0.08765
# [107]	validation_0-logloss:0.08224	validation_1-logloss:0.08716
# [108]	validation_0-logloss:0.08129	validation_1-logloss:0.08625
# [109]	validation_0-logloss:0.08037	validation_1-logloss:0.08514
# [110]	validation_0-logloss:0.07986	validation_1-logloss:0.08476
# [111]	validation_0-logloss:0.07909	validation_1-logloss:0.08411
# [112]	validation_0-logloss:0.07848	validation_1-logloss:0.08348
# [113]	validation_0-logloss:0.07758	validation_1-logloss:0.08270
# [114]	validation_0-logloss:0.07719	validation_1-logloss:0.08226
# [115]	validation_0-logloss:0.07658	validation_1-logloss:0.08160
# [116]	validation_0-logloss:0.07608	validation_1-logloss:0.08103
# [117]	validation_0-logloss:0.07574	validation_1-logloss:0.08074
# [118]	validation_0-logloss:0.07523	validation_1-logloss:0.07990
# [119]	validation_0-logloss:0.07474	validation_1-logloss:0.07934
# [120]	validation_0-logloss:0.07404	validation_1-logloss:0.07860
# [121]	validation_0-logloss:0.07381	validation_1-logloss:0.07827
# [122]	validation_0-logloss:0.07323	validation_1-logloss:0.07757
# [123]	validation_0-logloss:0.07269	validation_1-logloss:0.07684
# [124]	validation_0-logloss:0.07194	validation_1-logloss:0.07606
# [125]	validation_0-logloss:0.07145	validation_1-logloss:0.07544
# [126]	validation_0-logloss:0.07086	validation_1-logloss:0.07488
# [127]	validation_0-logloss:0.07042	validation_1-logloss:0.07434
# [128]	validation_0-logloss:0.07006	validation_1-logloss:0.07381
# [129]	validation_0-logloss:0.06936	validation_1-logloss:0.07325
# [130]	validation_0-logloss:0.06885	validation_1-logloss:0.07274
# [131]	validation_0-logloss:0.06818	validation_1-logloss:0.07220
# [132]	validation_0-logloss:0.06769	validation_1-logloss:0.07178
# [133]	validation_0-logloss:0.06730	validation_1-logloss:0.07138
# [134]	validation_0-logloss:0.06678	validation_1-logloss:0.07091
# [135]	validation_0-logloss:0.06632	validation_1-logloss:0.07047
# [136]	validation_0-logloss:0.06599	validation_1-logloss:0.07009
# [137]	validation_0-logloss:0.06537	validation_1-logloss:0.06963
# [138]	validation_0-logloss:0.06502	validation_1-logloss:0.06929
# [139]	validation_0-logloss:0.06469	validation_1-logloss:0.06877
# [140]	validation_0-logloss:0.06433	validation_1-logloss:0.06863
# [141]	validation_0-logloss:0.06390	validation_1-logloss:0.06815
# [142]	validation_0-logloss:0.06334	validation_1-logloss:0.06751
# [143]	validation_0-logloss:0.06304	validation_1-logloss:0.06700
# [144]	validation_0-logloss:0.06253	validation_1-logloss:0.06652
# [145]	validation_0-logloss:0.06222	validation_1-logloss:0.06625
# [146]	validation_0-logloss:0.06191	validation_1-logloss:0.06585
# [147]	validation_0-logloss:0.06156	validation_1-logloss:0.06579
# [148]	validation_0-logloss:0.06115	validation_1-logloss:0.06535
# [149]	validation_0-logloss:0.06073	validation_1-logloss:0.06502
# [150]	validation_0-logloss:0.06040	validation_1-logloss:0.06451
# [151]	validation_0-logloss:0.05999	validation_1-logloss:0.06414
# [152]	validation_0-logloss:0.05962	validation_1-logloss:0.06373
# [153]	validation_0-logloss:0.05917	validation_1-logloss:0.06321
# [154]	validation_0-logloss:0.05898	validation_1-logloss:0.06307
# [155]	validation_0-logloss:0.05869	validation_1-logloss:0.06268
# [156]	validation_0-logloss:0.05832	validation_1-logloss:0.06237
# [157]	validation_0-logloss:0.05793	validation_1-logloss:0.06200
# [158]	validation_0-logloss:0.05750	validation_1-logloss:0.06151
# [159]	validation_0-logloss:0.05711	validation_1-logloss:0.06104
# [160]	validation_0-logloss:0.05676	validation_1-logloss:0.06072
# [161]	validation_0-logloss:0.05651	validation_1-logloss:0.06036
# [162]	validation_0-logloss:0.05610	validation_1-logloss:0.06002
# [163]	validation_0-logloss:0.05595	validation_1-logloss:0.05982
# [164]	validation_0-logloss:0.05563	validation_1-logloss:0.05951
# [165]	validation_0-logloss:0.05543	validation_1-logloss:0.05910
# [166]	validation_0-logloss:0.05531	validation_1-logloss:0.05899
# [167]	validation_0-logloss:0.05484	validation_1-logloss:0.05851
# [168]	validation_0-logloss:0.05451	validation_1-logloss:0.05816
# [169]	validation_0-logloss:0.05430	validation_1-logloss:0.05786
# [170]	validation_0-logloss:0.05403	validation_1-logloss:0.05756
# [171]	validation_0-logloss:0.05376	validation_1-logloss:0.05737
# [172]	validation_0-logloss:0.05331	validation_1-logloss:0.05673
# [173]	validation_0-logloss:0.05319	validation_1-logloss:0.05656
# [174]	validation_0-logloss:0.05299	validation_1-logloss:0.05648
# [175]	validation_0-logloss:0.05276	validation_1-logloss:0.05627
# [176]	validation_0-logloss:0.05254	validation_1-logloss:0.05627
# [177]	validation_0-logloss:0.05243	validation_1-logloss:0.05618
# [178]	validation_0-logloss:0.05224	validation_1-logloss:0.05611
# [179]	validation_0-logloss:0.05199	validation_1-logloss:0.05589
# [180]	validation_0-logloss:0.05173	validation_1-logloss:0.05559
# [181]	validation_0-logloss:0.05156	validation_1-logloss:0.05547
# [182]	validation_0-logloss:0.05134	validation_1-logloss:0.05526
# [183]	validation_0-logloss:0.05105	validation_1-logloss:0.05499
# [184]	validation_0-logloss:0.05082	validation_1-logloss:0.05471
# [185]	validation_0-logloss:0.05061	validation_1-logloss:0.05440
# [186]	validation_0-logloss:0.05045	validation_1-logloss:0.05425
# [187]	validation_0-logloss:0.05021	validation_1-logloss:0.05421
# [188]	validation_0-logloss:0.04993	validation_1-logloss:0.05401
# [189]	validation_0-logloss:0.04978	validation_1-logloss:0.05391
# [190]	validation_0-logloss:0.04963	validation_1-logloss:0.05393
# [191]	validation_0-logloss:0.04949	validation_1-logloss:0.05375
# [192]	validation_0-logloss:0.04935	validation_1-logloss:0.05358
# [193]	validation_0-logloss:0.04906	validation_1-logloss:0.05339
# [194]	validation_0-logloss:0.04882	validation_1-logloss:0.05311
# [195]	validation_0-logloss:0.04851	validation_1-logloss:0.05257
# [196]	validation_0-logloss:0.04823	validation_1-logloss:0.05248
# [197]	validation_0-logloss:0.04814	validation_1-logloss:0.05230
# [198]	validation_0-logloss:0.04804	validation_1-logloss:0.05220
# [199]	validation_0-logloss:0.04784	validation_1-logloss:0.05191
# Train AUC: 1.0
# Train Accuracy: 0.9981179422835633
# Test AUC:  0.9998677132022225
# Test Accuracy:  0.9937264742785445
