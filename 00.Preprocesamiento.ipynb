# %%
def preprocesamiento(df):

    import pandas as pd
    import numpy as np
    
    import warnings
    warnings.filterwarnings('ignore')
    
    
#    df = pd.read_csv("Esophageal_Dataset.csv")
    cols_to_drop = ['Unnamed: 0',
                    'patient_barcode',
                    'tissue_source_site',
                    'patient_id',
                    'bcr_patient_uuid',
                    'informed_consent_verified',
                    'icd_o_3_site',
                    'country_of_birth',
                    'country_of_procurement', 
                    'state_province_of_procurement',
                    'city_of_procurement',
                    'history_of_neoadjuvant_treatment', 
                    'age_began_smoking_in_years',
                    'stopped_smoking_year',
                    'number_pack_years_smoked',
                    'frequency_of_alcohol_consumption',
                    'amount_of_alcohol_consumption_per_day',
                    'antireflux_treatment_types',
                    'h_pylori_infection',
                    'goblet_cells_present',
                    'number_of_relatives_diagnosed',
                    'day_of_form_completion',
                    'month_of_form_completion',
                    'year_of_form_completion',
                    'project',
                    'stage_event_system_version',
                    'stage_event_psa',
                    'stage_event_gleason_grading',
                    'stage_event_ann_arbor',
                    'stage_event_serum_markers',
                    'stage_event_igcccg_stage',
                    'stage_event_masaoka_stage',
                    'primary_pathology_tumor_tissue_site',
                    'primary_pathology_esophageal_tumor_involvement_sites',
                    'primary_pathology_columnar_metaplasia_present',
                    'primary_pathology_columnar_mucosa_goblet_cell_present',
                    'primary_pathology_columnar_mucosa_dysplasia',
                    'primary_pathology_days_to_initial_pathologic_diagnosis',
                    'primary_pathology_year_of_initial_pathologic_diagnosis',
                    'primary_pathology_init_pathology_dx_method_other',
                    'primary_pathology_number_of_lymphnodes_positive_by_he',
                    'primary_pathology_number_of_lymphnodes_positive_by_ihc',
                    'primary_pathology_planned_surgery_status',
                    'primary_pathology_treatment_prior_to_surgery',
                    'primary_pathology_karnofsky_performance_score',
                    'primary_pathology_eastern_cancer_oncology_group',
                    'days_to_last_followup',
                    'days_to_death']
    
    df.drop(columns=cols_to_drop, inplace=True)
    
#se harán dummies para los indicadores histológicos icd_o_3 & icd_10
    
#rellenamos nans de prospective collection con método bfill, y usamos prospective collection para crear columna tissue collection:
#con valor 1 para prospective (prospective=YES) y 0 para retrospective (prospective=NO)
#y eliminaremos las columnas prospective y retrospective
    df.tissue_prospective_collection_indicator = df.tissue_prospective_collection_indicator.fillna(method='bfill')
    df['tissue_collection'] = df['tissue_prospective_collection_indicator']
    
    df.loc[(df['tissue_prospective_collection_indicator'] == 'YES'), 'tissue_collection'] = 1
    df.loc[(df['tissue_prospective_collection_indicator'] == 'NO'), 'tissue_collection'] = 0
  
    
#se crea una columna edad que contendrá la edad en años (módulo de la division por 365 de la columna days_to_birth)
#y se crea una columna de años sobrevividos con la diferencia entre edad y edad de diagnóstico
#(para casos en los que la diferencia es -1 por ajuste del modulo, se fuerza valor 0)
#se escala usando minmax scaling
#por último se eliminará la columna original days_to_birth
    df['age'] = df.days_to_birth // -365
    df['years_survived']=df.age - df.primary_pathology_age_at_initial_pathologic_diagnosis
    df.loc[df.years_survived < 0, 'years_survived'] = 0
    df.age = (df.age - df.age.min()) / (df.age.max() - df.age.min())
    
#se crean dummies para sexo
#se eliminará la columna original después de haber calculado las medias de altura y peso por sexo
#para rellenar los NaN de esas columnas 
#se escalan min_max la altura y el peso    
    df.loc[(df.height.isna()) & (df.gender == 'FEMALE'), 'height'] = df.loc[(df.gender == 'FEMALE'), 'height'].mean()
    df.loc[(df.height.isna()) & (df.gender == 'MALE'), 'height'] = df.loc[(df.gender == 'MALE'), 'height'].mean()
    df.height = (df.height - df.height.min()) / (df.height.max() - df.height.min())
    
    df.loc[(df.weight.isna()) & (df.gender == 'FEMALE'), 'weight'] = df.loc[(df.gender == 'FEMALE'), 'weight'].mean()
    df.loc[(df.weight.isna()) & (df.gender == 'MALE'), 'weight'] = df.loc[(df.gender == 'MALE'), 'weight'].mean()
    df.weight = (df.weight - df.weight.min()) / (df.weight.max() - df.weight.min())

    
#Los NaN de la columna race_list se rellenará de la siguiente forma:
#en los casos en los que sea NAN y la columna 'ethnicity' sea HISPANIC, se rellenará como HISPANIC… 
#los demás NAN se rellenárán usando el método backfill.
#se crean dummies para la columna y se eliminará la columna 'ethnicity'
    df.loc[(df.race_list.isna()) & (df.ethnicity == 'HISPANIC OR LATINO'), 'race_list'] = 'HISPANIC'
    df.race_list = df.race_list.fillna(method='bfill')
    
#valores YES/NO de other_dx pasan a ser 1/0
    df.loc[df.other_dx == 'Yes', 'other_dx'] = 1
    df.loc[df.other_dx == 'No', 'other_dx'] = 0
    
#valores TUMOR FREE/WITH TUMOR de person_neoplasm_cancer_status pasan a ser 0/1
#y NaN se cambian con método ffill
    df.loc[df.person_neoplasm_cancer_status == 'TUMOR FREE', 'person_neoplasm_cancer_status'] = 0
    df.loc[df.person_neoplasm_cancer_status == 'WITH TUMOR', 'person_neoplasm_cancer_status'] = 1
    df.person_neoplasm_cancer_status = df.person_neoplasm_cancer_status.fillna(method='ffill')
    
#valores Dead/Alive de vital_status pasan a ser 0/1
    df.loc[df.vital_status == 'Dead', 'vital_status'] = 0
    df.loc[df.vital_status == 'Alive', 'vital_status'] = 1
    
#historial de fumador: sustituimos NaN con método ffill y hacemos dummies para los valores 1,2,3,4. 
    df.tobacco_smoking_history = df.tobacco_smoking_history.fillna(method='ffill')
   
    
#historial de alcohol: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.loc[df.alcohol_history_documented == 'NO', 'alcohol_history_documented'] = 0
    df.loc[df.alcohol_history_documented == 'YES', 'alcohol_history_documented'] = 1
    df.alcohol_history_documented = df.alcohol_history_documented.fillna(method='bfill')
    
#historial de reflujo: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.reflux_history = df.reflux_history.fillna(method='ffill')
    df.loc[(df.reflux_history == 'NO') | (df.reflux_history.isna()), 'reflux_history'] = 0
    df.loc[df.reflux_history == 'YES', 'reflux_history'] = 1
    
    
#diagnóstico inicial: pasar Symptomatic/Screening/Surveillance a 1/2/3 
#rellenar NaN con frontfill y get_dummies
    df.initial_diagnosis_by = df.initial_diagnosis_by.fillna(method='ffill')

    
#barretts_esophagus: Yes/No a 1/0 y rellenar NaN con frontfill
    df.loc[df.barretts_esophagus  == 'No', 'barretts_esophagus'] = 0
    df.loc[df.barretts_esophagus  == 'Yes-USA', 'barretts_esophagus'] = 1
    df.loc[df.barretts_esophagus  == 'Yes-UK', 'barretts_esophagus'] = 1 
    df.barretts_esophagus = df.barretts_esophagus.fillna(method='ffill')
    
#historial de cáncer de esófago: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.history_of_esophageal_cancer = df.history_of_esophageal_cancer.fillna(method='ffill')
    df.loc[(df.history_of_esophageal_cancer == 'NO') | (df.history_of_esophageal_cancer.isna()), 'history_of_esophageal_cancer'] = 0
    df.loc[df.history_of_esophageal_cancer == 'YES', 'history_of_esophageal_cancer'] = 1
    
    
#nuevos eventos tumorales: pasar Yes/No a 1/0
    df.loc[df.has_new_tumor_events_information == 'NO', 'has_new_tumor_events_information'] = 0
    df.loc[df.has_new_tumor_events_information == 'YES', 'has_new_tumor_events_information'] = 1
    
#le hacen seguimientos: pasar Yes/No a 1/0
    df.loc[df.has_follow_ups_information == 'NO', 'has_follow_ups_information'] = 0
    df.loc[df.has_follow_ups_information == 'YES', 'has_follow_ups_information'] = 1
    
#pautan medicación tumorales: pasar Yes/No a 1/0
    df.loc[df.has_drugs_information == 'NO', 'has_drugs_information'] = 0
    df.loc[df.has_drugs_information == 'YES', 'has_drugs_information'] = 1
    
#pautan radiación: pasar Yes/No a 1/0
    df.loc[df.has_radiations_information == 'NO', 'has_radiations_information'] = 0
    df.loc[df.has_radiations_information == 'YES', 'has_radiations_information'] = 1
    
#Combinamos las columnas stage_event_clinical_stage y stage_event_pathologic_stage en una única columna stage
#tomando como referencia el valor de stage_event_pathologic_stage, y cuando este es NaN
#tomando el valor de stage_event_clinical_stage.
    df['stage'] = np.where(~df['stage_event_pathologic_stage'].isna(), 
                           df['stage_event_pathologic_stage'], 
                           df['stage_event_clinical_stage'])
    
#Para aquellos casos en los que no está informado ni el estadio clínico ni patológico
#utilizaremos el valor T y N de la columna stage_event_tnm_categories para establecer el Stage
#Para ello, creamos las siguientes máscaras booleanas según la clasificación de stages
#para cáncer de esófago a partir de valores TNM encontrado online:

    #Stage I: T1, N0, M0
    #Stage II: T2, N0, M0 or T3, N0, M0 ...incluyo aquí los T2NX por ser Stage II mayoría
    #Stage III: T1-3, N1, M0 or T4, N0-1, M0
    #Stage IV: T1-4, N2-3, M0 or T1-4, N0-3, M1
    
    bool_mask_1 = ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                   (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False)))
    
    bool_mask_2 = (((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('X').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))))
    
    bool_mask_3 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))))
    
    bool_mask_4 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))))
    
    #Aplicamos la máscara
    mask_na = df['stage'].isna()
    df.loc[mask_na, 'stage'] = np.select([bool_mask_1[df['stage'].isna()], 
                                          bool_mask_2[df['stage'].isna()], 
                                          bool_mask_3[df['stage'].isna()],
                                          bool_mask_4[df['stage'].isna()]], 
                                         ['Stage I', 'Stage II', 'Stage III', 'Stage IV'], 
                                            default=np.nan)
    
#Simplificamos los valores de Stage a Stage I, Stage II, Stage III y Stage IV eliminando sufijos, previo a pasar a dummies
    df['stage'] = df['stage'].str.removesuffix('A').str.removesuffix('B').str.removesuffix('C')
      
#eliminaremos las columnas de clinical_stage, pathologic_stage y tnm_categories
    
    
#rellenamos los pocos valores NaN de primary_pathology_esophageal_tumor_cental_location 
#con Distal por ser el valor más frecuente y hacemos get_dummies para los tres valores: Distal, Mid, Proximal
    df.primary_pathology_esophageal_tumor_cental_location = df.primary_pathology_esophageal_tumor_cental_location.fillna('Distal')

    
#primary_pathology_histological_type: renombramos y hacemos get_dummies antes de eliminar columna original
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Adenocarcinoma, NOS'), 
            'primary_pathology_histological_type'] = 'Adeno-NOS'
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Squamous Cell Carcinoma'), 
            'primary_pathology_histological_type'] = 'ESCC'
   
    
#primary_pathology_neoplasm_histologic_grade: get_dummies

    
#primary_pathology_age_at_initial_pathologic_diagnosis: escalar min_max
    df.primary_pathology_age_at_initial_pathologic_diagnosis = (df.primary_pathology_age_at_initial_pathologic_diagnosis - df.primary_pathology_age_at_initial_pathologic_diagnosis.min()) / (df.primary_pathology_age_at_initial_pathologic_diagnosis.max() - df.primary_pathology_age_at_initial_pathologic_diagnosis.min())
    
#primary_pathology_initial_pathologic_diagnosis_method:
#valores: biopsy/surgery/other
#la columna primary_pathology_init_pathology_dx_method_other (elimiada) informa de los posibles 'other':
#que en la gran mayoría de casos son surgical resection… por tanto, dejaremos solo dos alores biopsy/resection
#y en el último incluiremos los other y NaN de la columna, para después crear dummies
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] == 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Biopsy'
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] != 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Resection'
    df.primary_pathology_initial_pathologic_diagnosis_method = df.primary_pathology_initial_pathologic_diagnosis_method.fillna('Resection')

    
#primary_pathology_lymph_node_metastasis_radiographic_evidence: 
#rellenar NaN en función de si en 'stage' es StageIV (YES) o no (NO), y hacer dummies
#borrar esta fila y stage
    
    bool_mask_stage = df.stage.str.match('Stage IV').fillna(False)
    bool_mask_no_stage = ((df.stage.str.match('Stage III').fillna(False)) |
                          (df.stage.str.match('Stage II').fillna(False)) |
                          (df.stage.str.match('Stage I').fillna(False)))
    mask_stage = df.primary_pathology_lymph_node_metastasis_radiographic_evidence.isna()
    df.loc[mask_stage, 'primary_pathology_lymph_node_metastasis_radiographic_evidence'] = np.select([bool_mask_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()], 
                                                                                                     bool_mask_no_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()]], 
                                                                                                    ['YES', 'NO'],
                                                                                                    default=np.nan)
        
#primary_pathology_primary_lymph_node_presentation_assessment. Rellenar NaN con method bfill
    df.primary_pathology_primary_lymph_node_presentation_assessment = df.primary_pathology_primary_lymph_node_presentation_assessment.fillna(method='bfill')

    
    
#primary_pathology_lymph_node_examined_count:
#se rellenarán los NaN como 0 si primary_lymph_node_presentation es 'NO' o con la media de recuento si es 'YES' (14.0)
#después se dividirán en 4 grupos según la distribución de cuartiles del describe, excluyendo 0 que tiene su propio grupo: 
#0 (no count), 1-9 (medium-low), 9-16 (average), más de 20 (above average)
    bool_mask_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('YES').fillna(False)
    bool_mask_no_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('NO').fillna(False)
    
    mask_lymph_count = df.primary_pathology_lymph_node_examined_count.isna()
    mean_count = round(df.primary_pathology_lymph_node_examined_count.mean(),0)
    df.loc[mask_lymph_count, 'primary_pathology_lymph_node_examined_count'] = np.select([bool_mask_lymph[df['primary_pathology_lymph_node_examined_count'].isna()], 
                                                                                                     bool_mask_no_lymph[df['primary_pathology_lymph_node_examined_count'].isna()]], 
                                                                                                    [mean_count, 0.0],
                                                                                                    default=np.nan)
    df.loc[(df['primary_pathology_lymph_node_examined_count'] == 0.0), 'lymph_node_count'] = 'N0'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 1.0) & (df['primary_pathology_lymph_node_examined_count'] <= 2.0), 'lymph_node_count'] = 'N1'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 3.0) & (df['primary_pathology_lymph_node_examined_count'] <= 6.0), 'lymph_node_count'] = 'N2'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 7.0), 'lymph_node_count'] = 'N3'
    
#primary_pathology_residual_tumor: rellenamos NaN con forward fill, y demás valores pasan a dos grupos: No (R0) & Yes (R1/R2/RX), then get_dummies
    
    df.primary_pathology_residual_tumor = df.primary_pathology_residual_tumor.fillna(method='ffill')
    df.loc[(df['primary_pathology_residual_tumor'] == 'R0'),'primary_pathology_residual_tumor'] = 'NO'
    df.loc[(df['primary_pathology_residual_tumor'] != 'R0'),'primary_pathology_residual_tumor'] = 'YES'

    
    #primary_pathology_radiation_therapy
    df.primary_pathology_radiation_therapy = df.primary_pathology_radiation_therapy.fillna(method='ffill')

    
    #primary_pathology_postoperative_rx_tx 
    df.primary_pathology_postoperative_rx_tx = df.primary_pathology_postoperative_rx_tx.fillna(method='bfill')
    
    cols_to_dummies = ['icd_o_3_histology', 'icd_10', 'gender', 'race_list', 'tobacco_smoking_history', 'initial_diagnosis_by', 'stage', 
                         'primary_pathology_esophageal_tumor_cental_location', 'primary_pathology_histological_type', 'primary_pathology_neoplasm_histologic_grade',
                         'primary_pathology_initial_pathologic_diagnosis_method', 'primary_pathology_lymph_node_metastasis_radiographic_evidence',
                         'primary_pathology_primary_lymph_node_presentation_assessment', 'lymph_node_count', 'primary_pathology_residual_tumor',
                         'primary_pathology_radiation_therapy', 'primary_pathology_postoperative_rx_tx']
    
#    cols_to_concat = ['tissue_collection','age','years_survived', 'height', 'weight', 'other_dx', 'person_neoplasm_cancer_status', 'vital_status', 'alcohol_history_documented',
#                     'reflux_history', 'barretts_esophagus', 'history_of_esophageal_cancer','has_new_tumor_events_information', 'has_follow_ups_information', 'has_drugs_information',
#                     'has_radiations_information', 'primary_pathology_age_at_initial_pathologic_diagnosis']
    
    
    df_final = pd.get_dummies(data=df, columns=cols_to_dummies, drop_first=True)
    df_final.drop(columns=['tissue_prospective_collection_indicator', 'tissue_retrospective_collection_indicator', 'days_to_birth', 
                           'ethnicity', 'stage_event_clinical_stage', 'stage_event_pathologic_stage', 'stage_event_tnm_categories', 
                           'primary_pathology_lymph_node_examined_count'], inplace=True)
    df_final=df_final.astype("float")
    df_final.to_csv('Esophageal_Dataset_clean.csv')
    return(df_final)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
#df.columns

# %%
data.isnull().sum()
# Out:
# height                                                               0
# weight                                                               0
# other_dx                                                             0
# person_neoplasm_cancer_status                                        0
# vital_status                                                         0
# alcohol_history_documented                                           0
# reflux_history                                                       0
# barretts_esophagus                                                   0
# history_of_esophageal_cancer                                         0
# has_new_tumor_events_information                                     0
# has_follow_ups_information                                           0
# has_drugs_information                                                0
# has_radiations_information                                           0
# primary_pathology_age_at_initial_pathologic_diagnosis                0
# tissue_collection                                                    0
# age                                                                  0
# years_survived                                                       0
# icd_o_3_histology_8071/3                                             0
# icd_o_3_histology_8083/3                                             0
# icd_o_3_histology_8140/3                                             0
# icd_o_3_histology_8211/3                                             0
# icd_o_3_histology_8480/3                                             0
# icd_10_C15.4                                                         0
# icd_10_C15.5                                                         0
# icd_10_C15.9                                                         0
# icd_10_C16.0                                                         0
# gender_MALE                                                          0
# race_list_BLACK OR AFRICAN AMERICAN                                  0
# race_list_HISPANIC                                                   0
# race_list_WHITE                                                      0
# tobacco_smoking_history_2.0                                          0
# tobacco_smoking_history_3.0                                          0
# tobacco_smoking_history_4.0                                          0
# initial_diagnosis_by_Surveillance                                    0
# initial_diagnosis_by_Symptomatic                                     0
# stage_Stage II                                                       0
# stage_Stage III                                                      0
# stage_Stage IV                                                       0
# primary_pathology_esophageal_tumor_cental_location_Mid               0
# primary_pathology_esophageal_tumor_cental_location_Proximal          0
# primary_pathology_histological_type_ESCC                             0
# primary_pathology_neoplasm_histologic_grade_G2                       0
# primary_pathology_neoplasm_histologic_grade_G3                       0
# primary_pathology_neoplasm_histologic_grade_GX                       0
# primary_pathology_lymph_node_metastasis_radiographic_evidence_YES    0
# primary_pathology_primary_lymph_node_presentation_assessment_YES     0
# lymph_node_count_High                                                0
# lymph_node_count_Low                                                 0
# lymph_node_count_None                                                0
# primary_pathology_radiation_therapy_YES                              0
# primary_pathology_postoperative_rx_tx_YES                            0
# dtype: int64

# %%
def random_forest(data, target):
    import sklearn
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
    rand_forest = RandomForestClassifier(max_depth=3, min_samples_leaf=5, n_estimators=50)
    rand_forest.fit(X_train,y_train)
    #resultados para el TRAIN
    y_pred_train=rand_forest.predict(X_train)
    probs=rand_forest.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = rand_forest.predict(X_test) 
    probs = rand_forest.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

# %%
df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
random_forest(data, 'vital_status')
# Out:
# Train AUC: 1.0
# Train Accuracy: 0.9394604767879549
# Test AUC:  0.9814744592438103
# Test Accuracy:  0.9422835633626098

# %%
df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
random_forest(data, 'primary_pathology_histological_type_ESCC')
# Out:
# Train AUC: 1.0
# Train Accuracy: 0.9965495608531995
# Test AUC:  0.9999811018860317
# Test Accuracy:  0.9949811794228356

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import sklearn
from sklearn.tree import DecisionTreeClassifier # predict proba
from sklearn.tree import DecisionTreeRegressor

# %%
def xgboost(data, target):
    import sklearn
    import xgboost as xgb
    from xgboost import XGBClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import GridSearchCV
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

    xgbmodel = xgb.XGBClassifier()

    params = { #'objective': 'binary:logistic',
             'base_score': [0.5], # prediccion inicial
             'booster': ['gbtree'], # (gbtree, gblinear, dart)
             'colsample_bylevel': [1], # ratio de columnas en cada nivel
             'colsample_bytree': [0.6], # ratio de columnas por tree
             #'device': None,
             'early_stopping_rounds': [10],
             #'enable_categorical': False,
             #'eval_metric': None,
             #'feature_types': None,
             #'gamma': None, # minimo "loss" reduccion para crear un nuevo split. Larger-> conservative
             #'grow_policy': None,
             #'importance_type': None,
             #'interaction_constraints': None,
             'learning_rate': [0.01, 0.05], # aportacion de cada arbol al modelo
             #'max_bin': None,
             #'max_cat_threshold': None,
             #'max_cat_to_onehot': None,
             #'max_delta_step': None,
             'max_depth': [3,4], # maxima profundidad en cada arbol
             #'max_leaves': None,
             'min_child_weight': [10], # minimo numero samples por hoja
             #'missing': [0],
             #'monotone_constraints': None,
             #'multi_strategy': None,
             'n_estimators': [50,100,200] # numero de arboles
             #'n_jobs': [-1], # trabajos en paralelo
             #'num_parallel_tree': None,
             #'random_state': [0], # seed para generar los folds
             #'reg_alpha': None, # L1 regularización
             #'reg_lambda': None, # L2 regularización
             #'sampling_method': None,
             #'scale_pos_weight': [1],
             #'subsample': [0.9] # ratio de muestras por cada arbol 
             #'tree_method': None,
             #'validate_parameters': None,
             #'verbosity': 1
                            }
    
    scoring = ['accuracy', 'roc_auc']
    
    grid_solver = GridSearchCV(estimator = xgbmodel, # model to train
                   param_grid = params,
                   scoring = scoring,
                   cv = 10,
                   n_jobs=-1,
                   refit='accuracy',
                   verbose = 5)
 
    #grid_solver.fit(X_train,y_train)
    model_grid_boost = grid_solver.fit(X_train,y_train, eval_set=[(X_train, y_train), (X_test, y_test)]) 
    #resultados para el TRAIN

    
    
    y_pred_train=grid_solver.predict(X_train)
    probs=grid_solver.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = grid_solver.predict(X_test) 
    probs = grid_solver.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

    #df_test=pd.read_csv("test.csv")
    #y_pred = grid_solver.predict(preprocessing(df_test)) 

    #data_return = {"id":df_test["id"], "Depression":y_pred}
    #df_return = pd.DataFrame(data=data_return)
    #df_return.to_csv('second_attempt_test_v2_increase_folds.csv', index=False)
    #df_return.head()

    return

# %%
df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
xgboost(data, 'vital_status')
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [0]	validation_0-logloss:0.66388	validation_1-logloss:0.66523
# [1]	validation_0-logloss:0.62498	validation_1-logloss:0.62708
# [2]	validation_0-logloss:0.59617	validation_1-logloss:0.59925
# [3]	validation_0-logloss:0.57844	validation_1-logloss:0.58212
# [4]	validation_0-logloss:0.54740	validation_1-logloss:0.55119
# [5]	validation_0-logloss:0.51809	validation_1-logloss:0.52247
# [6]	validation_0-logloss:0.49182	validation_1-logloss:0.49627
# [7]	validation_0-logloss:0.46593	validation_1-logloss:0.47110
# [8]	validation_0-logloss:0.44297	validation_1-logloss:0.44850
# [9]	validation_0-logloss:0.42081	validation_1-logloss:0.42685
# [10]	validation_0-logloss:0.40813	validation_1-logloss:0.41404
# [11]	validation_0-logloss:0.38848	validation_1-logloss:0.39500
# [12]	validation_0-logloss:0.37017	validation_1-logloss:0.37749
# [13]	validation_0-logloss:0.35909	validation_1-logloss:0.36647
# [14]	validation_0-logloss:0.34317	validation_1-logloss:0.35144
# [15]	validation_0-logloss:0.32791	validation_1-logloss:0.33680
# [16]	validation_0-logloss:0.31940	validation_1-logloss:0.32878
# [17]	validation_0-logloss:0.31075	validation_1-logloss:0.32078
# [18]	validation_0-logloss:0.29770	validation_1-logloss:0.30810
# [19]	validation_0-logloss:0.28557	validation_1-logloss:0.29618
# [20]	validation_0-logloss:0.27872	validation_1-logloss:0.28973
# [21]	validation_0-logloss:0.27257	validation_1-logloss:0.28364
# [22]	validation_0-logloss:0.26463	validation_1-logloss:0.27629
# [23]	validation_0-logloss:0.25411	validation_1-logloss:0.26580
# [24]	validation_0-logloss:0.24422	validation_1-logloss:0.25586
# [25]	validation_0-logloss:0.23446	validation_1-logloss:0.24655
# [26]	validation_0-logloss:0.22565	validation_1-logloss:0.23750
# [27]	validation_0-logloss:0.21735	validation_1-logloss:0.22921
# [28]	validation_0-logloss:0.20926	validation_1-logloss:0.22127
# [29]	validation_0-logloss:0.20078	validation_1-logloss:0.21278
# [30]	validation_0-logloss:0.19636	validation_1-logloss:0.20838
# [31]	validation_0-logloss:0.18965	validation_1-logloss:0.20160
# [32]	validation_0-logloss:0.18272	validation_1-logloss:0.19500
# [33]	validation_0-logloss:0.17627	validation_1-logloss:0.18898
# [34]	validation_0-logloss:0.17266	validation_1-logloss:0.18549
# [35]	validation_0-logloss:0.16921	validation_1-logloss:0.18222
# [36]	validation_0-logloss:0.16404	validation_1-logloss:0.17720
# [37]	validation_0-logloss:0.16044	validation_1-logloss:0.17374
# [38]	validation_0-logloss:0.15508	validation_1-logloss:0.16802
# [39]	validation_0-logloss:0.15213	validation_1-logloss:0.16534
# [40]	validation_0-logloss:0.14733	validation_1-logloss:0.16012
# [41]	validation_0-logloss:0.14286	validation_1-logloss:0.15584
# [42]	validation_0-logloss:0.13871	validation_1-logloss:0.15135
# [43]	validation_0-logloss:0.13670	validation_1-logloss:0.14951
# [44]	validation_0-logloss:0.13447	validation_1-logloss:0.14712
# [45]	validation_0-logloss:0.13291	validation_1-logloss:0.14547
# [46]	validation_0-logloss:0.12897	validation_1-logloss:0.14178
# [47]	validation_0-logloss:0.12684	validation_1-logloss:0.13980
# [48]	validation_0-logloss:0.12525	validation_1-logloss:0.13798
# [49]	validation_0-logloss:0.12237	validation_1-logloss:0.13532
# [50]	validation_0-logloss:0.11925	validation_1-logloss:0.13234
# [51]	validation_0-logloss:0.11553	validation_1-logloss:0.12867
# [52]	validation_0-logloss:0.11230	validation_1-logloss:0.12531
# [53]	validation_0-logloss:0.10922	validation_1-logloss:0.12236
# [54]	validation_0-logloss:0.10607	validation_1-logloss:0.11925
# [55]	validation_0-logloss:0.10333	validation_1-logloss:0.11641
# [56]	validation_0-logloss:0.10071	validation_1-logloss:0.11371
# [57]	validation_0-logloss:0.09807	validation_1-logloss:0.11098
# [58]	validation_0-logloss:0.09699	validation_1-logloss:0.10977
# [59]	validation_0-logloss:0.09485	validation_1-logloss:0.10755
# [60]	validation_0-logloss:0.09247	validation_1-logloss:0.10494
# [61]	validation_0-logloss:0.08995	validation_1-logloss:0.10254
# [62]	validation_0-logloss:0.08793	validation_1-logloss:0.10022
# [63]	validation_0-logloss:0.08623	validation_1-logloss:0.09838
# [64]	validation_0-logloss:0.08466	validation_1-logloss:0.09683
# [65]	validation_0-logloss:0.08266	validation_1-logloss:0.09477
# [66]	validation_0-logloss:0.08124	validation_1-logloss:0.09332
# [67]	validation_0-logloss:0.07995	validation_1-logloss:0.09194
# [68]	validation_0-logloss:0.07861	validation_1-logloss:0.09049
# [69]	validation_0-logloss:0.07736	validation_1-logloss:0.08906
# [70]	validation_0-logloss:0.07614	validation_1-logloss:0.08786
# [71]	validation_0-logloss:0.07489	validation_1-logloss:0.08647
# [72]	validation_0-logloss:0.07376	validation_1-logloss:0.08512
# [73]	validation_0-logloss:0.07222	validation_1-logloss:0.08355
# [74]	validation_0-logloss:0.07107	validation_1-logloss:0.08224
# [75]	validation_0-logloss:0.06996	validation_1-logloss:0.08097
# [76]	validation_0-logloss:0.06880	validation_1-logloss:0.07980
# [77]	validation_0-logloss:0.06790	validation_1-logloss:0.07863
# [78]	validation_0-logloss:0.06689	validation_1-logloss:0.07748
# [79]	validation_0-logloss:0.06576	validation_1-logloss:0.07622
# [80]	validation_0-logloss:0.06412	validation_1-logloss:0.07448
# [81]	validation_0-logloss:0.06320	validation_1-logloss:0.07333
# [82]	validation_0-logloss:0.06241	validation_1-logloss:0.07237
# [83]	validation_0-logloss:0.06178	validation_1-logloss:0.07163
# [84]	validation_0-logloss:0.06109	validation_1-logloss:0.07088
# [85]	validation_0-logloss:0.06010	validation_1-logloss:0.06973
# [86]	validation_0-logloss:0.05954	validation_1-logloss:0.06896
# [87]	validation_0-logloss:0.05887	validation_1-logloss:0.06818
# [88]	validation_0-logloss:0.05829	validation_1-logloss:0.06751
# [89]	validation_0-logloss:0.05739	validation_1-logloss:0.06648
# [90]	validation_0-logloss:0.05685	validation_1-logloss:0.06570
# [91]	validation_0-logloss:0.05550	validation_1-logloss:0.06430
# [92]	validation_0-logloss:0.05466	validation_1-logloss:0.06340
# [93]	validation_0-logloss:0.05368	validation_1-logloss:0.06242
# [94]	validation_0-logloss:0.05269	validation_1-logloss:0.06151
# [95]	validation_0-logloss:0.05200	validation_1-logloss:0.06070
# [96]	validation_0-logloss:0.05140	validation_1-logloss:0.06004
# [97]	validation_0-logloss:0.05092	validation_1-logloss:0.05946
# [98]	validation_0-logloss:0.05028	validation_1-logloss:0.05876
# [99]	validation_0-logloss:0.04940	validation_1-logloss:0.05788
# [100]	validation_0-logloss:0.04837	validation_1-logloss:0.05679
# [101]	validation_0-logloss:0.04789	validation_1-logloss:0.05606
# [102]	validation_0-logloss:0.04745	validation_1-logloss:0.05547
# [103]	validation_0-logloss:0.04709	validation_1-logloss:0.05505
# [104]	validation_0-logloss:0.04652	validation_1-logloss:0.05443
# [105]	validation_0-logloss:0.04610	validation_1-logloss:0.05387
# [106]	validation_0-logloss:0.04550	validation_1-logloss:0.05315
# [107]	validation_0-logloss:0.04491	validation_1-logloss:0.05252
# [108]	validation_0-logloss:0.04437	validation_1-logloss:0.05191
# [109]	validation_0-logloss:0.04384	validation_1-logloss:0.05137
# [110]	validation_0-logloss:0.04344	validation_1-logloss:0.05102
# [111]	validation_0-logloss:0.04294	validation_1-logloss:0.05042
# [112]	validation_0-logloss:0.04250	validation_1-logloss:0.05000
# [113]	validation_0-logloss:0.04207	validation_1-logloss:0.04954
# [114]	validation_0-logloss:0.04158	validation_1-logloss:0.04900
# [115]	validation_0-logloss:0.04109	validation_1-logloss:0.04843
# [116]	validation_0-logloss:0.04083	validation_1-logloss:0.04809
# [117]	validation_0-logloss:0.04034	validation_1-logloss:0.04750
# [118]	validation_0-logloss:0.03991	validation_1-logloss:0.04698
# [119]	validation_0-logloss:0.03952	validation_1-logloss:0.04648
# [120]	validation_0-logloss:0.03921	validation_1-logloss:0.04600
# [121]	validation_0-logloss:0.03888	validation_1-logloss:0.04559
# [122]	validation_0-logloss:0.03824	validation_1-logloss:0.04494
# [123]	validation_0-logloss:0.03795	validation_1-logloss:0.04454
# [124]	validation_0-logloss:0.03766	validation_1-logloss:0.04415
# [125]	validation_0-logloss:0.03706	validation_1-logloss:0.04347
# [126]	validation_0-logloss:0.03683	validation_1-logloss:0.04310
# [127]	validation_0-logloss:0.03636	validation_1-logloss:0.04253
# [128]	validation_0-logloss:0.03588	validation_1-logloss:0.04208
# [129]	validation_0-logloss:0.03562	validation_1-logloss:0.04176
# [130]	validation_0-logloss:0.03524	validation_1-logloss:0.04141
# [131]	validation_0-logloss:0.03495	validation_1-logloss:0.04098
# [132]	validation_0-logloss:0.03470	validation_1-logloss:0.04071
# [133]	validation_0-logloss:0.03416	validation_1-logloss:0.04004
# [134]	validation_0-logloss:0.03389	validation_1-logloss:0.03970
# [135]	validation_0-logloss:0.03359	validation_1-logloss:0.03936
# [136]	validation_0-logloss:0.03343	validation_1-logloss:0.03916
# [137]	validation_0-logloss:0.03322	validation_1-logloss:0.03889
# [138]	validation_0-logloss:0.03301	validation_1-logloss:0.03860
# [139]	validation_0-logloss:0.03260	validation_1-logloss:0.03824
# [140]	validation_0-logloss:0.03241	validation_1-logloss:0.03801
# [141]	validation_0-logloss:0.03214	validation_1-logloss:0.03771
# [142]	validation_0-logloss:0.03194	validation_1-logloss:0.03745
# [143]	validation_0-logloss:0.03171	validation_1-logloss:0.03724
# [144]	validation_0-logloss:0.03146	validation_1-logloss:0.03697
# [145]	validation_0-logloss:0.03107	validation_1-logloss:0.03659
# [146]	validation_0-logloss:0.03088	validation_1-logloss:0.03634
# [147]	validation_0-logloss:0.03071	validation_1-logloss:0.03609
# [148]	validation_0-logloss:0.03051	validation_1-logloss:0.03585
# [149]	validation_0-logloss:0.03029	validation_1-logloss:0.03561
# [150]	validation_0-logloss:0.03001	validation_1-logloss:0.03539
# [151]	validation_0-logloss:0.02983	validation_1-logloss:0.03516
# [152]	validation_0-logloss:0.02954	validation_1-logloss:0.03489
# [153]	validation_0-logloss:0.02924	validation_1-logloss:0.03453
# [154]	validation_0-logloss:0.02904	validation_1-logloss:0.03428
# [155]	validation_0-logloss:0.02887	validation_1-logloss:0.03406
# [156]	validation_0-logloss:0.02872	validation_1-logloss:0.03394
# [157]	validation_0-logloss:0.02843	validation_1-logloss:0.03365
# [158]	validation_0-logloss:0.02815	validation_1-logloss:0.03341
# [159]	validation_0-logloss:0.02800	validation_1-logloss:0.03325
# [160]	validation_0-logloss:0.02785	validation_1-logloss:0.03302
# [161]	validation_0-logloss:0.02769	validation_1-logloss:0.03283
# [162]	validation_0-logloss:0.02747	validation_1-logloss:0.03255
# [163]	validation_0-logloss:0.02731	validation_1-logloss:0.03236
# [164]	validation_0-logloss:0.02710	validation_1-logloss:0.03212
# [165]	validation_0-logloss:0.02697	validation_1-logloss:0.03194
# [166]	validation_0-logloss:0.02685	validation_1-logloss:0.03179
# [167]	validation_0-logloss:0.02666	validation_1-logloss:0.03165
# [168]	validation_0-logloss:0.02653	validation_1-logloss:0.03148
# [169]	validation_0-logloss:0.02634	validation_1-logloss:0.03123
# [170]	validation_0-logloss:0.02623	validation_1-logloss:0.03112
# [171]	validation_0-logloss:0.02600	validation_1-logloss:0.03098
# [172]	validation_0-logloss:0.02583	validation_1-logloss:0.03084
# [173]	validation_0-logloss:0.02568	validation_1-logloss:0.03063
# [174]	validation_0-logloss:0.02552	validation_1-logloss:0.03046
# [175]	validation_0-logloss:0.02538	validation_1-logloss:0.03027
# [176]	validation_0-logloss:0.02522	validation_1-logloss:0.03010
# [177]	validation_0-logloss:0.02512	validation_1-logloss:0.02994
# [178]	validation_0-logloss:0.02498	validation_1-logloss:0.02975
# [179]	validation_0-logloss:0.02485	validation_1-logloss:0.02960
# [180]	validation_0-logloss:0.02474	validation_1-logloss:0.02946
# [181]	validation_0-logloss:0.02464	validation_1-logloss:0.02932
# [182]	validation_0-logloss:0.02452	validation_1-logloss:0.02912
# [183]	validation_0-logloss:0.02435	validation_1-logloss:0.02896
# [184]	validation_0-logloss:0.02426	validation_1-logloss:0.02887
# [185]	validation_0-logloss:0.02413	validation_1-logloss:0.02874
# [186]	validation_0-logloss:0.02401	validation_1-logloss:0.02861
# [187]	validation_0-logloss:0.02391	validation_1-logloss:0.02848
# [188]	validation_0-logloss:0.02375	validation_1-logloss:0.02834
# [189]	validation_0-logloss:0.02361	validation_1-logloss:0.02818
# [190]	validation_0-logloss:0.02348	validation_1-logloss:0.02808
# [191]	validation_0-logloss:0.02337	validation_1-logloss:0.02792
# [192]	validation_0-logloss:0.02328	validation_1-logloss:0.02778
# [193]	validation_0-logloss:0.02318	validation_1-logloss:0.02769
# [194]	validation_0-logloss:0.02304	validation_1-logloss:0.02750
# [195]	validation_0-logloss:0.02296	validation_1-logloss:0.02739
# [196]	validation_0-logloss:0.02289	validation_1-logloss:0.02726
# [197]	validation_0-logloss:0.02282	validation_1-logloss:0.02717
# [198]	validation_0-logloss:0.02268	validation_1-logloss:0.02704
# [199]	validation_0-logloss:0.02258	validation_1-logloss:0.02696
# Train AUC: 1.0
# Train Accuracy: 1.0
# Test AUC:  1.0
# Test Accuracy:  1.0

# %%
df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
xgboost(data, 'primary_pathology_histological_type_ESCC')
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [0]	validation_0-logloss:0.68356	validation_1-logloss:0.68360
# [1]	validation_0-logloss:0.67727	validation_1-logloss:0.67743
# [2]	validation_0-logloss:0.67054	validation_1-logloss:0.67074
# [3]	validation_0-logloss:0.66119	validation_1-logloss:0.66142
# [4]	validation_0-logloss:0.65204	validation_1-logloss:0.65226
# [5]	validation_0-logloss:0.64324	validation_1-logloss:0.64343
# [6]	validation_0-logloss:0.63715	validation_1-logloss:0.63752
# [7]	validation_0-logloss:0.63125	validation_1-logloss:0.63170
# [8]	validation_0-logloss:0.62537	validation_1-logloss:0.62580
# [9]	validation_0-logloss:0.61688	validation_1-logloss:0.61732
# [10]	validation_0-logloss:0.60855	validation_1-logloss:0.60899
# [11]	validation_0-logloss:0.60297	validation_1-logloss:0.60355
# [12]	validation_0-logloss:0.59736	validation_1-logloss:0.59798
# [13]	validation_0-logloss:0.59228	validation_1-logloss:0.59309
# [14]	validation_0-logloss:0.58724	validation_1-logloss:0.58822
# [15]	validation_0-logloss:0.58196	validation_1-logloss:0.58301
# [16]	validation_0-logloss:0.57707	validation_1-logloss:0.57825
# [17]	validation_0-logloss:0.57284	validation_1-logloss:0.57409
# [18]	validation_0-logloss:0.56530	validation_1-logloss:0.56654
# [19]	validation_0-logloss:0.55788	validation_1-logloss:0.55912
# [20]	validation_0-logloss:0.55058	validation_1-logloss:0.55182
# [21]	validation_0-logloss:0.54570	validation_1-logloss:0.54698
# [22]	validation_0-logloss:0.53869	validation_1-logloss:0.53995
# [23]	validation_0-logloss:0.53415	validation_1-logloss:0.53553
# [24]	validation_0-logloss:0.52961	validation_1-logloss:0.53096
# [25]	validation_0-logloss:0.52279	validation_1-logloss:0.52415
# [26]	validation_0-logloss:0.51841	validation_1-logloss:0.51987
# [27]	validation_0-logloss:0.51409	validation_1-logloss:0.51552
# [28]	validation_0-logloss:0.51011	validation_1-logloss:0.51167
# [29]	validation_0-logloss:0.50613	validation_1-logloss:0.50763
# [30]	validation_0-logloss:0.50189	validation_1-logloss:0.50348
# [31]	validation_0-logloss:0.49556	validation_1-logloss:0.49713
# [32]	validation_0-logloss:0.49166	validation_1-logloss:0.49329
# [33]	validation_0-logloss:0.48750	validation_1-logloss:0.48915
# [34]	validation_0-logloss:0.48374	validation_1-logloss:0.48546
# [35]	validation_0-logloss:0.47766	validation_1-logloss:0.47938
# [36]	validation_0-logloss:0.47168	validation_1-logloss:0.47340
# [37]	validation_0-logloss:0.46784	validation_1-logloss:0.46954
# [38]	validation_0-logloss:0.46201	validation_1-logloss:0.46371
# [39]	validation_0-logloss:0.45628	validation_1-logloss:0.45798
# [40]	validation_0-logloss:0.45079	validation_1-logloss:0.45248
# [41]	validation_0-logloss:0.44754	validation_1-logloss:0.44935
# [42]	validation_0-logloss:0.44426	validation_1-logloss:0.44616
# [43]	validation_0-logloss:0.43883	validation_1-logloss:0.44071
# [44]	validation_0-logloss:0.43552	validation_1-logloss:0.43745
# [45]	validation_0-logloss:0.43023	validation_1-logloss:0.43216
# [46]	validation_0-logloss:0.42714	validation_1-logloss:0.42915
# [47]	validation_0-logloss:0.42440	validation_1-logloss:0.42646
# [48]	validation_0-logloss:0.42188	validation_1-logloss:0.42393
# [49]	validation_0-logloss:0.41676	validation_1-logloss:0.41880
# [50]	validation_0-logloss:0.41383	validation_1-logloss:0.41595
# [51]	validation_0-logloss:0.41065	validation_1-logloss:0.41280
# [52]	validation_0-logloss:0.40569	validation_1-logloss:0.40784
# [53]	validation_0-logloss:0.40335	validation_1-logloss:0.40547
# [54]	validation_0-logloss:0.39856	validation_1-logloss:0.40066
# [55]	validation_0-logloss:0.39581	validation_1-logloss:0.39798
# [56]	validation_0-logloss:0.39107	validation_1-logloss:0.39324
# [57]	validation_0-logloss:0.38864	validation_1-logloss:0.39089
# [58]	validation_0-logloss:0.38601	validation_1-logloss:0.38834
# [59]	validation_0-logloss:0.38145	validation_1-logloss:0.38376
# [60]	validation_0-logloss:0.37692	validation_1-logloss:0.37922
# [61]	validation_0-logloss:0.37440	validation_1-logloss:0.37679
# [62]	validation_0-logloss:0.37001	validation_1-logloss:0.37237
# [63]	validation_0-logloss:0.36573	validation_1-logloss:0.36807
# [64]	validation_0-logloss:0.36142	validation_1-logloss:0.36375
# [65]	validation_0-logloss:0.35894	validation_1-logloss:0.36128
# [66]	validation_0-logloss:0.35703	validation_1-logloss:0.35933
# [67]	validation_0-logloss:0.35461	validation_1-logloss:0.35693
# [68]	validation_0-logloss:0.35050	validation_1-logloss:0.35279
# [69]	validation_0-logloss:0.34652	validation_1-logloss:0.34882
# [70]	validation_0-logloss:0.34252	validation_1-logloss:0.34479
# [71]	validation_0-logloss:0.33854	validation_1-logloss:0.34080
# [72]	validation_0-logloss:0.33465	validation_1-logloss:0.33689
# [73]	validation_0-logloss:0.33085	validation_1-logloss:0.33306
# [74]	validation_0-logloss:0.32703	validation_1-logloss:0.32922
# [75]	validation_0-logloss:0.32326	validation_1-logloss:0.32544
# [76]	validation_0-logloss:0.32113	validation_1-logloss:0.32335
# [77]	validation_0-logloss:0.31747	validation_1-logloss:0.31968
# [78]	validation_0-logloss:0.31542	validation_1-logloss:0.31765
# [79]	validation_0-logloss:0.31333	validation_1-logloss:0.31558
# [80]	validation_0-logloss:0.30978	validation_1-logloss:0.31201
# [81]	validation_0-logloss:0.30625	validation_1-logloss:0.30846
# [82]	validation_0-logloss:0.30275	validation_1-logloss:0.30496
# [83]	validation_0-logloss:0.29935	validation_1-logloss:0.30153
# [84]	validation_0-logloss:0.29595	validation_1-logloss:0.29812
# [85]	validation_0-logloss:0.29259	validation_1-logloss:0.29475
# [86]	validation_0-logloss:0.28931	validation_1-logloss:0.29146
# [87]	validation_0-logloss:0.28606	validation_1-logloss:0.28821
# [88]	validation_0-logloss:0.28410	validation_1-logloss:0.28627
# [89]	validation_0-logloss:0.28233	validation_1-logloss:0.28452
# [90]	validation_0-logloss:0.27917	validation_1-logloss:0.28136
# [91]	validation_0-logloss:0.27606	validation_1-logloss:0.27824
# [92]	validation_0-logloss:0.27439	validation_1-logloss:0.27662
# [93]	validation_0-logloss:0.27134	validation_1-logloss:0.27356
# [94]	validation_0-logloss:0.26834	validation_1-logloss:0.27054
# [95]	validation_0-logloss:0.26544	validation_1-logloss:0.26762
# [96]	validation_0-logloss:0.26258	validation_1-logloss:0.26475
# [97]	validation_0-logloss:0.25968	validation_1-logloss:0.26185
# [98]	validation_0-logloss:0.25689	validation_1-logloss:0.25903
# [99]	validation_0-logloss:0.25406	validation_1-logloss:0.25620
# [100]	validation_0-logloss:0.25254	validation_1-logloss:0.25471
# [101]	validation_0-logloss:0.24975	validation_1-logloss:0.25190
# [102]	validation_0-logloss:0.24700	validation_1-logloss:0.24913
# [103]	validation_0-logloss:0.24427	validation_1-logloss:0.24640
# [104]	validation_0-logloss:0.24284	validation_1-logloss:0.24498
# [105]	validation_0-logloss:0.24125	validation_1-logloss:0.24341
# [106]	validation_0-logloss:0.23862	validation_1-logloss:0.24077
# [107]	validation_0-logloss:0.23721	validation_1-logloss:0.23934
# [108]	validation_0-logloss:0.23462	validation_1-logloss:0.23672
# [109]	validation_0-logloss:0.23340	validation_1-logloss:0.23553
# [110]	validation_0-logloss:0.23088	validation_1-logloss:0.23299
# [111]	validation_0-logloss:0.22955	validation_1-logloss:0.23170
# [112]	validation_0-logloss:0.22817	validation_1-logloss:0.23029
# [113]	validation_0-logloss:0.22706	validation_1-logloss:0.22915
# [114]	validation_0-logloss:0.22458	validation_1-logloss:0.22666
# [115]	validation_0-logloss:0.22214	validation_1-logloss:0.22421
# [116]	validation_0-logloss:0.22104	validation_1-logloss:0.22313
# [117]	validation_0-logloss:0.21866	validation_1-logloss:0.22074
# [118]	validation_0-logloss:0.21629	validation_1-logloss:0.21835
# [119]	validation_0-logloss:0.21512	validation_1-logloss:0.21722
# [120]	validation_0-logloss:0.21281	validation_1-logloss:0.21490
# [121]	validation_0-logloss:0.21164	validation_1-logloss:0.21376
# [122]	validation_0-logloss:0.21038	validation_1-logloss:0.21253
# [123]	validation_0-logloss:0.20810	validation_1-logloss:0.21024
# [124]	validation_0-logloss:0.20589	validation_1-logloss:0.20801
# [125]	validation_0-logloss:0.20367	validation_1-logloss:0.20578
# [126]	validation_0-logloss:0.20248	validation_1-logloss:0.20462
# [127]	validation_0-logloss:0.20030	validation_1-logloss:0.20243
# [128]	validation_0-logloss:0.19823	validation_1-logloss:0.20035
# [129]	validation_0-logloss:0.19618	validation_1-logloss:0.19827
# [130]	validation_0-logloss:0.19414	validation_1-logloss:0.19621
# [131]	validation_0-logloss:0.19210	validation_1-logloss:0.19414
# [132]	validation_0-logloss:0.19006	validation_1-logloss:0.19210
# [133]	validation_0-logloss:0.18811	validation_1-logloss:0.19014
# [134]	validation_0-logloss:0.18704	validation_1-logloss:0.18909
# [135]	validation_0-logloss:0.18592	validation_1-logloss:0.18799
# [136]	validation_0-logloss:0.18396	validation_1-logloss:0.18601
# [137]	validation_0-logloss:0.18208	validation_1-logloss:0.18411
# [138]	validation_0-logloss:0.18111	validation_1-logloss:0.18315
# [139]	validation_0-logloss:0.17920	validation_1-logloss:0.18123
# [140]	validation_0-logloss:0.17732	validation_1-logloss:0.17934
# [141]	validation_0-logloss:0.17546	validation_1-logloss:0.17747
# [142]	validation_0-logloss:0.17447	validation_1-logloss:0.17649
# [143]	validation_0-logloss:0.17264	validation_1-logloss:0.17465
# [144]	validation_0-logloss:0.17173	validation_1-logloss:0.17376
# [145]	validation_0-logloss:0.16993	validation_1-logloss:0.17196
# [146]	validation_0-logloss:0.16817	validation_1-logloss:0.17017
# [147]	validation_0-logloss:0.16724	validation_1-logloss:0.16922
# [148]	validation_0-logloss:0.16644	validation_1-logloss:0.16843
# [149]	validation_0-logloss:0.16472	validation_1-logloss:0.16669
# [150]	validation_0-logloss:0.16302	validation_1-logloss:0.16497
# [151]	validation_0-logloss:0.16133	validation_1-logloss:0.16327
# [152]	validation_0-logloss:0.15966	validation_1-logloss:0.16158
# [153]	validation_0-logloss:0.15804	validation_1-logloss:0.15995
# [154]	validation_0-logloss:0.15645	validation_1-logloss:0.15834
# [155]	validation_0-logloss:0.15583	validation_1-logloss:0.15771
# [156]	validation_0-logloss:0.15421	validation_1-logloss:0.15609
# [157]	validation_0-logloss:0.15338	validation_1-logloss:0.15526
# [158]	validation_0-logloss:0.15180	validation_1-logloss:0.15366
# [159]	validation_0-logloss:0.15023	validation_1-logloss:0.15209
# [160]	validation_0-logloss:0.14872	validation_1-logloss:0.15057
# [161]	validation_0-logloss:0.14720	validation_1-logloss:0.14903
# [162]	validation_0-logloss:0.14570	validation_1-logloss:0.14751
# [163]	validation_0-logloss:0.14497	validation_1-logloss:0.14680
# [164]	validation_0-logloss:0.14349	validation_1-logloss:0.14530
# [165]	validation_0-logloss:0.14201	validation_1-logloss:0.14382
# [166]	validation_0-logloss:0.14132	validation_1-logloss:0.14315
# [167]	validation_0-logloss:0.13989	validation_1-logloss:0.14170
# [168]	validation_0-logloss:0.13916	validation_1-logloss:0.14098
# [169]	validation_0-logloss:0.13778	validation_1-logloss:0.13960
# [170]	validation_0-logloss:0.13637	validation_1-logloss:0.13818
# [171]	validation_0-logloss:0.13498	validation_1-logloss:0.13678
# [172]	validation_0-logloss:0.13365	validation_1-logloss:0.13545
# [173]	validation_0-logloss:0.13229	validation_1-logloss:0.13408
# [174]	validation_0-logloss:0.13170	validation_1-logloss:0.13350
# [175]	validation_0-logloss:0.13042	validation_1-logloss:0.13221
# [176]	validation_0-logloss:0.12980	validation_1-logloss:0.13161
# [177]	validation_0-logloss:0.12919	validation_1-logloss:0.13101
# [178]	validation_0-logloss:0.12854	validation_1-logloss:0.13034
# [179]	validation_0-logloss:0.12795	validation_1-logloss:0.12976
# [180]	validation_0-logloss:0.12665	validation_1-logloss:0.12845
# [181]	validation_0-logloss:0.12605	validation_1-logloss:0.12785
# [182]	validation_0-logloss:0.12549	validation_1-logloss:0.12731
# [183]	validation_0-logloss:0.12421	validation_1-logloss:0.12603
# [184]	validation_0-logloss:0.12296	validation_1-logloss:0.12476
# [185]	validation_0-logloss:0.12172	validation_1-logloss:0.12351
# [186]	validation_0-logloss:0.12051	validation_1-logloss:0.12228
# [187]	validation_0-logloss:0.11929	validation_1-logloss:0.12105
# [188]	validation_0-logloss:0.11810	validation_1-logloss:0.11984
# [189]	validation_0-logloss:0.11770	validation_1-logloss:0.11943
# [190]	validation_0-logloss:0.11717	validation_1-logloss:0.11890
# [191]	validation_0-logloss:0.11598	validation_1-logloss:0.11771
# [192]	validation_0-logloss:0.11551	validation_1-logloss:0.11725
# [193]	validation_0-logloss:0.11435	validation_1-logloss:0.11608
# [194]	validation_0-logloss:0.11390	validation_1-logloss:0.11562
# [195]	validation_0-logloss:0.11335	validation_1-logloss:0.11509
# [196]	validation_0-logloss:0.11223	validation_1-logloss:0.11395
# [197]	validation_0-logloss:0.11111	validation_1-logloss:0.11282
# [198]	validation_0-logloss:0.11064	validation_1-logloss:0.11236
# [199]	validation_0-logloss:0.10957	validation_1-logloss:0.11128
# Train AUC: 1.0
# Train Accuracy: 1.0
# Test AUC:  1.0
# Test Accuracy:  1.0
