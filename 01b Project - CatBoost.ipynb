# %%
def preprocesamiento(df):

    import pandas as pd
    import numpy as np
    
    import warnings
    warnings.filterwarnings('ignore')
    
    
#    df = pd.read_csv("Esophageal_Dataset.csv")
    cols_to_drop = ['Unnamed: 0',
                    'patient_barcode',
                    'tissue_source_site',
                    'patient_id',
                    'bcr_patient_uuid',
                    'informed_consent_verified',
                    'icd_o_3_site',
                    'country_of_birth',
                    'country_of_procurement', 
                    'state_province_of_procurement',
                    'city_of_procurement',
                    'history_of_neoadjuvant_treatment', 
                    'age_began_smoking_in_years',
                    'stopped_smoking_year',
                    'number_pack_years_smoked',
                    'frequency_of_alcohol_consumption',
                    'amount_of_alcohol_consumption_per_day',
                    'antireflux_treatment_types',
                    'h_pylori_infection',
                    'goblet_cells_present',
                    'number_of_relatives_diagnosed',
                    'day_of_form_completion',
                    'month_of_form_completion',
                    'year_of_form_completion',
                    'project',
                    'stage_event_system_version',
                    'stage_event_psa',
                    'stage_event_gleason_grading',
                    'stage_event_ann_arbor',
                    'stage_event_serum_markers',
                    'stage_event_igcccg_stage',
                    'stage_event_masaoka_stage',
                    'primary_pathology_tumor_tissue_site',
                    'primary_pathology_esophageal_tumor_involvement_sites',
                    'primary_pathology_columnar_metaplasia_present',
                    'primary_pathology_columnar_mucosa_goblet_cell_present',
                    'primary_pathology_columnar_mucosa_dysplasia',
                    'primary_pathology_days_to_initial_pathologic_diagnosis',
                    'primary_pathology_year_of_initial_pathologic_diagnosis',
                    'primary_pathology_init_pathology_dx_method_other',
                    'primary_pathology_number_of_lymphnodes_positive_by_he',
                    'primary_pathology_number_of_lymphnodes_positive_by_ihc',
                    'primary_pathology_planned_surgery_status',
                    'primary_pathology_treatment_prior_to_surgery',
                    'primary_pathology_karnofsky_performance_score',
                    'primary_pathology_eastern_cancer_oncology_group',
                    'days_to_last_followup',
                    'days_to_death']
    
    df.drop(columns=cols_to_drop, inplace=True)
    
#se harán dummies para los indicadores histológicos icd_o_3 & icd_10
    
#rellenamos nans de prospective collection con método bfill, y usamos prospective collection para crear columna tissue collection:
#con valor 1 para prospective (prospective=YES) y 0 para retrospective (prospective=NO)
#y eliminaremos las columnas prospective y retrospective
    df.tissue_prospective_collection_indicator = df.tissue_prospective_collection_indicator.fillna(method='bfill')
    df['tissue_collection'] = df['tissue_prospective_collection_indicator']
    
    df.loc[(df['tissue_prospective_collection_indicator'] == 'YES'), 'tissue_collection'] = 1
    df.loc[(df['tissue_prospective_collection_indicator'] == 'NO'), 'tissue_collection'] = 0
  
    
#se crea una columna edad que contendrá la edad en años (módulo de la division por 365 de la columna days_to_birth)
#y se crea una columna de años sobrevividos con la diferencia entre edad y edad de diagnóstico
#(para casos en los que la diferencia es -1 por ajuste del modulo, se fuerza valor 0)
#se escala usando minmax scaling
#por último se eliminará la columna original days_to_birth
    df['age'] = df.days_to_birth // -365
    df['years_survived']=df.age - df.primary_pathology_age_at_initial_pathologic_diagnosis
    df.loc[df.years_survived < 0, 'years_survived'] = 0
    df.age = (df.age - df.age.min()) / (df.age.max() - df.age.min())
    
#se crean dummies para sexo
#se eliminará la columna original después de haber calculado las medias de altura y peso por sexo
#para rellenar los NaN de esas columnas 
#se escalan min_max la altura y el peso    
    df.loc[(df.height.isna()) & (df.gender == 'FEMALE'), 'height'] = df.loc[(df.gender == 'FEMALE'), 'height'].mean()
    df.loc[(df.height.isna()) & (df.gender == 'MALE'), 'height'] = df.loc[(df.gender == 'MALE'), 'height'].mean()
    df.height = (df.height - df.height.min()) / (df.height.max() - df.height.min())
    
    df.loc[(df.weight.isna()) & (df.gender == 'FEMALE'), 'weight'] = df.loc[(df.gender == 'FEMALE'), 'weight'].mean()
    df.loc[(df.weight.isna()) & (df.gender == 'MALE'), 'weight'] = df.loc[(df.gender == 'MALE'), 'weight'].mean()
    df.weight = (df.weight - df.weight.min()) / (df.weight.max() - df.weight.min())

    
#Los NaN de la columna race_list se rellenará de la siguiente forma:
#en los casos en los que sea NAN y la columna 'ethnicity' sea HISPANIC, se rellenará como HISPANIC… 
#los demás NAN se rellenárán usando el método backfill.
#se crean dummies para la columna y se eliminará la columna 'ethnicity'
    df.loc[(df.race_list.isna()) & (df.ethnicity == 'HISPANIC OR LATINO'), 'race_list'] = 'HISPANIC'
    df.race_list = df.race_list.fillna(method='bfill')
    
#valores YES/NO de other_dx pasan a ser 1/0
    df.loc[df.other_dx == 'Yes', 'other_dx'] = 1
    df.loc[df.other_dx == 'No', 'other_dx'] = 0
    
#valores TUMOR FREE/WITH TUMOR de person_neoplasm_cancer_status pasan a ser 0/1
#y NaN se cambian con método ffill
    df.loc[df.person_neoplasm_cancer_status == 'TUMOR FREE', 'person_neoplasm_cancer_status'] = 0
    df.loc[df.person_neoplasm_cancer_status == 'WITH TUMOR', 'person_neoplasm_cancer_status'] = 1
    df.person_neoplasm_cancer_status = df.person_neoplasm_cancer_status.fillna(method='ffill')
    
#valores Dead/Alive de vital_status pasan a ser 0/1
    df.loc[df.vital_status == 'Dead', 'vital_status'] = 0
    df.loc[df.vital_status == 'Alive', 'vital_status'] = 1
    
#historial de fumador: sustituimos NaN con método ffill y hacemos dummies para los valores 1,2,3,4. 
    df.tobacco_smoking_history = df.tobacco_smoking_history.fillna(method='ffill')
   
    
#historial de alcohol: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.loc[df.alcohol_history_documented == 'NO', 'alcohol_history_documented'] = 0
    df.loc[df.alcohol_history_documented == 'YES', 'alcohol_history_documented'] = 1
    df.alcohol_history_documented = df.alcohol_history_documented.fillna(method='bfill')
    
#historial de reflujo: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.reflux_history = df.reflux_history.fillna(method='ffill')
    df.loc[(df.reflux_history == 'NO') | (df.reflux_history.isna()), 'reflux_history'] = 0
    df.loc[df.reflux_history == 'YES', 'reflux_history'] = 1
    
    
#diagnóstico inicial: pasar Symptomatic/Screening/Surveillance a 1/2/3 
#rellenar NaN con frontfill y get_dummies
    df.initial_diagnosis_by = df.initial_diagnosis_by.fillna(method='ffill')

    
#barretts_esophagus: Yes/No a 1/0 y rellenar NaN con frontfill
    df.loc[df.barretts_esophagus  == 'No', 'barretts_esophagus'] = 0
    df.loc[df.barretts_esophagus  == 'Yes-USA', 'barretts_esophagus'] = 1
    df.loc[df.barretts_esophagus  == 'Yes-UK', 'barretts_esophagus'] = 1 
    df.barretts_esophagus = df.barretts_esophagus.fillna(method='ffill')
    
#historial de cáncer de esófago: pasar Yes/No a 1/0 y rellenar NaN con backfill
    df.history_of_esophageal_cancer = df.history_of_esophageal_cancer.fillna(method='ffill')
    df.loc[(df.history_of_esophageal_cancer == 'NO') | (df.history_of_esophageal_cancer.isna()), 'history_of_esophageal_cancer'] = 0
    df.loc[df.history_of_esophageal_cancer == 'YES', 'history_of_esophageal_cancer'] = 1
    
    
#nuevos eventos tumorales: pasar Yes/No a 1/0
    df.loc[df.has_new_tumor_events_information == 'NO', 'has_new_tumor_events_information'] = 0
    df.loc[df.has_new_tumor_events_information == 'YES', 'has_new_tumor_events_information'] = 1
    
#le hacen seguimientos: pasar Yes/No a 1/0
    df.loc[df.has_follow_ups_information == 'NO', 'has_follow_ups_information'] = 0
    df.loc[df.has_follow_ups_information == 'YES', 'has_follow_ups_information'] = 1
    
#pautan medicación tumorales: pasar Yes/No a 1/0
    df.loc[df.has_drugs_information == 'NO', 'has_drugs_information'] = 0
    df.loc[df.has_drugs_information == 'YES', 'has_drugs_information'] = 1
    
#pautan radiación: pasar Yes/No a 1/0
    df.loc[df.has_radiations_information == 'NO', 'has_radiations_information'] = 0
    df.loc[df.has_radiations_information == 'YES', 'has_radiations_information'] = 1
    
#Combinamos las columnas stage_event_clinical_stage y stage_event_pathologic_stage en una única columna stage
#tomando como referencia el valor de stage_event_pathologic_stage, y cuando este es NaN
#tomando el valor de stage_event_clinical_stage.
    df['stage'] = np.where(~df['stage_event_pathologic_stage'].isna(), 
                           df['stage_event_pathologic_stage'], 
                           df['stage_event_clinical_stage'])
    
#Para aquellos casos en los que no está informado ni el estadio clínico ni patológico
#utilizaremos el valor T y N de la columna stage_event_tnm_categories para establecer el Stage
#Para ello, creamos las siguientes máscaras booleanas según la clasificación de stages
#para cáncer de esófago a partir de valores TNM encontrado online:

    #Stage I: T1, N0, M0
    #Stage II: T2, N0, M0 or T3, N0, M0 ...incluyo aquí los T2NX por ser Stage II mayoría
    #Stage III: T1-3, N1, M0 or T4, N0-1, M0
    #Stage IV: T1-4, N2-3, M0 or T1-4, N0-3, M1
    
    bool_mask_1 = ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                   (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False)))
    
    bool_mask_2 = (((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('X').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))))
    
    bool_mask_3 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('0').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('1').fillna(False))))
    
    bool_mask_4 = (((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('2').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('1').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |               
                   ((df['stage_event_tnm_categories'].str[1].str.match('2').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('3').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))) |
                   ((df['stage_event_tnm_categories'].str[1].str.match('4').fillna(False)) & 
                    (df['stage_event_tnm_categories'].str[3].str.match('3').fillna(False))))
    
    #Aplicamos la máscara
    mask_na = df['stage'].isna()
    df.loc[mask_na, 'stage'] = np.select([bool_mask_1[df['stage'].isna()], 
                                          bool_mask_2[df['stage'].isna()], 
                                          bool_mask_3[df['stage'].isna()],
                                          bool_mask_4[df['stage'].isna()]], 
                                         ['Stage I', 'Stage II', 'Stage III', 'Stage IV'], 
                                            default=np.nan)
    
#Simplificamos los valores de Stage a Stage I, Stage II, Stage III y Stage IV eliminando sufijos, previo a pasar a dummies
    df['stage'] = df['stage'].str.removesuffix('A').str.removesuffix('B').str.removesuffix('C')
      
#eliminaremos las columnas de clinical_stage, pathologic_stage y tnm_categories
    
    
#rellenamos los pocos valores NaN de primary_pathology_esophageal_tumor_cental_location 
#con Distal por ser el valor más frecuente y hacemos get_dummies para los tres valores: Distal, Mid, Proximal
    df.primary_pathology_esophageal_tumor_cental_location = df.primary_pathology_esophageal_tumor_cental_location.fillna('Distal')

    
#primary_pathology_histological_type: renombramos y hacemos get_dummies antes de eliminar columna original
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Adenocarcinoma, NOS'), 
            'primary_pathology_histological_type'] = 'Adeno-NOS'
    df.loc[(df['primary_pathology_histological_type']=='Esophagus Squamous Cell Carcinoma'), 
            'primary_pathology_histological_type'] = 'ESCC'
   
    
#primary_pathology_neoplasm_histologic_grade: get_dummies

    
#primary_pathology_age_at_initial_pathologic_diagnosis: escalar min_max
    df.primary_pathology_age_at_initial_pathologic_diagnosis = (df.primary_pathology_age_at_initial_pathologic_diagnosis - df.primary_pathology_age_at_initial_pathologic_diagnosis.min()) / (df.primary_pathology_age_at_initial_pathologic_diagnosis.max() - df.primary_pathology_age_at_initial_pathologic_diagnosis.min())
    
#primary_pathology_initial_pathologic_diagnosis_method:
#valores: biopsy/surgery/other
#la columna primary_pathology_init_pathology_dx_method_other (elimiada) informa de los posibles 'other':
#que en la gran mayoría de casos son surgical resection… por tanto, dejaremos solo dos alores biopsy/resection
#y en el último incluiremos los other y NaN de la columna, para después crear dummies
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] == 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Biopsy'
    df.loc[df['primary_pathology_initial_pathologic_diagnosis_method'] != 'Endoscopic Biopsy', 'primary_pathology_initial_pathologic_diagnosis_method'] = 'Resection'
    df.primary_pathology_initial_pathologic_diagnosis_method = df.primary_pathology_initial_pathologic_diagnosis_method.fillna('Resection')

    
#primary_pathology_lymph_node_metastasis_radiographic_evidence: 
#rellenar NaN en función de si en 'stage' es StageIV (YES) o no (NO), y hacer dummies
#borrar esta fila y stage
    
    bool_mask_stage = df.stage.str.match('Stage IV').fillna(False)
    bool_mask_no_stage = ((df.stage.str.match('Stage III').fillna(False)) |
                          (df.stage.str.match('Stage II').fillna(False)) |
                          (df.stage.str.match('Stage I').fillna(False)))
    mask_stage = df.primary_pathology_lymph_node_metastasis_radiographic_evidence.isna()
    df.loc[mask_stage, 'primary_pathology_lymph_node_metastasis_radiographic_evidence'] = np.select([bool_mask_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()], 
                                                                                                     bool_mask_no_stage[df['primary_pathology_lymph_node_metastasis_radiographic_evidence'].isna()]], 
                                                                                                    ['YES', 'NO'],
                                                                                                    default=np.nan)
        
#primary_pathology_primary_lymph_node_presentation_assessment. Rellenar NaN con method bfill
    df.primary_pathology_primary_lymph_node_presentation_assessment = df.primary_pathology_primary_lymph_node_presentation_assessment.fillna(method='bfill')

    
    
#primary_pathology_lymph_node_examined_count:
#se rellenarán los NaN como 0 si primary_lymph_node_presentation es 'NO' o con la media de recuento si es 'YES' (14.0)
#después se dividirán en 4 grupos según la clasificación descrita por The Cleveland Journal of Medicine
#de la clasificación TNM para el cáncer de esófago: 
#0 (N0), 1-2 (N1), 3-6 (N2), 7 o más (N3)
    bool_mask_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('YES').fillna(False)
    bool_mask_no_lymph = df.primary_pathology_primary_lymph_node_presentation_assessment.str.match('NO').fillna(False)
    
    mask_lymph_count = df.primary_pathology_lymph_node_examined_count.isna()
    mean_count = round(df.primary_pathology_lymph_node_examined_count.mean(),0)
    df.loc[mask_lymph_count, 'primary_pathology_lymph_node_examined_count'] = np.select([bool_mask_lymph[df['primary_pathology_lymph_node_examined_count'].isna()], 
                                                                                                     bool_mask_no_lymph[df['primary_pathology_lymph_node_examined_count'].isna()]], 
                                                                                                    [mean_count, 0.0],
                                                                                                    default=np.nan)
    df.loc[(df['primary_pathology_lymph_node_examined_count'] == 0.0), 'lymph_node_count'] = 'N0'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 1.0) & (df['primary_pathology_lymph_node_examined_count'] <= 2.0), 'lymph_node_count'] = 'N1'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 3.0) & (df['primary_pathology_lymph_node_examined_count'] <= 6.0), 'lymph_node_count'] = 'N2'
    df.loc[(df['primary_pathology_lymph_node_examined_count'] >= 7.0), 'lymph_node_count'] = 'N3'
    
#primary_pathology_residual_tumor: rellenamos NaN con forward fill, y demás valores pasan a dos grupos: No (R0) & Yes (R1/R2/RX), then get_dummies
    
    df.primary_pathology_residual_tumor = df.primary_pathology_residual_tumor.fillna(method='ffill')
    df.loc[(df['primary_pathology_residual_tumor'] == 'R0'),'primary_pathology_residual_tumor'] = 'NO'
    df.loc[(df['primary_pathology_residual_tumor'] != 'R0'),'primary_pathology_residual_tumor'] = 'YES'

    
    #primary_pathology_radiation_therapy
    df.primary_pathology_radiation_therapy = df.primary_pathology_radiation_therapy.fillna(method='ffill')

    
    #primary_pathology_postoperative_rx_tx 
    df.primary_pathology_postoperative_rx_tx = df.primary_pathology_postoperative_rx_tx.fillna(method='bfill')
    
    cols_to_dummies = ['icd_o_3_histology', 'icd_10', 'gender', 'race_list', 'tobacco_smoking_history', 'initial_diagnosis_by', 'stage', 
                         'primary_pathology_esophageal_tumor_cental_location', 'primary_pathology_histological_type', 'primary_pathology_neoplasm_histologic_grade',
                         'primary_pathology_initial_pathologic_diagnosis_method', 'primary_pathology_lymph_node_metastasis_radiographic_evidence',
                         'primary_pathology_primary_lymph_node_presentation_assessment', 'lymph_node_count', 'primary_pathology_residual_tumor',
                         'primary_pathology_radiation_therapy', 'primary_pathology_postoperative_rx_tx']
    
#    cols_to_concat = ['tissue_collection','age','years_survived', 'height', 'weight', 'other_dx', 'person_neoplasm_cancer_status', 'vital_status', 'alcohol_history_documented',
#                     'reflux_history', 'barretts_esophagus', 'history_of_esophageal_cancer','has_new_tumor_events_information', 'has_follow_ups_information', 'has_drugs_information',
#                     'has_radiations_information', 'primary_pathology_age_at_initial_pathologic_diagnosis']
    
    
    df_final = pd.get_dummies(data=df, columns=cols_to_dummies, drop_first=True)
    df_final.drop(columns=['tissue_prospective_collection_indicator', 'tissue_retrospective_collection_indicator', 'days_to_birth', 
                           'ethnicity', 'stage_event_clinical_stage', 'stage_event_pathologic_stage', 'stage_event_tnm_categories', 
                           'primary_pathology_lymph_node_examined_count'], inplace=True)
    df_final=df_final.astype("float")
    df_final.to_csv('Esophageal_Dataset_clean.csv')
    return(df_final)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)
# Out:
# Index(['height', 'weight', 'other_dx', 'person_neoplasm_cancer_status',
#        'vital_status', 'alcohol_history_documented', 'reflux_history',
#        'barretts_esophagus', 'history_of_esophageal_cancer',
#        'has_new_tumor_events_information', 'has_follow_ups_information',
#        'has_drugs_information', 'has_radiations_information',
#        'primary_pathology_age_at_initial_pathologic_diagnosis',
#        'tissue_collection', 'age', 'years_survived',
#        'icd_o_3_histology_8071/3', 'icd_o_3_histology_8083/3',
#        'icd_o_3_histology_8140/3', 'icd_o_3_histology_8211/3',
#        'icd_o_3_histology_8480/3', 'icd_10_C15.4', 'icd_10_C15.5',
#        'icd_10_C15.9', 'icd_10_C16.0', 'gender_MALE',
#        'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
#        'race_list_WHITE', 'tobacco_smoking_history_2.0',
#        'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
#        'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
#        'stage_Stage II', 'stage_Stage III', 'stage_Stage IV',
#        'primary_pathology_esophageal_tumor_cental_location_Mid',
#        'primary_pathology_esophageal_tumor_cental_location_Proximal',
#        'primary_pathology_histological_type_ESCC',
#        'primary_pathology_neoplasm_histologic_grade_G2',
#        'primary_pathology_neoplasm_histologic_grade_G3',
#        'primary_pathology_neoplasm_histologic_grade_GX',
#        'primary_pathology_lymph_node_metastasis_radiographic_evidence_YES',
#        'primary_pathology_primary_lymph_node_presentation_assessment_YES',
#        'lymph_node_count_N1', 'lymph_node_count_N2', 'lymph_node_count_N3',
#        'primary_pathology_radiation_therapy_YES',
#        'primary_pathology_postoperative_rx_tx_YES'],
#       dtype='object')

# %%
def random_forest(data, target):
    import sklearn
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
    rand_forest = RandomForestClassifier(max_depth=3, min_samples_leaf=5, n_estimators=50)
    rand_forest.fit(X_train,y_train)
    #resultados para el TRAIN
    y_pred_train=rand_forest.predict(X_train)
    probs=rand_forest.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = rand_forest.predict(X_test) 
    probs = rand_forest.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import sklearn
from sklearn.tree import DecisionTreeClassifier # predict proba
from sklearn.tree import DecisionTreeRegressor

# %%
def catboost(data, target):
    import sklearn
    import catboost as ctb
    from catboost import CatBoostClassifier
    #from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import GridSearchCV
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

    ctbmodel = ctb.CatBoostClassifier()
    
    params = { #'objective': 'binary:logistic',
             'base_score': [0.5], # prediccion inicial
             'booster': ['gbtree'], # (gbtree, gblinear, dart)
             'colsample_bylevel': [1], # ratio de columnas en cada nivel
             'colsample_bytree': [0.6], # ratio de columnas por tree
             #'device': None,
             'early_stopping_rounds': [10],
             #'enable_categorical': False,
             #'eval_metric': None,
             #'feature_types': None,
             #'gamma': None, # minimo "loss" reduccion para crear un nuevo split. Larger-> conservative
             #'grow_policy': None,
             #'importance_type': None,
             #'interaction_constraints': None,
             'learning_rate': [0.01, 0.05], # aportacion de cada arbol al modelo
             #'max_bin': None,
             #'max_cat_threshold': None,
             #'max_cat_to_onehot': None,
             #'max_delta_step': None,
             'max_depth': [3,4], # maxima profundidad en cada arbol
             #'max_leaves': None,
             'min_child_weight': [10], # minimo numero samples por hoja
             #'missing': [0],
             #'monotone_constraints': None,
             #'multi_strategy': None,
             'n_estimators': [50,100,200] # numero de arboles
             #'n_jobs': [-1], # trabajos en paralelo
             #'num_parallel_tree': None,
             #'random_state': [0], # seed para generar los folds
             #'reg_alpha': None, # L1 regularización
             #'reg_lambda': None, # L2 regularización
             #'sampling_method': None,
             #'scale_pos_weight': [1],
             #'subsample': [0.9] # ratio de muestras por cada arbol 
             #'tree_method': None,
             #'validate_parameters': None,
             #'verbosity': 1
                            }
    
    scoring = ['accuracy', 'roc_auc']
    
    grid_solver = GridSearchCV(estimator = ctbmodel, # model to train
                   param_grid = params,
                   scoring = scoring,
                   cv = 2,
                   n_jobs=-1,
                   refit='accuracy',
                   verbose = 5,
                   error_score='raise')
 
    #grid_solver.fit(X_train,y_train)
    model_grid_boost = grid_solver.fit(X_train,y_train, eval_set=[(X_train, y_train), (X_test, y_test)]) 
    #resultados para el TRAIN

    
    
    y_pred_train=grid_solver.predict(X_train)
    probs=grid_solver.predict_proba(X_train)
    AUC_train = sklearn.metrics.roc_auc_score(y_pred_train, probs[:,1])
    Acc_train = sklearn.metrics.accuracy_score(y_train, y_pred_train)
    print("Train AUC:", AUC_train)
    print("Train Accuracy:", Acc_train)
    #resultados para el TEST
    y_pred_test = grid_solver.predict(X_test) 
    probs = grid_solver.predict_proba(X_test)
    AUC_test = sklearn.metrics.roc_auc_score(y_test, probs[:,1])
    Acc_test = sklearn.metrics.accuracy_score(y_test,y_pred_test)
    print("Test AUC: ", AUC_test)
    print("Test Accuracy: ", Acc_test)

    #df_test=pd.read_csv("test.csv")
    #y_pred = grid_solver.predict(preprocessing(df_test)) 

    #data_return = {"id":df_test["id"], "Depression":y_pred}
    #df_return = pd.DataFrame(data=data_return)
    #df_return.to_csv('second_attempt_test_v2_increase_folds.csv', index=False)
    #df_return.head()

    print(" Results from Grid Search:" )
    print("\n The best estimator across ALL searched params:\n", grid_solver.best_estimator_)
    print("\n The best score across ALL searched params:\n", grid_solver.best_score_)
    print("\n The best parameters across ALL searched params:\n", grid_solver.best_params_)

    return

# %%
def catboost_simp(data, target):
    import sklearn
    import catboost as ctb
    from catboost import CatBoostClassifier
    #from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import GridSearchCV
    from sklearn.metrics import accuracy_score, roc_auc_score
    from sklearn.model_selection import train_test_split
    
    X = data.drop(columns=[target])
    y = data[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

    ctbmodel_simp = ctb.CatBoostClassifier()

    ctbmodel_simp.fit(X_train, y_train)

# Evaluate and predict
    accuracy_train = ctbmodel_simp.score(X_train, y_train)
    
    predictions = ctbmodel_simp.predict(X_test)
    accuracy = ctbmodel_simp.score(X_test, y_test)
    print("accuracy of ctbmodel_simp on training: ", accuracy_train)
    print("accuracy of ctbmodel_simp on testing: ", accuracy)
    return

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)

cols_to_model = ['height', 'weight', 'other_dx', 'alcohol_history_documented', 'reflux_history',
       'barretts_esophagus', 'history_of_esophageal_cancer', 'vital_status', 'age', 
       'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
       'race_list_WHITE', 'tobacco_smoking_history_2.0',
       'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
       'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
       'primary_pathology_esophageal_tumor_cental_location_Mid',
       'primary_pathology_esophageal_tumor_cental_location_Proximal', 'primary_pathology_histological_type_ESCC']

data_model = pd.DataFrame(data=data, columns=cols_to_model)
catboost_simp(data_model, 'primary_pathology_histological_type_ESCC')
# Out:
# Learning rate set to 0.016902
# 0:	learn: 0.6684445	total: 6.05ms	remaining: 6.05s
# 1:	learn: 0.6506043	total: 11.1ms	remaining: 5.55s
# 2:	learn: 0.6287617	total: 16.9ms	remaining: 5.63s
# 3:	learn: 0.6058862	total: 21.3ms	remaining: 5.3s
# 4:	learn: 0.5876687	total: 26.7ms	remaining: 5.32s
# 5:	learn: 0.5705073	total: 32.4ms	remaining: 5.37s
# 6:	learn: 0.5542475	total: 37.9ms	remaining: 5.38s
# 7:	learn: 0.5428007	total: 43ms	remaining: 5.34s
# 8:	learn: 0.5284679	total: 48.5ms	remaining: 5.34s
# 9:	learn: 0.5136985	total: 54.4ms	remaining: 5.39s
# 10:	learn: 0.4980600	total: 61.2ms	remaining: 5.5s
# 11:	learn: 0.4846656	total: 68.3ms	remaining: 5.62s
# 12:	learn: 0.4713316	total: 75.4ms	remaining: 5.72s
# 13:	learn: 0.4594128	total: 83.2ms	remaining: 5.86s
# 14:	learn: 0.4445180	total: 90.6ms	remaining: 5.95s
# 15:	learn: 0.4302631	total: 99.2ms	remaining: 6.1s
# 16:	learn: 0.4193414	total: 108ms	remaining: 6.23s
# 17:	learn: 0.4101721	total: 115ms	remaining: 6.25s
# 18:	learn: 0.3988466	total: 123ms	remaining: 6.33s
# 19:	learn: 0.3901719	total: 130ms	remaining: 6.38s
# 20:	learn: 0.3823934	total: 138ms	remaining: 6.43s
# 21:	learn: 0.3727446	total: 146ms	remaining: 6.48s
# 22:	learn: 0.3653197	total: 154ms	remaining: 6.53s
# 23:	learn: 0.3590001	total: 162ms	remaining: 6.58s
# 24:	learn: 0.3532441	total: 170ms	remaining: 6.63s
# 25:	learn: 0.3469977	total: 178ms	remaining: 6.66s
# 26:	learn: 0.3380196	total: 185ms	remaining: 6.68s
# 27:	learn: 0.3305972	total: 194ms	remaining: 6.75s
# 28:	learn: 0.3226565	total: 203ms	remaining: 6.8s
# 29:	learn: 0.3173736	total: 211ms	remaining: 6.83s
# 30:	learn: 0.3117664	total: 219ms	remaining: 6.86s
# 31:	learn: 0.3085872	total: 226ms	remaining: 6.82s
# 32:	learn: 0.3023446	total: 232ms	remaining: 6.79s
# 33:	learn: 0.2956137	total: 240ms	remaining: 6.81s
# 34:	learn: 0.2900557	total: 248ms	remaining: 6.83s
# 35:	learn: 0.2864422	total: 256ms	remaining: 6.84s
# 36:	learn: 0.2814232	total: 264ms	remaining: 6.86s
# 37:	learn: 0.2770659	total: 271ms	remaining: 6.87s
# 38:	learn: 0.2741107	total: 278ms	remaining: 6.85s
# 39:	learn: 0.2694297	total: 286ms	remaining: 6.87s
# 40:	learn: 0.2639183	total: 295ms	remaining: 6.89s
# 41:	learn: 0.2609264	total: 303ms	remaining: 6.9s
# 42:	learn: 0.2568920	total: 311ms	remaining: 6.92s
# 43:	learn: 0.2540590	total: 319ms	remaining: 6.93s
# 44:	learn: 0.2503918	total: 326ms	remaining: 6.93s
# 45:	learn: 0.2470018	total: 335ms	remaining: 6.94s
# 46:	learn: 0.2431503	total: 343ms	remaining: 6.96s
# 47:	learn: 0.2385797	total: 351ms	remaining: 6.97s
# 48:	learn: 0.2346059	total: 358ms	remaining: 6.94s
# 49:	learn: 0.2320047	total: 366ms	remaining: 6.95s
# 50:	learn: 0.2289851	total: 373ms	remaining: 6.94s
# 51:	learn: 0.2258451	total: 380ms	remaining: 6.93s
# 52:	learn: 0.2227935	total: 388ms	remaining: 6.94s
# 53:	learn: 0.2200101	total: 395ms	remaining: 6.93s
# 54:	learn: 0.2179901	total: 402ms	remaining: 6.91s
# 55:	learn: 0.2150647	total: 408ms	remaining: 6.88s
# 56:	learn: 0.2130781	total: 414ms	remaining: 6.85s
# 57:	learn: 0.2104670	total: 421ms	remaining: 6.84s
# 58:	learn: 0.2075072	total: 429ms	remaining: 6.84s
# 59:	learn: 0.2042070	total: 437ms	remaining: 6.85s
# 60:	learn: 0.2012405	total: 444ms	remaining: 6.83s
# 61:	learn: 0.2002258	total: 452ms	remaining: 6.83s
# 62:	learn: 0.1983571	total: 459ms	remaining: 6.82s
# 63:	learn: 0.1962903	total: 467ms	remaining: 6.83s
# 64:	learn: 0.1941190	total: 473ms	remaining: 6.81s
# 65:	learn: 0.1922104	total: 479ms	remaining: 6.78s
# 66:	learn: 0.1909430	total: 487ms	remaining: 6.78s
# 67:	learn: 0.1895796	total: 494ms	remaining: 6.77s
# 68:	learn: 0.1880018	total: 500ms	remaining: 6.75s
# 69:	learn: 0.1862147	total: 507ms	remaining: 6.74s
# 70:	learn: 0.1843786	total: 514ms	remaining: 6.72s
# 71:	learn: 0.1829669	total: 521ms	remaining: 6.71s
# 72:	learn: 0.1818409	total: 526ms	remaining: 6.68s
# 73:	learn: 0.1799222	total: 533ms	remaining: 6.66s
# 74:	learn: 0.1785653	total: 539ms	remaining: 6.65s
# 75:	learn: 0.1761915	total: 546ms	remaining: 6.64s
# 76:	learn: 0.1745088	total: 553ms	remaining: 6.63s
# 77:	learn: 0.1725872	total: 559ms	remaining: 6.61s
# 78:	learn: 0.1710737	total: 567ms	remaining: 6.61s
# 79:	learn: 0.1688200	total: 573ms	remaining: 6.59s
# 80:	learn: 0.1666349	total: 580ms	remaining: 6.58s
# 81:	learn: 0.1646858	total: 586ms	remaining: 6.56s
# 82:	learn: 0.1629471	total: 591ms	remaining: 6.53s
# 83:	learn: 0.1612737	total: 598ms	remaining: 6.52s
# 84:	learn: 0.1598196	total: 605ms	remaining: 6.51s
# 85:	learn: 0.1585922	total: 609ms	remaining: 6.47s
# 86:	learn: 0.1574613	total: 613ms	remaining: 6.43s
# 87:	learn: 0.1560503	total: 617ms	remaining: 6.4s
# 88:	learn: 0.1547983	total: 622ms	remaining: 6.37s
# 89:	learn: 0.1535527	total: 627ms	remaining: 6.33s
# 90:	learn: 0.1524705	total: 631ms	remaining: 6.3s
# 91:	learn: 0.1513645	total: 636ms	remaining: 6.28s
# 92:	learn: 0.1493093	total: 640ms	remaining: 6.25s
# 93:	learn: 0.1482458	total: 645ms	remaining: 6.22s
# 94:	learn: 0.1461785	total: 650ms	remaining: 6.19s
# 95:	learn: 0.1443624	total: 655ms	remaining: 6.17s
# 96:	learn: 0.1428889	total: 659ms	remaining: 6.14s
# 97:	learn: 0.1418625	total: 663ms	remaining: 6.1s
# 98:	learn: 0.1404165	total: 667ms	remaining: 6.07s
# 99:	learn: 0.1385798	total: 672ms	remaining: 6.05s
# 100:	learn: 0.1376893	total: 677ms	remaining: 6.02s
# 101:	learn: 0.1366557	total: 681ms	remaining: 5.99s
# 102:	learn: 0.1353867	total: 685ms	remaining: 5.96s
# 103:	learn: 0.1342236	total: 688ms	remaining: 5.93s
# 104:	learn: 0.1330133	total: 692ms	remaining: 5.9s
# 105:	learn: 0.1322983	total: 695ms	remaining: 5.86s
# 106:	learn: 0.1311165	total: 700ms	remaining: 5.84s
# 107:	learn: 0.1299378	total: 704ms	remaining: 5.81s
# 108:	learn: 0.1288127	total: 707ms	remaining: 5.78s
# 109:	learn: 0.1281647	total: 711ms	remaining: 5.76s
# 110:	learn: 0.1272211	total: 715ms	remaining: 5.73s
# 111:	learn: 0.1260062	total: 720ms	remaining: 5.71s
# 112:	learn: 0.1252287	total: 723ms	remaining: 5.67s
# 113:	learn: 0.1242147	total: 726ms	remaining: 5.64s
# 114:	learn: 0.1231846	total: 730ms	remaining: 5.62s
# 115:	learn: 0.1220455	total: 733ms	remaining: 5.59s
# 116:	learn: 0.1208193	total: 736ms	remaining: 5.56s
# 117:	learn: 0.1200700	total: 740ms	remaining: 5.53s
# 118:	learn: 0.1193605	total: 743ms	remaining: 5.5s
# 119:	learn: 0.1182306	total: 746ms	remaining: 5.47s
# 120:	learn: 0.1168504	total: 749ms	remaining: 5.44s
# 121:	learn: 0.1164696	total: 753ms	remaining: 5.42s
# 122:	learn: 0.1156172	total: 756ms	remaining: 5.39s
# 123:	learn: 0.1147911	total: 761ms	remaining: 5.37s
# 124:	learn: 0.1143466	total: 764ms	remaining: 5.35s
# 125:	learn: 0.1135317	total: 767ms	remaining: 5.32s
# 126:	learn: 0.1129910	total: 772ms	remaining: 5.3s
# 127:	learn: 0.1124561	total: 776ms	remaining: 5.28s
# 128:	learn: 0.1121037	total: 780ms	remaining: 5.26s
# 129:	learn: 0.1106267	total: 783ms	remaining: 5.24s
# 130:	learn: 0.1097999	total: 787ms	remaining: 5.22s
# 131:	learn: 0.1089601	total: 792ms	remaining: 5.2s
# 132:	learn: 0.1082040	total: 797ms	remaining: 5.19s
# 133:	learn: 0.1073552	total: 802ms	remaining: 5.18s
# 134:	learn: 0.1061480	total: 806ms	remaining: 5.17s
# 135:	learn: 0.1055774	total: 811ms	remaining: 5.15s
# 136:	learn: 0.1048241	total: 814ms	remaining: 5.13s
# 137:	learn: 0.1041532	total: 818ms	remaining: 5.11s
# 138:	learn: 0.1035728	total: 821ms	remaining: 5.09s
# 139:	learn: 0.1027154	total: 825ms	remaining: 5.07s
# 140:	learn: 0.1019091	total: 829ms	remaining: 5.05s
# 141:	learn: 0.1013166	total: 833ms	remaining: 5.04s
# 142:	learn: 0.1007731	total: 839ms	remaining: 5.03s
# 143:	learn: 0.0997070	total: 844ms	remaining: 5.01s
# 144:	learn: 0.0990505	total: 849ms	remaining: 5s
# 145:	learn: 0.0985549	total: 854ms	remaining: 5s
# 146:	learn: 0.0978640	total: 859ms	remaining: 4.99s
# 147:	learn: 0.0972791	total: 864ms	remaining: 4.98s
# 148:	learn: 0.0967569	total: 870ms	remaining: 4.97s
# 149:	learn: 0.0962423	total: 875ms	remaining: 4.96s
# 150:	learn: 0.0956645	total: 881ms	remaining: 4.95s
# 151:	learn: 0.0948603	total: 886ms	remaining: 4.94s
# 152:	learn: 0.0939729	total: 891ms	remaining: 4.93s
# 153:	learn: 0.0931326	total: 896ms	remaining: 4.92s
# 154:	learn: 0.0928273	total: 902ms	remaining: 4.92s
# 155:	learn: 0.0923211	total: 908ms	remaining: 4.91s
# 156:	learn: 0.0919313	total: 913ms	remaining: 4.9s
# 157:	learn: 0.0913552	total: 919ms	remaining: 4.9s
# 158:	learn: 0.0906945	total: 923ms	remaining: 4.88s
# 159:	learn: 0.0903499	total: 930ms	remaining: 4.88s
# 160:	learn: 0.0900452	total: 935ms	remaining: 4.87s
# 161:	learn: 0.0893513	total: 941ms	remaining: 4.87s
# 162:	learn: 0.0885902	total: 947ms	remaining: 4.86s
# 163:	learn: 0.0879282	total: 952ms	remaining: 4.85s
# 164:	learn: 0.0874539	total: 957ms	remaining: 4.84s
# 165:	learn: 0.0866098	total: 963ms	remaining: 4.84s
# 166:	learn: 0.0860285	total: 968ms	remaining: 4.83s
# 167:	learn: 0.0852945	total: 973ms	remaining: 4.82s
# 168:	learn: 0.0847724	total: 980ms	remaining: 4.82s
# 169:	learn: 0.0842158	total: 986ms	remaining: 4.81s
# 170:	learn: 0.0837749	total: 993ms	remaining: 4.81s
# 171:	learn: 0.0828825	total: 1000ms	remaining: 4.81s
# 172:	learn: 0.0823343	total: 1s	remaining: 4.81s
# 173:	learn: 0.0818890	total: 1.01s	remaining: 4.8s
# 174:	learn: 0.0812194	total: 1.01s	remaining: 4.79s
# 175:	learn: 0.0807664	total: 1.02s	remaining: 4.78s
# 176:	learn: 0.0802051	total: 1.02s	remaining: 4.76s
# 177:	learn: 0.0798665	total: 1.03s	remaining: 4.75s
# 178:	learn: 0.0792882	total: 1.03s	remaining: 4.75s
# 179:	learn: 0.0788626	total: 1.04s	remaining: 4.74s
# 180:	learn: 0.0783834	total: 1.04s	remaining: 4.73s
# 181:	learn: 0.0778624	total: 1.05s	remaining: 4.72s
# 182:	learn: 0.0775952	total: 1.05s	remaining: 4.71s
# 183:	learn: 0.0771414	total: 1.06s	remaining: 4.71s
# 184:	learn: 0.0768292	total: 1.07s	remaining: 4.7s
# 185:	learn: 0.0764032	total: 1.07s	remaining: 4.69s
# 186:	learn: 0.0761815	total: 1.08s	remaining: 4.69s
# 187:	learn: 0.0757498	total: 1.08s	remaining: 4.68s
# 188:	learn: 0.0750947	total: 1.09s	remaining: 4.68s
# 189:	learn: 0.0746118	total: 1.1s	remaining: 4.68s
# 190:	learn: 0.0738053	total: 1.1s	remaining: 4.68s
# 191:	learn: 0.0732551	total: 1.11s	remaining: 4.68s
# 192:	learn: 0.0724952	total: 1.12s	remaining: 4.67s
# 193:	learn: 0.0722152	total: 1.13s	remaining: 4.67s
# 194:	learn: 0.0717912	total: 1.13s	remaining: 4.67s
# 195:	learn: 0.0711016	total: 1.14s	remaining: 4.67s
# 196:	learn: 0.0709019	total: 1.15s	remaining: 4.67s
# 197:	learn: 0.0700212	total: 1.15s	remaining: 4.67s
# 198:	learn: 0.0698191	total: 1.16s	remaining: 4.67s
# 199:	learn: 0.0691590	total: 1.17s	remaining: 4.67s
# 200:	learn: 0.0688262	total: 1.17s	remaining: 4.66s
# 201:	learn: 0.0683077	total: 1.18s	remaining: 4.66s
# 202:	learn: 0.0680345	total: 1.19s	remaining: 4.66s
# 203:	learn: 0.0676056	total: 1.19s	remaining: 4.66s
# 204:	learn: 0.0672827	total: 1.2s	remaining: 4.65s
# 205:	learn: 0.0670922	total: 1.2s	remaining: 4.64s
# 206:	learn: 0.0668619	total: 1.21s	remaining: 4.63s
# 207:	learn: 0.0665657	total: 1.21s	remaining: 4.62s
# 208:	learn: 0.0662454	total: 1.22s	remaining: 4.61s
# 209:	learn: 0.0657978	total: 1.22s	remaining: 4.6s
# 210:	learn: 0.0656155	total: 1.23s	remaining: 4.58s
# 211:	learn: 0.0652289	total: 1.23s	remaining: 4.57s
# 212:	learn: 0.0649059	total: 1.23s	remaining: 4.56s
# 213:	learn: 0.0643718	total: 1.24s	remaining: 4.55s
# 214:	learn: 0.0639420	total: 1.24s	remaining: 4.53s
# 215:	learn: 0.0636867	total: 1.25s	remaining: 4.52s
# 216:	learn: 0.0630820	total: 1.25s	remaining: 4.51s
# 217:	learn: 0.0626063	total: 1.25s	remaining: 4.49s
# 218:	learn: 0.0624078	total: 1.25s	remaining: 4.48s
# 219:	learn: 0.0621590	total: 1.26s	remaining: 4.46s
# 220:	learn: 0.0617984	total: 1.26s	remaining: 4.45s
# 221:	learn: 0.0612162	total: 1.26s	remaining: 4.43s
# 222:	learn: 0.0607535	total: 1.27s	remaining: 4.42s
# 223:	learn: 0.0603310	total: 1.27s	remaining: 4.4s
# 224:	learn: 0.0600782	total: 1.27s	remaining: 4.39s
# 225:	learn: 0.0595275	total: 1.28s	remaining: 4.37s
# 226:	learn: 0.0591828	total: 1.28s	remaining: 4.36s
# 227:	learn: 0.0588274	total: 1.28s	remaining: 4.34s
# 228:	learn: 0.0585756	total: 1.28s	remaining: 4.33s
# 229:	learn: 0.0581103	total: 1.29s	remaining: 4.31s
# 230:	learn: 0.0579535	total: 1.29s	remaining: 4.3s
# 231:	learn: 0.0577957	total: 1.29s	remaining: 4.28s
# 232:	learn: 0.0575033	total: 1.3s	remaining: 4.27s
# 233:	learn: 0.0571614	total: 1.3s	remaining: 4.25s
# 234:	learn: 0.0566676	total: 1.3s	remaining: 4.24s
# 235:	learn: 0.0561727	total: 1.3s	remaining: 4.22s
# 236:	learn: 0.0559135	total: 1.31s	remaining: 4.21s
# 237:	learn: 0.0557904	total: 1.31s	remaining: 4.19s
# 238:	learn: 0.0553442	total: 1.31s	remaining: 4.18s
# 239:	learn: 0.0550623	total: 1.31s	remaining: 4.16s
# 240:	learn: 0.0548413	total: 1.32s	remaining: 4.15s
# 241:	learn: 0.0545394	total: 1.32s	remaining: 4.13s
# 242:	learn: 0.0541262	total: 1.32s	remaining: 4.12s
# 243:	learn: 0.0538378	total: 1.32s	remaining: 4.11s
# 244:	learn: 0.0536275	total: 1.33s	remaining: 4.09s
# 245:	learn: 0.0534021	total: 1.33s	remaining: 4.08s
# 246:	learn: 0.0531068	total: 1.33s	remaining: 4.06s
# 247:	learn: 0.0528438	total: 1.33s	remaining: 4.05s
# 248:	learn: 0.0525507	total: 1.34s	remaining: 4.04s
# 249:	learn: 0.0521442	total: 1.34s	remaining: 4.02s
# 250:	learn: 0.0517373	total: 1.34s	remaining: 4.01s
# 251:	learn: 0.0514633	total: 1.34s	remaining: 3.99s
# 252:	learn: 0.0511958	total: 1.35s	remaining: 3.98s
# 253:	learn: 0.0508544	total: 1.35s	remaining: 3.97s
# 254:	learn: 0.0505023	total: 1.35s	remaining: 3.96s
# 255:	learn: 0.0502362	total: 1.36s	remaining: 3.94s
# 256:	learn: 0.0498792	total: 1.36s	remaining: 3.93s
# 257:	learn: 0.0496701	total: 1.36s	remaining: 3.92s
# 258:	learn: 0.0492719	total: 1.36s	remaining: 3.9s
# 259:	learn: 0.0490285	total: 1.37s	remaining: 3.89s
# 260:	learn: 0.0488769	total: 1.37s	remaining: 3.88s
# 261:	learn: 0.0487187	total: 1.37s	remaining: 3.87s
# 262:	learn: 0.0485546	total: 1.38s	remaining: 3.86s
# 263:	learn: 0.0483586	total: 1.38s	remaining: 3.85s
# 264:	learn: 0.0481562	total: 1.38s	remaining: 3.83s
# 265:	learn: 0.0479834	total: 1.39s	remaining: 3.82s
# 266:	learn: 0.0478075	total: 1.39s	remaining: 3.81s
# 267:	learn: 0.0476335	total: 1.39s	remaining: 3.8s
# 268:	learn: 0.0473641	total: 1.4s	remaining: 3.79s
# 269:	learn: 0.0472371	total: 1.4s	remaining: 3.78s
# 270:	learn: 0.0470813	total: 1.4s	remaining: 3.77s
# 271:	learn: 0.0468974	total: 1.41s	remaining: 3.77s
# 272:	learn: 0.0465760	total: 1.41s	remaining: 3.76s
# 273:	learn: 0.0462856	total: 1.41s	remaining: 3.75s
# 274:	learn: 0.0459648	total: 1.42s	remaining: 3.74s
# 275:	learn: 0.0457137	total: 1.42s	remaining: 3.73s
# 276:	learn: 0.0454250	total: 1.43s	remaining: 3.72s
# 277:	learn: 0.0453725	total: 1.43s	remaining: 3.71s
# 278:	learn: 0.0451458	total: 1.43s	remaining: 3.7s
# 279:	learn: 0.0448836	total: 1.44s	remaining: 3.69s
# 280:	learn: 0.0444670	total: 1.44s	remaining: 3.68s
# 281:	learn: 0.0443574	total: 1.44s	remaining: 3.68s
# 282:	learn: 0.0441784	total: 1.45s	remaining: 3.67s
# 283:	learn: 0.0438792	total: 1.45s	remaining: 3.66s
# 284:	learn: 0.0436935	total: 1.46s	remaining: 3.65s
# 285:	learn: 0.0434516	total: 1.46s	remaining: 3.65s
# 286:	learn: 0.0432641	total: 1.47s	remaining: 3.64s
# 287:	learn: 0.0430065	total: 1.47s	remaining: 3.64s
# 288:	learn: 0.0427446	total: 1.47s	remaining: 3.63s
# 289:	learn: 0.0425476	total: 1.48s	remaining: 3.62s
# 290:	learn: 0.0423175	total: 1.48s	remaining: 3.62s
# 291:	learn: 0.0421305	total: 1.49s	remaining: 3.61s
# 292:	learn: 0.0417909	total: 1.49s	remaining: 3.6s
# 293:	learn: 0.0416126	total: 1.5s	remaining: 3.59s
# 294:	learn: 0.0413652	total: 1.5s	remaining: 3.59s
# 295:	learn: 0.0411699	total: 1.5s	remaining: 3.58s
# 296:	learn: 0.0409742	total: 1.51s	remaining: 3.58s
# 297:	learn: 0.0407873	total: 1.51s	remaining: 3.57s
# 298:	learn: 0.0407152	total: 1.52s	remaining: 3.56s
# 299:	learn: 0.0404925	total: 1.52s	remaining: 3.56s
# 300:	learn: 0.0401977	total: 1.53s	remaining: 3.55s
# 301:	learn: 0.0400212	total: 1.53s	remaining: 3.55s
# 302:	learn: 0.0397582	total: 1.54s	remaining: 3.54s
# 303:	learn: 0.0393943	total: 1.55s	remaining: 3.54s
# 304:	learn: 0.0392393	total: 1.55s	remaining: 3.54s
# 305:	learn: 0.0390394	total: 1.56s	remaining: 3.53s
# 306:	learn: 0.0388412	total: 1.56s	remaining: 3.53s
# 307:	learn: 0.0384106	total: 1.57s	remaining: 3.52s
# 308:	learn: 0.0383072	total: 1.57s	remaining: 3.51s
# 309:	learn: 0.0379546	total: 1.58s	remaining: 3.51s
# 310:	learn: 0.0377770	total: 1.58s	remaining: 3.51s
# 311:	learn: 0.0376149	total: 1.59s	remaining: 3.5s
# 312:	learn: 0.0374840	total: 1.59s	remaining: 3.5s
# 313:	learn: 0.0373951	total: 1.6s	remaining: 3.49s
# 314:	learn: 0.0371977	total: 1.6s	remaining: 3.49s
# 315:	learn: 0.0370449	total: 1.61s	remaining: 3.48s
# 316:	learn: 0.0368921	total: 1.61s	remaining: 3.48s
# 317:	learn: 0.0366616	total: 1.62s	remaining: 3.48s
# 318:	learn: 0.0364188	total: 1.63s	remaining: 3.47s
# 319:	learn: 0.0363063	total: 1.63s	remaining: 3.47s
# 320:	learn: 0.0361442	total: 1.64s	remaining: 3.46s
# 321:	learn: 0.0360365	total: 1.64s	remaining: 3.46s
# 322:	learn: 0.0357160	total: 1.65s	remaining: 3.45s
# 323:	learn: 0.0355414	total: 1.65s	remaining: 3.45s
# 324:	learn: 0.0354066	total: 1.66s	remaining: 3.45s
# 325:	learn: 0.0353265	total: 1.67s	remaining: 3.44s
# 326:	learn: 0.0351115	total: 1.67s	remaining: 3.44s
# 327:	learn: 0.0349181	total: 1.68s	remaining: 3.44s
# 328:	learn: 0.0347515	total: 1.68s	remaining: 3.44s
# 329:	learn: 0.0344417	total: 1.69s	remaining: 3.43s
# 330:	learn: 0.0343508	total: 1.7s	remaining: 3.43s
# 331:	learn: 0.0342070	total: 1.7s	remaining: 3.43s
# 332:	learn: 0.0339988	total: 1.71s	remaining: 3.42s
# 333:	learn: 0.0338267	total: 1.72s	remaining: 3.42s
# 334:	learn: 0.0337837	total: 1.72s	remaining: 3.42s
# 335:	learn: 0.0336493	total: 1.73s	remaining: 3.42s
# 336:	learn: 0.0335474	total: 1.74s	remaining: 3.42s
# 337:	learn: 0.0333850	total: 1.74s	remaining: 3.41s
# 338:	learn: 0.0331428	total: 1.75s	remaining: 3.41s
# 339:	learn: 0.0329923	total: 1.76s	remaining: 3.41s
# 340:	learn: 0.0328336	total: 1.76s	remaining: 3.41s
# 341:	learn: 0.0326060	total: 1.77s	remaining: 3.41s
# 342:	learn: 0.0324324	total: 1.78s	remaining: 3.4s
# 343:	learn: 0.0323589	total: 1.78s	remaining: 3.4s
# 344:	learn: 0.0322470	total: 1.79s	remaining: 3.4s
# 345:	learn: 0.0321946	total: 1.8s	remaining: 3.4s
# 346:	learn: 0.0320774	total: 1.8s	remaining: 3.4s
# 347:	learn: 0.0318923	total: 1.81s	remaining: 3.39s
# 348:	learn: 0.0316911	total: 1.82s	remaining: 3.39s
# 349:	learn: 0.0315429	total: 1.82s	remaining: 3.39s
# 350:	learn: 0.0313906	total: 1.83s	remaining: 3.38s
# 351:	learn: 0.0312955	total: 1.83s	remaining: 3.38s
# 352:	learn: 0.0312266	total: 1.84s	remaining: 3.37s
# 353:	learn: 0.0311174	total: 1.84s	remaining: 3.37s
# 354:	learn: 0.0309857	total: 1.85s	remaining: 3.36s
# 355:	learn: 0.0309168	total: 1.85s	remaining: 3.36s
# 356:	learn: 0.0308043	total: 1.86s	remaining: 3.35s
# 357:	learn: 0.0306256	total: 1.86s	remaining: 3.35s
# 358:	learn: 0.0304952	total: 1.87s	remaining: 3.34s
# 359:	learn: 0.0303509	total: 1.87s	remaining: 3.33s
# 360:	learn: 0.0301626	total: 1.88s	remaining: 3.33s
# 361:	learn: 0.0300317	total: 1.89s	remaining: 3.32s
# 362:	learn: 0.0298845	total: 1.89s	remaining: 3.32s
# 363:	learn: 0.0298087	total: 1.9s	remaining: 3.31s
# 364:	learn: 0.0297145	total: 1.9s	remaining: 3.31s
# 365:	learn: 0.0295799	total: 1.91s	remaining: 3.3s
# 366:	learn: 0.0294796	total: 1.91s	remaining: 3.29s
# 367:	learn: 0.0293693	total: 1.91s	remaining: 3.29s
# 368:	learn: 0.0292666	total: 1.92s	remaining: 3.28s
# 369:	learn: 0.0291632	total: 1.92s	remaining: 3.27s
# 370:	learn: 0.0290012	total: 1.93s	remaining: 3.27s
# 371:	learn: 0.0289431	total: 1.93s	remaining: 3.26s
# 372:	learn: 0.0287898	total: 1.94s	remaining: 3.26s
# 373:	learn: 0.0286599	total: 1.94s	remaining: 3.25s
# 374:	learn: 0.0285454	total: 1.95s	remaining: 3.25s
# 375:	learn: 0.0284240	total: 1.95s	remaining: 3.24s
# 376:	learn: 0.0283340	total: 1.96s	remaining: 3.24s
# 377:	learn: 0.0281832	total: 1.96s	remaining: 3.23s
# 378:	learn: 0.0280664	total: 1.97s	remaining: 3.23s
# 379:	learn: 0.0279582	total: 1.97s	remaining: 3.22s
# 380:	learn: 0.0278708	total: 1.98s	remaining: 3.22s
# 381:	learn: 0.0277425	total: 1.99s	remaining: 3.21s
# 382:	learn: 0.0275593	total: 1.99s	remaining: 3.21s
# 383:	learn: 0.0274515	total: 2s	remaining: 3.21s
# 384:	learn: 0.0273202	total: 2.01s	remaining: 3.2s
# 385:	learn: 0.0272529	total: 2.01s	remaining: 3.2s
# 386:	learn: 0.0271603	total: 2.02s	remaining: 3.2s
# 387:	learn: 0.0271008	total: 2.02s	remaining: 3.19s
# 388:	learn: 0.0269570	total: 2.03s	remaining: 3.19s
# 389:	learn: 0.0266922	total: 2.04s	remaining: 3.19s
# 390:	learn: 0.0265526	total: 2.04s	remaining: 3.19s
# 391:	learn: 0.0265053	total: 2.05s	remaining: 3.18s
# 392:	learn: 0.0264025	total: 2.06s	remaining: 3.18s
# 393:	learn: 0.0262804	total: 2.07s	remaining: 3.18s
# 394:	learn: 0.0261594	total: 2.07s	remaining: 3.17s
# 395:	learn: 0.0260700	total: 2.08s	remaining: 3.17s
# 396:	learn: 0.0258519	total: 2.09s	remaining: 3.17s
# 397:	learn: 0.0257394	total: 2.09s	remaining: 3.17s
# 398:	learn: 0.0256373	total: 2.1s	remaining: 3.16s
# 399:	learn: 0.0255471	total: 2.11s	remaining: 3.16s
# 400:	learn: 0.0254749	total: 2.11s	remaining: 3.16s
# 401:	learn: 0.0253866	total: 2.12s	remaining: 3.15s
# 402:	learn: 0.0252951	total: 2.13s	remaining: 3.15s
# 403:	learn: 0.0251710	total: 2.13s	remaining: 3.15s
# 404:	learn: 0.0250817	total: 2.14s	remaining: 3.14s
# 405:	learn: 0.0249893	total: 2.15s	remaining: 3.14s
# 406:	learn: 0.0248902	total: 2.15s	remaining: 3.14s
# 407:	learn: 0.0247455	total: 2.16s	remaining: 3.14s
# 408:	learn: 0.0246754	total: 2.17s	remaining: 3.13s
# 409:	learn: 0.0246056	total: 2.18s	remaining: 3.13s
# 410:	learn: 0.0245107	total: 2.18s	remaining: 3.13s
# 411:	learn: 0.0243977	total: 2.19s	remaining: 3.13s
# 412:	learn: 0.0242942	total: 2.2s	remaining: 3.12s
# 413:	learn: 0.0242256	total: 2.2s	remaining: 3.12s
# 414:	learn: 0.0241204	total: 2.21s	remaining: 3.12s
# 415:	learn: 0.0240385	total: 2.22s	remaining: 3.11s
# 416:	learn: 0.0239558	total: 2.22s	remaining: 3.11s
# 417:	learn: 0.0238006	total: 2.23s	remaining: 3.1s
# 418:	learn: 0.0236488	total: 2.23s	remaining: 3.1s
# 419:	learn: 0.0235422	total: 2.24s	remaining: 3.09s
# 420:	learn: 0.0234308	total: 2.25s	remaining: 3.09s
# 421:	learn: 0.0232426	total: 2.25s	remaining: 3.08s
# 422:	learn: 0.0230182	total: 2.26s	remaining: 3.08s
# 423:	learn: 0.0228794	total: 2.26s	remaining: 3.08s
# 424:	learn: 0.0226854	total: 2.27s	remaining: 3.07s
# 425:	learn: 0.0225306	total: 2.28s	remaining: 3.07s
# 426:	learn: 0.0223543	total: 2.28s	remaining: 3.06s
# 427:	learn: 0.0222436	total: 2.29s	remaining: 3.06s
# 428:	learn: 0.0221470	total: 2.3s	remaining: 3.06s
# 429:	learn: 0.0220916	total: 2.3s	remaining: 3.05s
# 430:	learn: 0.0218520	total: 2.31s	remaining: 3.05s
# 431:	learn: 0.0217241	total: 2.32s	remaining: 3.05s
# 432:	learn: 0.0216393	total: 2.32s	remaining: 3.04s
# 433:	learn: 0.0215423	total: 2.33s	remaining: 3.04s
# 434:	learn: 0.0214451	total: 2.34s	remaining: 3.03s
# 435:	learn: 0.0214130	total: 2.34s	remaining: 3.03s
# 436:	learn: 0.0213247	total: 2.35s	remaining: 3.03s
# 437:	learn: 0.0211982	total: 2.36s	remaining: 3.02s
# 438:	learn: 0.0211501	total: 2.37s	remaining: 3.02s
# 439:	learn: 0.0210839	total: 2.37s	remaining: 3.02s
# 440:	learn: 0.0210063	total: 2.38s	remaining: 3.02s
# 441:	learn: 0.0208578	total: 2.38s	remaining: 3.01s
# 442:	learn: 0.0207965	total: 2.39s	remaining: 3.01s
# 443:	learn: 0.0207222	total: 2.4s	remaining: 3s
# 444:	learn: 0.0205622	total: 2.41s	remaining: 3s
# 445:	learn: 0.0204756	total: 2.41s	remaining: 3s
# 446:	learn: 0.0204120	total: 2.42s	remaining: 2.99s
# 447:	learn: 0.0203517	total: 2.43s	remaining: 2.99s
# 448:	learn: 0.0202205	total: 2.43s	remaining: 2.98s
# 449:	learn: 0.0201108	total: 2.44s	remaining: 2.98s
# 450:	learn: 0.0200391	total: 2.45s	remaining: 2.98s
# 451:	learn: 0.0199766	total: 2.45s	remaining: 2.97s
# 452:	learn: 0.0199356	total: 2.46s	remaining: 2.97s
# 453:	learn: 0.0198663	total: 2.47s	remaining: 2.97s
# 454:	learn: 0.0197902	total: 2.47s	remaining: 2.96s
# 455:	learn: 0.0197022	total: 2.48s	remaining: 2.96s
# 456:	learn: 0.0196049	total: 2.49s	remaining: 2.95s
# 457:	learn: 0.0195359	total: 2.49s	remaining: 2.95s
# 458:	learn: 0.0194555	total: 2.5s	remaining: 2.95s
# 459:	learn: 0.0193682	total: 2.51s	remaining: 2.94s
# 460:	learn: 0.0192912	total: 2.51s	remaining: 2.94s
# 461:	learn: 0.0191827	total: 2.52s	remaining: 2.94s
# 462:	learn: 0.0191042	total: 2.53s	remaining: 2.93s
# 463:	learn: 0.0190335	total: 2.53s	remaining: 2.93s
# 464:	learn: 0.0189444	total: 2.54s	remaining: 2.92s
# 465:	learn: 0.0189036	total: 2.55s	remaining: 2.92s
# 466:	learn: 0.0188249	total: 2.55s	remaining: 2.91s
# 467:	learn: 0.0186989	total: 2.56s	remaining: 2.91s
# 468:	learn: 0.0186489	total: 2.56s	remaining: 2.9s
# 469:	learn: 0.0185742	total: 2.57s	remaining: 2.9s
# 470:	learn: 0.0184638	total: 2.58s	remaining: 2.9s
# 471:	learn: 0.0184207	total: 2.58s	remaining: 2.89s
# 472:	learn: 0.0183444	total: 2.59s	remaining: 2.89s
# 473:	learn: 0.0182640	total: 2.6s	remaining: 2.88s
# 474:	learn: 0.0180787	total: 2.6s	remaining: 2.88s
# 475:	learn: 0.0180203	total: 2.62s	remaining: 2.89s
# 476:	learn: 0.0179393	total: 2.63s	remaining: 2.88s
# 477:	learn: 0.0178762	total: 2.63s	remaining: 2.88s
# 478:	learn: 0.0178230	total: 2.64s	remaining: 2.87s
# 479:	learn: 0.0177712	total: 2.64s	remaining: 2.86s
# 480:	learn: 0.0177175	total: 2.65s	remaining: 2.86s
# 481:	learn: 0.0176590	total: 2.65s	remaining: 2.85s
# 482:	learn: 0.0176031	total: 2.66s	remaining: 2.85s
# 483:	learn: 0.0174729	total: 2.67s	remaining: 2.84s
# 484:	learn: 0.0174290	total: 2.67s	remaining: 2.83s
# 485:	learn: 0.0173494	total: 2.67s	remaining: 2.83s
# 486:	learn: 0.0172827	total: 2.68s	remaining: 2.82s
# 487:	learn: 0.0171384	total: 2.69s	remaining: 2.82s
# 488:	learn: 0.0170584	total: 2.69s	remaining: 2.81s
# 489:	learn: 0.0169959	total: 2.7s	remaining: 2.81s
# 490:	learn: 0.0168968	total: 2.71s	remaining: 2.8s
# 491:	learn: 0.0168353	total: 2.71s	remaining: 2.8s
# 492:	learn: 0.0167629	total: 2.72s	remaining: 2.79s
# 493:	learn: 0.0167230	total: 2.73s	remaining: 2.79s
# 494:	learn: 0.0166516	total: 2.73s	remaining: 2.79s
# 495:	learn: 0.0165737	total: 2.74s	remaining: 2.78s
# 496:	learn: 0.0164958	total: 2.75s	remaining: 2.78s
# 497:	learn: 0.0164125	total: 2.75s	remaining: 2.77s
# 498:	learn: 0.0163513	total: 2.76s	remaining: 2.77s
# 499:	learn: 0.0162465	total: 2.77s	remaining: 2.77s
# 500:	learn: 0.0161944	total: 2.77s	remaining: 2.76s
# 501:	learn: 0.0161457	total: 2.78s	remaining: 2.76s
# 502:	learn: 0.0161029	total: 2.79s	remaining: 2.75s
# 503:	learn: 0.0160406	total: 2.79s	remaining: 2.75s
# 504:	learn: 0.0159897	total: 2.8s	remaining: 2.74s
# 505:	learn: 0.0159062	total: 2.8s	remaining: 2.74s
# 506:	learn: 0.0158707	total: 2.81s	remaining: 2.73s
# 507:	learn: 0.0158422	total: 2.81s	remaining: 2.73s
# 508:	learn: 0.0157760	total: 2.82s	remaining: 2.72s
# 509:	learn: 0.0157172	total: 2.82s	remaining: 2.71s
# 510:	learn: 0.0156431	total: 2.83s	remaining: 2.71s
# 511:	learn: 0.0155917	total: 2.83s	remaining: 2.7s
# 512:	learn: 0.0155435	total: 2.84s	remaining: 2.69s
# 513:	learn: 0.0154745	total: 2.84s	remaining: 2.69s
# 514:	learn: 0.0153855	total: 2.84s	remaining: 2.68s
# 515:	learn: 0.0153233	total: 2.85s	remaining: 2.67s
# 516:	learn: 0.0152701	total: 2.85s	remaining: 2.66s
# 517:	learn: 0.0152295	total: 2.85s	remaining: 2.66s
# 518:	learn: 0.0151667	total: 2.86s	remaining: 2.65s
# 519:	learn: 0.0151281	total: 2.86s	remaining: 2.64s
# 520:	learn: 0.0150271	total: 2.86s	remaining: 2.63s
# 521:	learn: 0.0149699	total: 2.87s	remaining: 2.63s
# 522:	learn: 0.0149148	total: 2.87s	remaining: 2.62s
# 523:	learn: 0.0148638	total: 2.88s	remaining: 2.61s
# 524:	learn: 0.0147667	total: 2.88s	remaining: 2.6s
# 525:	learn: 0.0147087	total: 2.88s	remaining: 2.6s
# 526:	learn: 0.0146573	total: 2.88s	remaining: 2.59s
# 527:	learn: 0.0145926	total: 2.89s	remaining: 2.58s
# 528:	learn: 0.0145484	total: 2.89s	remaining: 2.58s
# 529:	learn: 0.0144894	total: 2.9s	remaining: 2.57s
# 530:	learn: 0.0144400	total: 2.9s	remaining: 2.56s
# 531:	learn: 0.0143935	total: 2.9s	remaining: 2.55s
# 532:	learn: 0.0143049	total: 2.91s	remaining: 2.55s
# 533:	learn: 0.0142391	total: 2.91s	remaining: 2.54s
# 534:	learn: 0.0141774	total: 2.91s	remaining: 2.53s
# 535:	learn: 0.0141502	total: 2.92s	remaining: 2.52s
# 536:	learn: 0.0140874	total: 2.92s	remaining: 2.52s
# 537:	learn: 0.0140043	total: 2.92s	remaining: 2.51s
# 538:	learn: 0.0139421	total: 2.93s	remaining: 2.5s
# 539:	learn: 0.0138851	total: 2.93s	remaining: 2.5s
# 540:	learn: 0.0138279	total: 2.94s	remaining: 2.49s
# 541:	learn: 0.0137707	total: 2.94s	remaining: 2.48s
# 542:	learn: 0.0137429	total: 2.94s	remaining: 2.48s
# 543:	learn: 0.0137025	total: 2.95s	remaining: 2.47s
# 544:	learn: 0.0136036	total: 2.95s	remaining: 2.46s
# 545:	learn: 0.0135496	total: 2.96s	remaining: 2.46s
# 546:	learn: 0.0135201	total: 2.96s	remaining: 2.45s
# 547:	learn: 0.0134516	total: 2.97s	remaining: 2.45s
# 548:	learn: 0.0134010	total: 2.97s	remaining: 2.44s
# 549:	learn: 0.0133709	total: 2.98s	remaining: 2.43s
# 550:	learn: 0.0132890	total: 2.98s	remaining: 2.43s
# 551:	learn: 0.0132376	total: 2.98s	remaining: 2.42s
# 552:	learn: 0.0131943	total: 2.99s	remaining: 2.42s
# 553:	learn: 0.0131691	total: 2.99s	remaining: 2.41s
# 554:	learn: 0.0131377	total: 3s	remaining: 2.4s
# 555:	learn: 0.0130972	total: 3s	remaining: 2.4s
# 556:	learn: 0.0130573	total: 3.01s	remaining: 2.39s
# 557:	learn: 0.0129997	total: 3.01s	remaining: 2.39s
# 558:	learn: 0.0129531	total: 3.02s	remaining: 2.38s
# 559:	learn: 0.0129047	total: 3.02s	remaining: 2.38s
# 560:	learn: 0.0128835	total: 3.03s	remaining: 2.37s
# 561:	learn: 0.0128486	total: 3.03s	remaining: 2.36s
# 562:	learn: 0.0127625	total: 3.04s	remaining: 2.36s
# 563:	learn: 0.0127213	total: 3.04s	remaining: 2.35s
# 564:	learn: 0.0126780	total: 3.04s	remaining: 2.34s
# 565:	learn: 0.0126242	total: 3.05s	remaining: 2.34s
# 566:	learn: 0.0125999	total: 3.05s	remaining: 2.33s
# 567:	learn: 0.0125506	total: 3.06s	remaining: 2.33s
# 568:	learn: 0.0125094	total: 3.06s	remaining: 2.32s
# 569:	learn: 0.0124733	total: 3.07s	remaining: 2.31s
# 570:	learn: 0.0124227	total: 3.07s	remaining: 2.31s
# 571:	learn: 0.0123986	total: 3.08s	remaining: 2.3s
# 572:	learn: 0.0123651	total: 3.08s	remaining: 2.3s
# 573:	learn: 0.0123154	total: 3.09s	remaining: 2.29s
# 574:	learn: 0.0122661	total: 3.09s	remaining: 2.29s
# 575:	learn: 0.0122160	total: 3.1s	remaining: 2.28s
# 576:	learn: 0.0121774	total: 3.1s	remaining: 2.27s
# 577:	learn: 0.0121209	total: 3.1s	remaining: 2.27s
# 578:	learn: 0.0120952	total: 3.11s	remaining: 2.26s
# 579:	learn: 0.0120751	total: 3.11s	remaining: 2.25s
# 580:	learn: 0.0120381	total: 3.12s	remaining: 2.25s
# 581:	learn: 0.0119910	total: 3.12s	remaining: 2.24s
# 582:	learn: 0.0119664	total: 3.13s	remaining: 2.23s
# 583:	learn: 0.0119249	total: 3.13s	remaining: 2.23s
# 584:	learn: 0.0119031	total: 3.13s	remaining: 2.22s
# 585:	learn: 0.0118630	total: 3.14s	remaining: 2.22s
# 586:	learn: 0.0118413	total: 3.14s	remaining: 2.21s
# 587:	learn: 0.0117884	total: 3.14s	remaining: 2.2s
# 588:	learn: 0.0117592	total: 3.15s	remaining: 2.2s
# 589:	learn: 0.0116928	total: 3.15s	remaining: 2.19s
# 590:	learn: 0.0116433	total: 3.16s	remaining: 2.18s
# 591:	learn: 0.0116021	total: 3.16s	remaining: 2.18s
# 592:	learn: 0.0115659	total: 3.16s	remaining: 2.17s
# 593:	learn: 0.0115451	total: 3.17s	remaining: 2.16s
# 594:	learn: 0.0114701	total: 3.17s	remaining: 2.16s
# 595:	learn: 0.0114263	total: 3.17s	remaining: 2.15s
# 596:	learn: 0.0113763	total: 3.18s	remaining: 2.14s
# 597:	learn: 0.0113474	total: 3.18s	remaining: 2.14s
# 598:	learn: 0.0113124	total: 3.18s	remaining: 2.13s
# 599:	learn: 0.0112781	total: 3.19s	remaining: 2.12s
# 600:	learn: 0.0112401	total: 3.19s	remaining: 2.12s
# 601:	learn: 0.0112024	total: 3.19s	remaining: 2.11s
# 602:	learn: 0.0111826	total: 3.2s	remaining: 2.1s
# 603:	learn: 0.0111382	total: 3.2s	remaining: 2.1s
# 604:	learn: 0.0111158	total: 3.2s	remaining: 2.09s
# 605:	learn: 0.0110747	total: 3.21s	remaining: 2.08s
# 606:	learn: 0.0110531	total: 3.21s	remaining: 2.08s
# 607:	learn: 0.0110335	total: 3.21s	remaining: 2.07s
# 608:	learn: 0.0110042	total: 3.21s	remaining: 2.06s
# 609:	learn: 0.0109572	total: 3.22s	remaining: 2.06s
# 610:	learn: 0.0109149	total: 3.22s	remaining: 2.05s
# 611:	learn: 0.0108754	total: 3.22s	remaining: 2.04s
# 612:	learn: 0.0108517	total: 3.23s	remaining: 2.04s
# 613:	learn: 0.0108121	total: 3.23s	remaining: 2.03s
# 614:	learn: 0.0107821	total: 3.23s	remaining: 2.02s
# 615:	learn: 0.0107439	total: 3.24s	remaining: 2.02s
# 616:	learn: 0.0107056	total: 3.24s	remaining: 2.01s
# 617:	learn: 0.0106697	total: 3.24s	remaining: 2s
# 618:	learn: 0.0106205	total: 3.25s	remaining: 2s
# 619:	learn: 0.0105761	total: 3.25s	remaining: 1.99s
# 620:	learn: 0.0105347	total: 3.25s	remaining: 1.98s
# 621:	learn: 0.0104981	total: 3.25s	remaining: 1.98s
# 622:	learn: 0.0104810	total: 3.26s	remaining: 1.97s
# 623:	learn: 0.0104273	total: 3.26s	remaining: 1.96s
# 624:	learn: 0.0103953	total: 3.26s	remaining: 1.96s
# 625:	learn: 0.0103625	total: 3.27s	remaining: 1.95s
# 626:	learn: 0.0103107	total: 3.27s	remaining: 1.94s
# 627:	learn: 0.0102888	total: 3.27s	remaining: 1.94s
# 628:	learn: 0.0102622	total: 3.27s	remaining: 1.93s
# 629:	learn: 0.0102273	total: 3.28s	remaining: 1.92s
# 630:	learn: 0.0102029	total: 3.28s	remaining: 1.92s
# 631:	learn: 0.0101857	total: 3.28s	remaining: 1.91s
# 632:	learn: 0.0101517	total: 3.29s	remaining: 1.91s
# 633:	learn: 0.0101323	total: 3.29s	remaining: 1.9s
# 634:	learn: 0.0101068	total: 3.29s	remaining: 1.89s
# 635:	learn: 0.0100876	total: 3.29s	remaining: 1.89s
# 636:	learn: 0.0100631	total: 3.3s	remaining: 1.88s
# 637:	learn: 0.0100418	total: 3.3s	remaining: 1.87s
# 638:	learn: 0.0100044	total: 3.3s	remaining: 1.86s
# 639:	learn: 0.0099856	total: 3.3s	remaining: 1.86s
# 640:	learn: 0.0099528	total: 3.31s	remaining: 1.85s
# 641:	learn: 0.0099154	total: 3.31s	remaining: 1.84s
# 642:	learn: 0.0098957	total: 3.31s	remaining: 1.84s
# 643:	learn: 0.0098591	total: 3.31s	remaining: 1.83s
# 644:	learn: 0.0098236	total: 3.32s	remaining: 1.83s
# 645:	learn: 0.0098054	total: 3.32s	remaining: 1.82s
# 646:	learn: 0.0097759	total: 3.32s	remaining: 1.81s
# 647:	learn: 0.0097521	total: 3.33s	remaining: 1.81s
# 648:	learn: 0.0097215	total: 3.33s	remaining: 1.8s
# 649:	learn: 0.0096919	total: 3.33s	remaining: 1.79s
# 650:	learn: 0.0096634	total: 3.33s	remaining: 1.79s
# 651:	learn: 0.0096438	total: 3.34s	remaining: 1.78s
# 652:	learn: 0.0096209	total: 3.34s	remaining: 1.77s
# 653:	learn: 0.0096041	total: 3.34s	remaining: 1.77s
# 654:	learn: 0.0095855	total: 3.34s	remaining: 1.76s
# 655:	learn: 0.0095574	total: 3.35s	remaining: 1.75s
# 656:	learn: 0.0095297	total: 3.35s	remaining: 1.75s
# 657:	learn: 0.0095076	total: 3.35s	remaining: 1.74s
# 658:	learn: 0.0094894	total: 3.35s	remaining: 1.74s
# 659:	learn: 0.0094553	total: 3.36s	remaining: 1.73s
# 660:	learn: 0.0094270	total: 3.36s	remaining: 1.72s
# 661:	learn: 0.0093939	total: 3.36s	remaining: 1.72s
# 662:	learn: 0.0093674	total: 3.37s	remaining: 1.71s
# 663:	learn: 0.0093211	total: 3.37s	remaining: 1.71s
# 664:	learn: 0.0092936	total: 3.37s	remaining: 1.7s
# 665:	learn: 0.0092757	total: 3.38s	remaining: 1.69s
# 666:	learn: 0.0092490	total: 3.38s	remaining: 1.69s
# 667:	learn: 0.0092278	total: 3.38s	remaining: 1.68s
# 668:	learn: 0.0092051	total: 3.38s	remaining: 1.68s
# 669:	learn: 0.0091825	total: 3.39s	remaining: 1.67s
# 670:	learn: 0.0091569	total: 3.39s	remaining: 1.66s
# 671:	learn: 0.0091295	total: 3.4s	remaining: 1.66s
# 672:	learn: 0.0091139	total: 3.4s	remaining: 1.65s
# 673:	learn: 0.0090849	total: 3.4s	remaining: 1.65s
# 674:	learn: 0.0090558	total: 3.41s	remaining: 1.64s
# 675:	learn: 0.0090364	total: 3.41s	remaining: 1.63s
# 676:	learn: 0.0090075	total: 3.41s	remaining: 1.63s
# 677:	learn: 0.0089793	total: 3.42s	remaining: 1.62s
# 678:	learn: 0.0089517	total: 3.42s	remaining: 1.62s
# 679:	learn: 0.0089299	total: 3.43s	remaining: 1.61s
# 680:	learn: 0.0089164	total: 3.43s	remaining: 1.61s
# 681:	learn: 0.0088965	total: 3.44s	remaining: 1.6s
# 682:	learn: 0.0088802	total: 3.44s	remaining: 1.6s
# 683:	learn: 0.0088557	total: 3.44s	remaining: 1.59s
# 684:	learn: 0.0088425	total: 3.45s	remaining: 1.58s
# 685:	learn: 0.0088296	total: 3.45s	remaining: 1.58s
# 686:	learn: 0.0088143	total: 3.46s	remaining: 1.57s
# 687:	learn: 0.0087994	total: 3.46s	remaining: 1.57s
# 688:	learn: 0.0087804	total: 3.46s	remaining: 1.56s
# 689:	learn: 0.0087360	total: 3.47s	remaining: 1.56s
# 690:	learn: 0.0087152	total: 3.47s	remaining: 1.55s
# 691:	learn: 0.0086997	total: 3.48s	remaining: 1.55s
# 692:	learn: 0.0086679	total: 3.48s	remaining: 1.54s
# 693:	learn: 0.0086290	total: 3.48s	remaining: 1.54s
# 694:	learn: 0.0086107	total: 3.49s	remaining: 1.53s
# 695:	learn: 0.0085879	total: 3.5s	remaining: 1.53s
# 696:	learn: 0.0085688	total: 3.5s	remaining: 1.52s
# 697:	learn: 0.0085502	total: 3.5s	remaining: 1.52s
# 698:	learn: 0.0085196	total: 3.51s	remaining: 1.51s
# 699:	learn: 0.0084809	total: 3.51s	remaining: 1.51s
# 700:	learn: 0.0084579	total: 3.52s	remaining: 1.5s
# 701:	learn: 0.0084327	total: 3.52s	remaining: 1.5s
# 702:	learn: 0.0084078	total: 3.53s	remaining: 1.49s
# 703:	learn: 0.0083913	total: 3.54s	remaining: 1.49s
# 704:	learn: 0.0083747	total: 3.54s	remaining: 1.48s
# 705:	learn: 0.0083522	total: 3.55s	remaining: 1.48s
# 706:	learn: 0.0083279	total: 3.55s	remaining: 1.47s
# 707:	learn: 0.0082976	total: 3.56s	remaining: 1.47s
# 708:	learn: 0.0082832	total: 3.56s	remaining: 1.46s
# 709:	learn: 0.0082588	total: 3.57s	remaining: 1.46s
# 710:	learn: 0.0082296	total: 3.58s	remaining: 1.45s
# 711:	learn: 0.0082057	total: 3.58s	remaining: 1.45s
# 712:	learn: 0.0081806	total: 3.59s	remaining: 1.45s
# 713:	learn: 0.0081515	total: 3.6s	remaining: 1.44s
# 714:	learn: 0.0081345	total: 3.6s	remaining: 1.44s
# 715:	learn: 0.0081234	total: 3.61s	remaining: 1.43s
# 716:	learn: 0.0081004	total: 3.62s	remaining: 1.43s
# 717:	learn: 0.0080846	total: 3.62s	remaining: 1.42s
# 718:	learn: 0.0080661	total: 3.63s	remaining: 1.42s
# 719:	learn: 0.0080525	total: 3.64s	remaining: 1.41s
# 720:	learn: 0.0080346	total: 3.64s	remaining: 1.41s
# 721:	learn: 0.0080215	total: 3.65s	remaining: 1.4s
# 722:	learn: 0.0080063	total: 3.65s	remaining: 1.4s
# 723:	learn: 0.0079935	total: 3.66s	remaining: 1.4s
# 724:	learn: 0.0079734	total: 3.67s	remaining: 1.39s
# 725:	learn: 0.0079631	total: 3.67s	remaining: 1.39s
# 726:	learn: 0.0079457	total: 3.68s	remaining: 1.38s
# 727:	learn: 0.0079110	total: 3.68s	remaining: 1.38s
# 728:	learn: 0.0078976	total: 3.69s	remaining: 1.37s
# 729:	learn: 0.0078809	total: 3.7s	remaining: 1.37s
# 730:	learn: 0.0078603	total: 3.7s	remaining: 1.36s
# 731:	learn: 0.0078436	total: 3.71s	remaining: 1.36s
# 732:	learn: 0.0078237	total: 3.72s	remaining: 1.35s
# 733:	learn: 0.0078116	total: 3.72s	remaining: 1.35s
# 734:	learn: 0.0077887	total: 3.73s	remaining: 1.34s
# 735:	learn: 0.0077515	total: 3.74s	remaining: 1.34s
# 736:	learn: 0.0077378	total: 3.74s	remaining: 1.33s
# 737:	learn: 0.0077225	total: 3.75s	remaining: 1.33s
# 738:	learn: 0.0077008	total: 3.75s	remaining: 1.33s
# 739:	learn: 0.0076768	total: 3.76s	remaining: 1.32s
# 740:	learn: 0.0076429	total: 3.77s	remaining: 1.32s
# 741:	learn: 0.0076273	total: 3.77s	remaining: 1.31s
# 742:	learn: 0.0075953	total: 3.78s	remaining: 1.31s
# 743:	learn: 0.0075739	total: 3.79s	remaining: 1.3s
# 744:	learn: 0.0075483	total: 3.8s	remaining: 1.3s
# 745:	learn: 0.0075368	total: 3.8s	remaining: 1.29s
# 746:	learn: 0.0075152	total: 3.81s	remaining: 1.29s
# 747:	learn: 0.0074799	total: 3.81s	remaining: 1.28s
# 748:	learn: 0.0074494	total: 3.82s	remaining: 1.28s
# 749:	learn: 0.0074181	total: 3.82s	remaining: 1.27s
# 750:	learn: 0.0074065	total: 3.83s	remaining: 1.27s
# 751:	learn: 0.0073977	total: 3.83s	remaining: 1.26s
# 752:	learn: 0.0073863	total: 3.84s	remaining: 1.26s
# 753:	learn: 0.0073752	total: 3.84s	remaining: 1.25s
# 754:	learn: 0.0073612	total: 3.85s	remaining: 1.25s
# 755:	learn: 0.0073311	total: 3.85s	remaining: 1.24s
# 756:	learn: 0.0073166	total: 3.87s	remaining: 1.24s
# 757:	learn: 0.0072880	total: 3.87s	remaining: 1.24s
# 758:	learn: 0.0072707	total: 3.88s	remaining: 1.23s
# 759:	learn: 0.0072415	total: 3.89s	remaining: 1.23s
# 760:	learn: 0.0072310	total: 3.89s	remaining: 1.22s
# 761:	learn: 0.0072061	total: 3.9s	remaining: 1.22s
# 762:	learn: 0.0071924	total: 3.9s	remaining: 1.21s
# 763:	learn: 0.0071744	total: 3.9s	remaining: 1.21s
# 764:	learn: 0.0071565	total: 3.9s	remaining: 1.2s
# 765:	learn: 0.0071416	total: 3.91s	remaining: 1.19s
# 766:	learn: 0.0071221	total: 3.91s	remaining: 1.19s
# 767:	learn: 0.0071141	total: 3.92s	remaining: 1.18s
# 768:	learn: 0.0070954	total: 3.92s	remaining: 1.18s
# 769:	learn: 0.0070813	total: 3.92s	remaining: 1.17s
# 770:	learn: 0.0070664	total: 3.93s	remaining: 1.17s
# 771:	learn: 0.0070437	total: 3.93s	remaining: 1.16s
# 772:	learn: 0.0070128	total: 3.93s	remaining: 1.15s
# 773:	learn: 0.0070028	total: 3.94s	remaining: 1.15s
# 774:	learn: 0.0069885	total: 3.94s	remaining: 1.14s
# 775:	learn: 0.0069609	total: 3.94s	remaining: 1.14s
# 776:	learn: 0.0069443	total: 3.95s	remaining: 1.13s
# 777:	learn: 0.0069271	total: 3.95s	remaining: 1.13s
# 778:	learn: 0.0069148	total: 3.95s	remaining: 1.12s
# 779:	learn: 0.0068991	total: 3.96s	remaining: 1.11s
# 780:	learn: 0.0068825	total: 3.96s	remaining: 1.11s
# 781:	learn: 0.0068637	total: 3.96s	remaining: 1.1s
# 782:	learn: 0.0068516	total: 3.97s	remaining: 1.1s
# 783:	learn: 0.0068364	total: 3.97s	remaining: 1.09s
# 784:	learn: 0.0068270	total: 3.97s	remaining: 1.09s
# 785:	learn: 0.0068103	total: 3.98s	remaining: 1.08s
# 786:	learn: 0.0067853	total: 3.98s	remaining: 1.08s
# 787:	learn: 0.0067641	total: 3.98s	remaining: 1.07s
# 788:	learn: 0.0067351	total: 3.99s	remaining: 1.07s
# 789:	learn: 0.0067171	total: 4s	remaining: 1.06s
# 790:	learn: 0.0067010	total: 4s	remaining: 1.06s
# 791:	learn: 0.0066936	total: 4s	remaining: 1.05s
# 792:	learn: 0.0066779	total: 4.01s	remaining: 1.05s
# 793:	learn: 0.0066706	total: 4.01s	remaining: 1.04s
# 794:	learn: 0.0066539	total: 4.01s	remaining: 1.03s
# 795:	learn: 0.0066454	total: 4.02s	remaining: 1.03s
# 796:	learn: 0.0066324	total: 4.03s	remaining: 1.02s
# 797:	learn: 0.0066231	total: 4.03s	remaining: 1.02s
# 798:	learn: 0.0066123	total: 4.03s	remaining: 1.01s
# 799:	learn: 0.0066039	total: 4.04s	remaining: 1.01s
# 800:	learn: 0.0065920	total: 4.04s	remaining: 1s
# 801:	learn: 0.0065767	total: 4.05s	remaining: 1000ms
# 802:	learn: 0.0065616	total: 4.05s	remaining: 994ms
# 803:	learn: 0.0065359	total: 4.06s	remaining: 989ms
# 804:	learn: 0.0065160	total: 4.06s	remaining: 984ms
# 805:	learn: 0.0064989	total: 4.07s	remaining: 979ms
# 806:	learn: 0.0064848	total: 4.07s	remaining: 974ms
# 807:	learn: 0.0064597	total: 4.08s	remaining: 969ms
# 808:	learn: 0.0064529	total: 4.08s	remaining: 964ms
# 809:	learn: 0.0064372	total: 4.09s	remaining: 959ms
# 810:	learn: 0.0064234	total: 4.09s	remaining: 954ms
# 811:	learn: 0.0064101	total: 4.1s	remaining: 949ms
# 812:	learn: 0.0063952	total: 4.11s	remaining: 944ms
# 813:	learn: 0.0063804	total: 4.11s	remaining: 940ms
# 814:	learn: 0.0063558	total: 4.12s	remaining: 935ms
# 815:	learn: 0.0063399	total: 4.12s	remaining: 930ms
# 816:	learn: 0.0063254	total: 4.13s	remaining: 925ms
# 817:	learn: 0.0063074	total: 4.13s	remaining: 920ms
# 818:	learn: 0.0062934	total: 4.14s	remaining: 915ms
# 819:	learn: 0.0062796	total: 4.15s	remaining: 910ms
# 820:	learn: 0.0062661	total: 4.15s	remaining: 906ms
# 821:	learn: 0.0062489	total: 4.16s	remaining: 901ms
# 822:	learn: 0.0062350	total: 4.17s	remaining: 896ms
# 823:	learn: 0.0062175	total: 4.17s	remaining: 892ms
# 824:	learn: 0.0061890	total: 4.18s	remaining: 887ms
# 825:	learn: 0.0061807	total: 4.19s	remaining: 882ms
# 826:	learn: 0.0061741	total: 4.19s	remaining: 877ms
# 827:	learn: 0.0061591	total: 4.2s	remaining: 872ms
# 828:	learn: 0.0061433	total: 4.21s	remaining: 868ms
# 829:	learn: 0.0061272	total: 4.21s	remaining: 863ms
# 830:	learn: 0.0061190	total: 4.22s	remaining: 858ms
# 831:	learn: 0.0061061	total: 4.23s	remaining: 853ms
# 832:	learn: 0.0060889	total: 4.23s	remaining: 849ms
# 833:	learn: 0.0060653	total: 4.24s	remaining: 844ms
# 834:	learn: 0.0060516	total: 4.25s	remaining: 839ms
# 835:	learn: 0.0060365	total: 4.25s	remaining: 835ms
# 836:	learn: 0.0060275	total: 4.26s	remaining: 830ms
# 837:	learn: 0.0060130	total: 4.27s	remaining: 825ms
# 838:	learn: 0.0059999	total: 4.27s	remaining: 820ms
# 839:	learn: 0.0059873	total: 4.28s	remaining: 815ms
# 840:	learn: 0.0059737	total: 4.29s	remaining: 811ms
# 841:	learn: 0.0059641	total: 4.29s	remaining: 806ms
# 842:	learn: 0.0059564	total: 4.3s	remaining: 801ms
# 843:	learn: 0.0059464	total: 4.31s	remaining: 796ms
# 844:	learn: 0.0059338	total: 4.32s	remaining: 792ms
# 845:	learn: 0.0059216	total: 4.32s	remaining: 787ms
# 846:	learn: 0.0059084	total: 4.33s	remaining: 782ms
# 847:	learn: 0.0058950	total: 4.34s	remaining: 777ms
# 848:	learn: 0.0058805	total: 4.34s	remaining: 772ms
# 849:	learn: 0.0058559	total: 4.35s	remaining: 767ms
# 850:	learn: 0.0058476	total: 4.36s	remaining: 763ms
# 851:	learn: 0.0058351	total: 4.36s	remaining: 758ms
# 852:	learn: 0.0058230	total: 4.37s	remaining: 753ms
# 853:	learn: 0.0058158	total: 4.38s	remaining: 748ms
# 854:	learn: 0.0058076	total: 4.38s	remaining: 743ms
# 855:	learn: 0.0057937	total: 4.39s	remaining: 738ms
# 856:	learn: 0.0057822	total: 4.4s	remaining: 734ms
# 857:	learn: 0.0057742	total: 4.4s	remaining: 729ms
# 858:	learn: 0.0057579	total: 4.41s	remaining: 724ms
# 859:	learn: 0.0057340	total: 4.42s	remaining: 719ms
# 860:	learn: 0.0057166	total: 4.42s	remaining: 714ms
# 861:	learn: 0.0057035	total: 4.43s	remaining: 709ms
# 862:	learn: 0.0056935	total: 4.44s	remaining: 704ms
# 863:	learn: 0.0056813	total: 4.44s	remaining: 700ms
# 864:	learn: 0.0056680	total: 4.45s	remaining: 695ms
# 865:	learn: 0.0056572	total: 4.46s	remaining: 690ms
# 866:	learn: 0.0056452	total: 4.46s	remaining: 685ms
# 867:	learn: 0.0056390	total: 4.47s	remaining: 680ms
# 868:	learn: 0.0056267	total: 4.48s	remaining: 675ms
# 869:	learn: 0.0056059	total: 4.48s	remaining: 670ms
# 870:	learn: 0.0055926	total: 4.49s	remaining: 665ms
# 871:	learn: 0.0055801	total: 4.5s	remaining: 660ms
# 872:	learn: 0.0055666	total: 4.5s	remaining: 655ms
# 873:	learn: 0.0055523	total: 4.51s	remaining: 650ms
# 874:	learn: 0.0055393	total: 4.51s	remaining: 645ms
# 875:	learn: 0.0055163	total: 4.52s	remaining: 640ms
# 876:	learn: 0.0055036	total: 4.53s	remaining: 635ms
# 877:	learn: 0.0054977	total: 4.54s	remaining: 631ms
# 878:	learn: 0.0054859	total: 4.54s	remaining: 626ms
# 879:	learn: 0.0054755	total: 4.55s	remaining: 621ms
# 880:	learn: 0.0054640	total: 4.56s	remaining: 616ms
# 881:	learn: 0.0054545	total: 4.56s	remaining: 611ms
# 882:	learn: 0.0054442	total: 4.57s	remaining: 606ms
# 883:	learn: 0.0054324	total: 4.58s	remaining: 600ms
# 884:	learn: 0.0054197	total: 4.58s	remaining: 595ms
# 885:	learn: 0.0054084	total: 4.59s	remaining: 590ms
# 886:	learn: 0.0053890	total: 4.6s	remaining: 586ms
# 887:	learn: 0.0053672	total: 4.6s	remaining: 581ms
# 888:	learn: 0.0053616	total: 4.61s	remaining: 575ms
# 889:	learn: 0.0053562	total: 4.61s	remaining: 570ms
# 890:	learn: 0.0053488	total: 4.62s	remaining: 565ms
# 891:	learn: 0.0053393	total: 4.63s	remaining: 560ms
# 892:	learn: 0.0053288	total: 4.64s	remaining: 556ms
# 893:	learn: 0.0053211	total: 4.64s	remaining: 551ms
# 894:	learn: 0.0053140	total: 4.65s	remaining: 546ms
# 895:	learn: 0.0053029	total: 4.66s	remaining: 540ms
# 896:	learn: 0.0052917	total: 4.66s	remaining: 535ms
# 897:	learn: 0.0052798	total: 4.67s	remaining: 530ms
# 898:	learn: 0.0052608	total: 4.67s	remaining: 525ms
# 899:	learn: 0.0052501	total: 4.68s	remaining: 520ms
# 900:	learn: 0.0052379	total: 4.69s	remaining: 515ms
# 901:	learn: 0.0052260	total: 4.7s	remaining: 510ms
# 902:	learn: 0.0052162	total: 4.7s	remaining: 505ms
# 903:	learn: 0.0052060	total: 4.71s	remaining: 500ms
# 904:	learn: 0.0051943	total: 4.71s	remaining: 495ms
# 905:	learn: 0.0051741	total: 4.72s	remaining: 490ms
# 906:	learn: 0.0051624	total: 4.73s	remaining: 485ms
# 907:	learn: 0.0051471	total: 4.74s	remaining: 480ms
# 908:	learn: 0.0051340	total: 4.75s	remaining: 475ms
# 909:	learn: 0.0051239	total: 4.75s	remaining: 470ms
# 910:	learn: 0.0051144	total: 4.76s	remaining: 465ms
# 911:	learn: 0.0050997	total: 4.77s	remaining: 460ms
# 912:	learn: 0.0050818	total: 4.78s	remaining: 455ms
# 913:	learn: 0.0050670	total: 4.78s	remaining: 450ms
# 914:	learn: 0.0050596	total: 4.79s	remaining: 445ms
# 915:	learn: 0.0050510	total: 4.8s	remaining: 440ms
# 916:	learn: 0.0050406	total: 4.8s	remaining: 435ms
# 917:	learn: 0.0050212	total: 4.81s	remaining: 430ms
# 918:	learn: 0.0050111	total: 4.82s	remaining: 425ms
# 919:	learn: 0.0049999	total: 4.83s	remaining: 420ms
# 920:	learn: 0.0049897	total: 4.83s	remaining: 415ms
# 921:	learn: 0.0049793	total: 4.84s	remaining: 410ms
# 922:	learn: 0.0049698	total: 4.85s	remaining: 405ms
# 923:	learn: 0.0049597	total: 4.86s	remaining: 400ms
# 924:	learn: 0.0049548	total: 4.87s	remaining: 395ms
# 925:	learn: 0.0049440	total: 4.88s	remaining: 390ms
# 926:	learn: 0.0049323	total: 4.88s	remaining: 385ms
# 927:	learn: 0.0049237	total: 4.89s	remaining: 380ms
# 928:	learn: 0.0049154	total: 4.9s	remaining: 375ms
# 929:	learn: 0.0048983	total: 4.91s	remaining: 370ms
# 930:	learn: 0.0048927	total: 4.92s	remaining: 364ms
# 931:	learn: 0.0048839	total: 4.93s	remaining: 359ms
# 932:	learn: 0.0048791	total: 4.93s	remaining: 354ms
# 933:	learn: 0.0048610	total: 4.94s	remaining: 349ms
# 934:	learn: 0.0048496	total: 4.95s	remaining: 344ms
# 935:	learn: 0.0048411	total: 4.96s	remaining: 339ms
# 936:	learn: 0.0048314	total: 4.97s	remaining: 334ms
# 937:	learn: 0.0048221	total: 4.97s	remaining: 329ms
# 938:	learn: 0.0048109	total: 4.98s	remaining: 324ms
# 939:	learn: 0.0048021	total: 4.99s	remaining: 319ms
# 940:	learn: 0.0047925	total: 5s	remaining: 313ms
# 941:	learn: 0.0047823	total: 5s	remaining: 308ms
# 942:	learn: 0.0047728	total: 5.01s	remaining: 303ms
# 943:	learn: 0.0047683	total: 5.01s	remaining: 297ms
# 944:	learn: 0.0047580	total: 5.02s	remaining: 292ms
# 945:	learn: 0.0047487	total: 5.02s	remaining: 287ms
# 946:	learn: 0.0047414	total: 5.03s	remaining: 282ms
# 947:	learn: 0.0047320	total: 5.04s	remaining: 276ms
# 948:	learn: 0.0047238	total: 5.04s	remaining: 271ms
# 949:	learn: 0.0047147	total: 5.04s	remaining: 266ms
# 950:	learn: 0.0046990	total: 5.05s	remaining: 260ms
# 951:	learn: 0.0046938	total: 5.05s	remaining: 255ms
# 952:	learn: 0.0046838	total: 5.06s	remaining: 249ms
# 953:	learn: 0.0046685	total: 5.06s	remaining: 244ms
# 954:	learn: 0.0046557	total: 5.06s	remaining: 239ms
# 955:	learn: 0.0046480	total: 5.07s	remaining: 233ms
# 956:	learn: 0.0046373	total: 5.07s	remaining: 228ms
# 957:	learn: 0.0046305	total: 5.07s	remaining: 222ms
# 958:	learn: 0.0046211	total: 5.08s	remaining: 217ms
# 959:	learn: 0.0046120	total: 5.08s	remaining: 212ms
# 960:	learn: 0.0046057	total: 5.08s	remaining: 206ms
# 961:	learn: 0.0045981	total: 5.08s	remaining: 201ms
# 962:	learn: 0.0045889	total: 5.09s	remaining: 195ms
# 963:	learn: 0.0045849	total: 5.09s	remaining: 190ms
# 964:	learn: 0.0045760	total: 5.09s	remaining: 185ms
# 965:	learn: 0.0045721	total: 5.09s	remaining: 179ms
# 966:	learn: 0.0045532	total: 5.1s	remaining: 174ms
# 967:	learn: 0.0045445	total: 5.1s	remaining: 169ms
# 968:	learn: 0.0045372	total: 5.1s	remaining: 163ms
# 969:	learn: 0.0045286	total: 5.11s	remaining: 158ms
# 970:	learn: 0.0045162	total: 5.11s	remaining: 153ms
# 971:	learn: 0.0045089	total: 5.11s	remaining: 147ms
# 972:	learn: 0.0045006	total: 5.11s	remaining: 142ms
# 973:	learn: 0.0044906	total: 5.11s	remaining: 137ms
# 974:	learn: 0.0044829	total: 5.12s	remaining: 131ms
# 975:	learn: 0.0044732	total: 5.12s	remaining: 126ms
# 976:	learn: 0.0044592	total: 5.12s	remaining: 121ms
# 977:	learn: 0.0044439	total: 5.13s	remaining: 115ms
# 978:	learn: 0.0044390	total: 5.13s	remaining: 110ms
# 979:	learn: 0.0044311	total: 5.13s	remaining: 105ms
# 980:	learn: 0.0044256	total: 5.13s	remaining: 99.4ms
# 981:	learn: 0.0044187	total: 5.13s	remaining: 94.1ms
# 982:	learn: 0.0044110	total: 5.14s	remaining: 88.9ms
# 983:	learn: 0.0044025	total: 5.14s	remaining: 83.6ms
# 984:	learn: 0.0043909	total: 5.14s	remaining: 78.3ms
# 985:	learn: 0.0043852	total: 5.14s	remaining: 73.1ms
# 986:	learn: 0.0043758	total: 5.15s	remaining: 67.8ms
# 987:	learn: 0.0043645	total: 5.15s	remaining: 62.6ms
# 988:	learn: 0.0043562	total: 5.15s	remaining: 57.3ms
# 989:	learn: 0.0043494	total: 5.16s	remaining: 52.1ms
# 990:	learn: 0.0043414	total: 5.16s	remaining: 46.8ms
# 991:	learn: 0.0043333	total: 5.16s	remaining: 41.6ms
# 992:	learn: 0.0043278	total: 5.16s	remaining: 36.4ms
# 993:	learn: 0.0043179	total: 5.17s	remaining: 31.2ms
# 994:	learn: 0.0043105	total: 5.17s	remaining: 26ms
# 995:	learn: 0.0043026	total: 5.17s	remaining: 20.8ms
# 996:	learn: 0.0042990	total: 5.17s	remaining: 15.6ms
# 997:	learn: 0.0042899	total: 5.18s	remaining: 10.4ms
# 998:	learn: 0.0042789	total: 5.18s	remaining: 5.18ms
# 999:	learn: 0.0042716	total: 5.18s	remaining: 0us
# accuracy of ctbmodel_simp on training:  1.0
# accuracy of ctbmodel_simp on testing:  1.0

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Esophageal_Dataset.csv")
data = preprocesamiento(df)

cols_to_model = ['height', 'weight', 'other_dx', 'alcohol_history_documented', 'reflux_history',
       'barretts_esophagus', 'history_of_esophageal_cancer', 'vital_status', 'age', 
       'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
       'race_list_WHITE', 'tobacco_smoking_history_2.0',
       'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
       'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
       'primary_pathology_esophageal_tumor_cental_location_Mid',
       'primary_pathology_esophageal_tumor_cental_location_Proximal', 'primary_pathology_histological_type_ESCC']

data_model = pd.DataFrame(data=data, columns=cols_to_model)
catboost(data_model, 'primary_pathology_histological_type_ESCC')

# %%
#MODEL NOW WITH LYMPH COUNT NODE OBTAINED FROM RADIOGRAPHY

df = pd.read_csv("Esophageal_Dataset.csv")
data2 = preprocesamiento(df)

cols_to_model2 = ['height', 'weight', 'other_dx', 'alcohol_history_documented', 'reflux_history',
       'barretts_esophagus', 'history_of_esophageal_cancer', 'vital_status', 'age', 
       'race_list_BLACK OR AFRICAN AMERICAN', 'race_list_HISPANIC',
       'race_list_WHITE', 'tobacco_smoking_history_2.0',
       'tobacco_smoking_history_3.0', 'tobacco_smoking_history_4.0',
       'initial_diagnosis_by_Surveillance', 'initial_diagnosis_by_Symptomatic',
       'primary_pathology_esophageal_tumor_cental_location_Mid',
       'primary_pathology_esophageal_tumor_cental_location_Proximal', 'primary_pathology_histological_type_ESCC',
       'lymph_node_count_N1', 'lymph_node_count_N2', 'lymph_node_count_N3']

data_model2 = pd.DataFrame(data=data2, columns=cols_to_model2)
catboost(data_model2, 'primary_pathology_histological_type_ESCC')
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [0]	validation_0-logloss:0.67101	validation_1-logloss:0.67153
# [1]	validation_0-logloss:0.64443	validation_1-logloss:0.64607
# [2]	validation_0-logloss:0.61813	validation_1-logloss:0.62030
# [3]	validation_0-logloss:0.59469	validation_1-logloss:0.59908
# [4]	validation_0-logloss:0.57502	validation_1-logloss:0.58001
# [5]	validation_0-logloss:0.55813	validation_1-logloss:0.56438
# [6]	validation_0-logloss:0.53867	validation_1-logloss:0.54528
# [7]	validation_0-logloss:0.52065	validation_1-logloss:0.52865
# [8]	validation_0-logloss:0.50312	validation_1-logloss:0.51161
# [9]	validation_0-logloss:0.48704	validation_1-logloss:0.49713
# [10]	validation_0-logloss:0.46856	validation_1-logloss:0.47958
# [11]	validation_0-logloss:0.45352	validation_1-logloss:0.46525
# [12]	validation_0-logloss:0.43773	validation_1-logloss:0.45024
# [13]	validation_0-logloss:0.42720	validation_1-logloss:0.43939
# [14]	validation_0-logloss:0.41869	validation_1-logloss:0.43089
# [15]	validation_0-logloss:0.40783	validation_1-logloss:0.42098
# [16]	validation_0-logloss:0.39820	validation_1-logloss:0.41144
# [17]	validation_0-logloss:0.38787	validation_1-logloss:0.40213
# [18]	validation_0-logloss:0.38193	validation_1-logloss:0.39552
# [19]	validation_0-logloss:0.37106	validation_1-logloss:0.38490
# [20]	validation_0-logloss:0.36093	validation_1-logloss:0.37518
# [21]	validation_0-logloss:0.35056	validation_1-logloss:0.36529
# [22]	validation_0-logloss:0.34101	validation_1-logloss:0.35622
# [23]	validation_0-logloss:0.33611	validation_1-logloss:0.35160
# [24]	validation_0-logloss:0.33071	validation_1-logloss:0.34653
# [25]	validation_0-logloss:0.32312	validation_1-logloss:0.33931
# [26]	validation_0-logloss:0.31577	validation_1-logloss:0.33243
# [27]	validation_0-logloss:0.31100	validation_1-logloss:0.32840
# [28]	validation_0-logloss:0.30495	validation_1-logloss:0.32234
# [29]	validation_0-logloss:0.29977	validation_1-logloss:0.31797
# [30]	validation_0-logloss:0.29423	validation_1-logloss:0.31252
# [31]	validation_0-logloss:0.28867	validation_1-logloss:0.30731
# [32]	validation_0-logloss:0.28258	validation_1-logloss:0.30190
# [33]	validation_0-logloss:0.27664	validation_1-logloss:0.29646
# [34]	validation_0-logloss:0.27121	validation_1-logloss:0.29110
# [35]	validation_0-logloss:0.26654	validation_1-logloss:0.28715
# [36]	validation_0-logloss:0.26263	validation_1-logloss:0.28326
# [37]	validation_0-logloss:0.25889	validation_1-logloss:0.27978
# [38]	validation_0-logloss:0.25596	validation_1-logloss:0.27706
# [39]	validation_0-logloss:0.25235	validation_1-logloss:0.27346
# [40]	validation_0-logloss:0.24840	validation_1-logloss:0.26985
# [41]	validation_0-logloss:0.24536	validation_1-logloss:0.26729
# [42]	validation_0-logloss:0.24249	validation_1-logloss:0.26484
# [43]	validation_0-logloss:0.23876	validation_1-logloss:0.26126
# [44]	validation_0-logloss:0.23544	validation_1-logloss:0.25774
# [45]	validation_0-logloss:0.23173	validation_1-logloss:0.25445
# [46]	validation_0-logloss:0.22982	validation_1-logloss:0.25275
# [47]	validation_0-logloss:0.22766	validation_1-logloss:0.25083
# [48]	validation_0-logloss:0.22556	validation_1-logloss:0.24908
# [49]	validation_0-logloss:0.22341	validation_1-logloss:0.24728
# [50]	validation_0-logloss:0.22055	validation_1-logloss:0.24432
# [51]	validation_0-logloss:0.21803	validation_1-logloss:0.24190
# [52]	validation_0-logloss:0.21584	validation_1-logloss:0.23954
# [53]	validation_0-logloss:0.21380	validation_1-logloss:0.23735
# [54]	validation_0-logloss:0.21161	validation_1-logloss:0.23530
# [55]	validation_0-logloss:0.20995	validation_1-logloss:0.23370
# [56]	validation_0-logloss:0.20865	validation_1-logloss:0.23279
# [57]	validation_0-logloss:0.20632	validation_1-logloss:0.23016
# [58]	validation_0-logloss:0.20451	validation_1-logloss:0.22816
# [59]	validation_0-logloss:0.20245	validation_1-logloss:0.22611
# [60]	validation_0-logloss:0.20041	validation_1-logloss:0.22373
# [61]	validation_0-logloss:0.19893	validation_1-logloss:0.22247
# [62]	validation_0-logloss:0.19714	validation_1-logloss:0.22050
# [63]	validation_0-logloss:0.19506	validation_1-logloss:0.21855
# [64]	validation_0-logloss:0.19272	validation_1-logloss:0.21620
# [65]	validation_0-logloss:0.19134	validation_1-logloss:0.21458
# [66]	validation_0-logloss:0.19006	validation_1-logloss:0.21328
# [67]	validation_0-logloss:0.18888	validation_1-logloss:0.21199
# [68]	validation_0-logloss:0.18721	validation_1-logloss:0.21005
# [69]	validation_0-logloss:0.18603	validation_1-logloss:0.20926
# [70]	validation_0-logloss:0.18508	validation_1-logloss:0.20835
# [71]	validation_0-logloss:0.18278	validation_1-logloss:0.20587
# [72]	validation_0-logloss:0.18173	validation_1-logloss:0.20506
# [73]	validation_0-logloss:0.17995	validation_1-logloss:0.20328
# [74]	validation_0-logloss:0.17825	validation_1-logloss:0.20157
# [75]	validation_0-logloss:0.17616	validation_1-logloss:0.19880
# [76]	validation_0-logloss:0.17467	validation_1-logloss:0.19676
# [77]	validation_0-logloss:0.17295	validation_1-logloss:0.19520
# [78]	validation_0-logloss:0.17118	validation_1-logloss:0.19374
# [79]	validation_0-logloss:0.16936	validation_1-logloss:0.19202
# [80]	validation_0-logloss:0.16816	validation_1-logloss:0.19039
# [81]	validation_0-logloss:0.16704	validation_1-logloss:0.18935
# [82]	validation_0-logloss:0.16564	validation_1-logloss:0.18780
# [83]	validation_0-logloss:0.16480	validation_1-logloss:0.18684
# [84]	validation_0-logloss:0.16374	validation_1-logloss:0.18540
# [85]	validation_0-logloss:0.16259	validation_1-logloss:0.18427
# [86]	validation_0-logloss:0.16084	validation_1-logloss:0.18189
# [87]	validation_0-logloss:0.15952	validation_1-logloss:0.18068
# [88]	validation_0-logloss:0.15870	validation_1-logloss:0.17997
# [89]	validation_0-logloss:0.15762	validation_1-logloss:0.17874
# [90]	validation_0-logloss:0.15559	validation_1-logloss:0.17651
# [91]	validation_0-logloss:0.15451	validation_1-logloss:0.17552
# [92]	validation_0-logloss:0.15362	validation_1-logloss:0.17437
# [93]	validation_0-logloss:0.15231	validation_1-logloss:0.17327
# [94]	validation_0-logloss:0.15115	validation_1-logloss:0.17223
# [95]	validation_0-logloss:0.15032	validation_1-logloss:0.17136
# [96]	validation_0-logloss:0.14951	validation_1-logloss:0.17053
# [97]	validation_0-logloss:0.14888	validation_1-logloss:0.16959
# [98]	validation_0-logloss:0.14740	validation_1-logloss:0.16797
# [99]	validation_0-logloss:0.14610	validation_1-logloss:0.16675
# [100]	validation_0-logloss:0.14497	validation_1-logloss:0.16567
# [101]	validation_0-logloss:0.14392	validation_1-logloss:0.16467
# [102]	validation_0-logloss:0.14330	validation_1-logloss:0.16391
# [103]	validation_0-logloss:0.14239	validation_1-logloss:0.16305
# [104]	validation_0-logloss:0.14197	validation_1-logloss:0.16277
# [105]	validation_0-logloss:0.14121	validation_1-logloss:0.16216
# [106]	validation_0-logloss:0.14069	validation_1-logloss:0.16160
# [107]	validation_0-logloss:0.14008	validation_1-logloss:0.16110
# [108]	validation_0-logloss:0.13923	validation_1-logloss:0.16045
# [109]	validation_0-logloss:0.13840	validation_1-logloss:0.15993
# [110]	validation_0-logloss:0.13764	validation_1-logloss:0.15934
# [111]	validation_0-logloss:0.13688	validation_1-logloss:0.15876
# [112]	validation_0-logloss:0.13607	validation_1-logloss:0.15800
# [113]	validation_0-logloss:0.13526	validation_1-logloss:0.15709
# [114]	validation_0-logloss:0.13488	validation_1-logloss:0.15670
# [115]	validation_0-logloss:0.13385	validation_1-logloss:0.15555
# [116]	validation_0-logloss:0.13299	validation_1-logloss:0.15472
# [117]	validation_0-logloss:0.13271	validation_1-logloss:0.15444
# [118]	validation_0-logloss:0.13236	validation_1-logloss:0.15413
# [119]	validation_0-logloss:0.13153	validation_1-logloss:0.15339
# [120]	validation_0-logloss:0.13050	validation_1-logloss:0.15247
# [121]	validation_0-logloss:0.12993	validation_1-logloss:0.15202
# [122]	validation_0-logloss:0.12832	validation_1-logloss:0.14998
# [123]	validation_0-logloss:0.12728	validation_1-logloss:0.14889
# [124]	validation_0-logloss:0.12603	validation_1-logloss:0.14722
# [125]	validation_0-logloss:0.12502	validation_1-logloss:0.14602
# [126]	validation_0-logloss:0.12432	validation_1-logloss:0.14525
# [127]	validation_0-logloss:0.12390	validation_1-logloss:0.14507
# [128]	validation_0-logloss:0.12335	validation_1-logloss:0.14428
# [129]	validation_0-logloss:0.12227	validation_1-logloss:0.14318
# [130]	validation_0-logloss:0.12169	validation_1-logloss:0.14275
# [131]	validation_0-logloss:0.12121	validation_1-logloss:0.14221
# [132]	validation_0-logloss:0.12078	validation_1-logloss:0.14186
# [133]	validation_0-logloss:0.12007	validation_1-logloss:0.14113
# [134]	validation_0-logloss:0.11914	validation_1-logloss:0.14026
# [135]	validation_0-logloss:0.11879	validation_1-logloss:0.13989
# [136]	validation_0-logloss:0.11825	validation_1-logloss:0.13915
# [137]	validation_0-logloss:0.11733	validation_1-logloss:0.13843
# [138]	validation_0-logloss:0.11684	validation_1-logloss:0.13820
# [139]	validation_0-logloss:0.11607	validation_1-logloss:0.13731
# [140]	validation_0-logloss:0.11527	validation_1-logloss:0.13624
# [141]	validation_0-logloss:0.11492	validation_1-logloss:0.13590
# [142]	validation_0-logloss:0.11401	validation_1-logloss:0.13458
# [143]	validation_0-logloss:0.11369	validation_1-logloss:0.13429
# [144]	validation_0-logloss:0.11294	validation_1-logloss:0.13324
# [145]	validation_0-logloss:0.11260	validation_1-logloss:0.13279
# [146]	validation_0-logloss:0.11222	validation_1-logloss:0.13232
# [147]	validation_0-logloss:0.11177	validation_1-logloss:0.13193
# [148]	validation_0-logloss:0.11142	validation_1-logloss:0.13170
# [149]	validation_0-logloss:0.11045	validation_1-logloss:0.13066
# [150]	validation_0-logloss:0.11019	validation_1-logloss:0.13060
# [151]	validation_0-logloss:0.10991	validation_1-logloss:0.13032
# [152]	validation_0-logloss:0.10912	validation_1-logloss:0.12946
# [153]	validation_0-logloss:0.10853	validation_1-logloss:0.12877
# [154]	validation_0-logloss:0.10815	validation_1-logloss:0.12844
# [155]	validation_0-logloss:0.10757	validation_1-logloss:0.12753
# [156]	validation_0-logloss:0.10713	validation_1-logloss:0.12715
# [157]	validation_0-logloss:0.10641	validation_1-logloss:0.12650
# [158]	validation_0-logloss:0.10585	validation_1-logloss:0.12597
# [159]	validation_0-logloss:0.10555	validation_1-logloss:0.12562
# [160]	validation_0-logloss:0.10485	validation_1-logloss:0.12495
# [161]	validation_0-logloss:0.10463	validation_1-logloss:0.12478
# [162]	validation_0-logloss:0.10429	validation_1-logloss:0.12434
# [163]	validation_0-logloss:0.10407	validation_1-logloss:0.12408
# [164]	validation_0-logloss:0.10360	validation_1-logloss:0.12332
# [165]	validation_0-logloss:0.10326	validation_1-logloss:0.12282
# [166]	validation_0-logloss:0.10301	validation_1-logloss:0.12258
# [167]	validation_0-logloss:0.10233	validation_1-logloss:0.12194
# [168]	validation_0-logloss:0.10179	validation_1-logloss:0.12150
# [169]	validation_0-logloss:0.10148	validation_1-logloss:0.12113
# [170]	validation_0-logloss:0.10101	validation_1-logloss:0.12057
# [171]	validation_0-logloss:0.10038	validation_1-logloss:0.11989
# [172]	validation_0-logloss:0.09993	validation_1-logloss:0.11942
# [173]	validation_0-logloss:0.09972	validation_1-logloss:0.11936
# [174]	validation_0-logloss:0.09892	validation_1-logloss:0.11849
# [175]	validation_0-logloss:0.09831	validation_1-logloss:0.11787
# [176]	validation_0-logloss:0.09785	validation_1-logloss:0.11735
# [177]	validation_0-logloss:0.09768	validation_1-logloss:0.11714
# [178]	validation_0-logloss:0.09748	validation_1-logloss:0.11696
# [179]	validation_0-logloss:0.09705	validation_1-logloss:0.11634
# [180]	validation_0-logloss:0.09679	validation_1-logloss:0.11591
# [181]	validation_0-logloss:0.09656	validation_1-logloss:0.11564
# [182]	validation_0-logloss:0.09615	validation_1-logloss:0.11521
# [183]	validation_0-logloss:0.09548	validation_1-logloss:0.11457
# [184]	validation_0-logloss:0.09501	validation_1-logloss:0.11416
# [185]	validation_0-logloss:0.09437	validation_1-logloss:0.11366
# [186]	validation_0-logloss:0.09399	validation_1-logloss:0.11321
# [187]	validation_0-logloss:0.09366	validation_1-logloss:0.11281
# [188]	validation_0-logloss:0.09305	validation_1-logloss:0.11229
# [189]	validation_0-logloss:0.09263	validation_1-logloss:0.11169
# [190]	validation_0-logloss:0.09222	validation_1-logloss:0.11117
# [191]	validation_0-logloss:0.09179	validation_1-logloss:0.11084
# [192]	validation_0-logloss:0.09146	validation_1-logloss:0.11044
# [193]	validation_0-logloss:0.09132	validation_1-logloss:0.11032
# [194]	validation_0-logloss:0.09072	validation_1-logloss:0.10963
# [195]	validation_0-logloss:0.09036	validation_1-logloss:0.10913
# [196]	validation_0-logloss:0.09009	validation_1-logloss:0.10891
# [197]	validation_0-logloss:0.08990	validation_1-logloss:0.10862
# [198]	validation_0-logloss:0.08953	validation_1-logloss:0.10798
# [199]	validation_0-logloss:0.08876	validation_1-logloss:0.10722
# Train AUC: 1.0
# Train Accuracy: 0.9733375156838143
# Test AUC:  0.9965545477450239
# Test Accuracy:  0.9611041405269761
